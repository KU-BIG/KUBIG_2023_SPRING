# %%
def trials(trade_end_date):
  return trade_end_date

# %%
trade_end_date = '2023-07-02'
a = trials(trade_end_date=trade_end_date)
a
# Out:
# '2023-07-02'

# %%
import datetime
today = datetime.date.today().strftime("%Y-%m-%d")
today
# Out:
# '2023-07-01'
