# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import FinanceDataReader as fdr
from Iterative_Backtester import IterativeBase
from Iterative_SMABOL import IterativeBacktest
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_31068\3546918746.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
data = fdr.DataReader('005930','2000-01-01','2023-06-01')['Close']
data.to_csv("SAMSUNG.csv")

data
# Out:
# Date
# 2000-01-04     6110
# 2000-01-05     5580
# 2000-01-06     5620
# 2000-01-07     5540
# 2000-01-10     5770
#               ...
# 2023-04-24    65200
# 2023-04-25    63600
# 2023-04-26    64100
# 2023-04-27    64600
# 2023-04-28    65500
# Name: Close, Length: 5760, dtype: int64

# %%
smabol = IterativeBacktest('005930','2022-01-01','2023-05-01',10000000,"SAMSUNG.csv")
smabol.SMA_BOL(50, 100, 200, 2)
smabol.plot_bol()
# Out:
# ---------------------------------------------------------------------------
# Testing SMA With Bolinger strategy | 005930 | SMA_S = 50 & SMA_M = 100 & SMA_L = 200 DEV = 2
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# 2023-04-28 | +++ CLOSING FINAL POSITION +++
# 2023-04-28 | closing position of 0 for 65500
# 2023-04-28 | Current Balance: 10000000.0
# 2023-04-28 | net performance (%) = 0.0
# 2023-04-28 | number of trades executed = 1
# ---------------------------------------------------------------------------
