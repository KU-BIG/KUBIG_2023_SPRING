# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools
# Out:
# c:\Users\se99a\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2020-07-31'

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TRADE_START_DATE = '2021-10-01'
TRADE_END_DATE = '2023-05-05'

# %%
tickers = ['XLB','XLE','XLF','XLI','XLK','XLP','XLU','XLV','XLY']

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = tickers).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (30213, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True)
# Out:
#              date        open        high         low       close    volume  \
# 0      2010-01-04   33.580002   34.020000   33.450001   25.364523   7567500
# 1      2010-01-04   57.919998   58.810001   57.790001   37.747677  16928400
# 2      2010-01-04   11.795288   11.965881   11.770918    9.344017  92942347
# 3      2010-01-04   28.090000   28.320000   27.959999   21.793045   7471500
# 4      2010-01-04   23.139999   23.290001   23.100000   19.110201   8449400
# ...           ...         ...         ...         ...         ...       ...
# 30208  2023-05-04  147.660004  148.539993  146.929993  147.231598   5430500
# 30209  2023-05-04   76.739998   76.860001   76.220001   75.931320  11682600
# 30210  2023-05-04   68.190002   68.860001   67.550003   68.042702  14631100
# 30211  2023-05-04  132.899994  132.979996  131.839996  131.857208   9625300
# 30212  2023-05-04  145.410004  146.039993  144.039993  143.980392   5331500
#
#        tic  day
# 0      XLB    0
# 1      XLE    0
# 2      XLF    0
# 3      XLI    0
# 4      XLK    0
# ...    ...  ...
# 30208  XLK    3
# 30209  XLP    3
# 30210  XLU    3
# 30211  XLV    3
# 30212  XLY    3
#
# [30213 rows x 8 columns]

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3356, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
processed
# Out:
#              date        open        high         low       close    volume  \
# 0      2010-01-04   33.580002   34.020000   33.450001   25.364523   7567500
# 1      2010-01-04   57.919998   58.810001   57.790001   37.747677  16928400
# 2      2010-01-04   11.795288   11.965881   11.770918    9.344017  92942347
# 3      2010-01-04   28.090000   28.320000   27.959999   21.793045   7471500
# 4      2010-01-04   23.139999   23.290001   23.100000   19.110201   8449400
# ...           ...         ...         ...         ...         ...       ...
# 30199  2023-05-03  149.690002  150.660004  148.179993  147.940125   5815100
# 30200  2023-05-03   77.059998   77.379997   76.639999   76.119987  11656600
# 30201  2023-05-03   68.639999   69.050003   67.989998   67.526855  11857200
# 30202  2023-05-03  134.259995  134.899994  133.270004  132.912888   8961500
# 30203  2023-05-03  145.940002  147.889999  145.279999  145.098145   4256000
#
#        tic  day      macd     boll_ub     boll_lb      rsi_30     cci_30  \
# 0      XLB    0  0.000000   25.521519   25.289543  100.000000  66.666667
# 1      XLE    0  0.000000   25.521519   25.289543  100.000000  66.666667
# 2      XLF    0  0.000000   25.521519   25.289543  100.000000  66.666667
# 3      XLI    0  0.000000   25.521519   25.289543  100.000000  66.666667
# 4      XLK    0  0.000000   25.521519   25.289543  100.000000  66.666667
# ...    ...  ...       ...         ...         ...         ...        ...
# 30199  XLK    2  1.101265  151.344400  144.908068   55.182961  46.442993
# 30200  XLP    2  0.875702   77.189108   74.079747   58.998054  93.547472
# 30201  XLU    2  0.319781   69.807814   67.590043   50.161291   8.126302
# 30202  XLV    2  0.915705  134.927106  131.520086   53.906948  54.096702
# 30203  XLY    2  0.418781  148.824533  143.067334   50.679820  23.335247
#
#             dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0      100.000000     25.364523     25.364523  20.040001    0.000000
# 1      100.000000     37.747677     37.747677  20.040001    0.000000
# 2      100.000000      9.344017      9.344017  20.040001    0.000000
# 3      100.000000     21.793045     21.793045  20.040001    0.000000
# 4      100.000000     19.110201     19.110201  20.040001    0.000000
# ...           ...           ...           ...        ...         ...
# 30199    6.225843    147.699630    143.517544  18.340000    4.220001
# 30200   22.508083     74.795711     73.269686  18.340000    4.220001
# 30201    8.132944     67.692193     66.656867  18.340000    4.220001
# 30202    6.687990    131.318106    129.596837  18.340000    4.220001
# 30203    0.925005    145.369260    145.068298  18.340000    4.220001
#
# [30204 rows x 18 columns]

# %%
processed.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close    volume  tic  day  \
# 0  2010-01-04  33.580002  34.020000  33.450001  25.364523   7567500  XLB    0
# 1  2010-01-04  57.919998  58.810001  57.790001  37.747677  16928400  XLE    0
# 2  2010-01-04  11.795288  11.965881  11.770918   9.344017  92942347  XLF    0
# 3  2010-01-04  28.090000  28.320000  27.959999  21.793045   7471500  XLI    0
# 4  2010-01-04  23.139999  23.290001  23.100000  19.110201   8449400  XLK    0
#
#    macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0   0.0  25.521519  25.289543   100.0  66.666667  100.0     25.364523
# 1   0.0  25.521519  25.289543   100.0  66.666667  100.0     37.747677
# 2   0.0  25.521519  25.289543   100.0  66.666667  100.0      9.344017
# 3   0.0  25.521519  25.289543   100.0  66.666667  100.0     21.793045
# 4   0.0  25.521519  25.289543   100.0  66.666667  100.0     19.110201
#
#    close_60_sma        vix  turbulence
# 0     25.364523  20.040001         0.0
# 1     37.747677  20.040001         0.0
# 2      9.344017  20.040001         0.0
# 3     21.793045  20.040001         0.0
# 4     19.110201  20.040001         0.0

# %%
list_ticker = processed["tic"].unique().tolist() #ticker 리스트 불러오기
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str)) #전체 데이터 날짜 날짜 리스트
combination = list(itertools.product(list_date,list_ticker)) #date, ticker 의 combination

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left") #date, tic combination 기준으로 우측에 해당되는 정보들 정리
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)
processed_full
# Out:
#              date  tic        open        high         low       close  \
# 0      2010-01-04  XLB   33.580002   34.020000   33.450001   25.364523
# 1      2010-01-04  XLE   57.919998   58.810001   57.790001   37.747677
# 2      2010-01-04  XLF   11.795288   11.965881   11.770918    9.344017
# 3      2010-01-04  XLI   28.090000   28.320000   27.959999   21.793045
# 4      2010-01-04  XLK   23.139999   23.290001   23.100000   19.110201
# ...           ...  ...         ...         ...         ...         ...
# 43807  2023-05-03  XLK  149.690002  150.660004  148.179993  147.940125
# 43808  2023-05-03  XLP   77.059998   77.379997   76.639999   76.119987
# 43809  2023-05-03  XLU   68.639999   69.050003   67.989998   67.526855
# 43810  2023-05-03  XLV  134.259995  134.899994  133.270004  132.912888
# 43811  2023-05-03  XLY  145.940002  147.889999  145.279999  145.098145
#
#            volume  day      macd     boll_ub     boll_lb      rsi_30  \
# 0       7567500.0  0.0  0.000000   25.521519   25.289543  100.000000
# 1      16928400.0  0.0  0.000000   25.521519   25.289543  100.000000
# 2      92942347.0  0.0  0.000000   25.521519   25.289543  100.000000
# 3       7471500.0  0.0  0.000000   25.521519   25.289543  100.000000
# 4       8449400.0  0.0  0.000000   25.521519   25.289543  100.000000
# ...           ...  ...       ...         ...         ...         ...
# 43807   5815100.0  2.0  1.101265  151.344400  144.908068   55.182961
# 43808  11656600.0  2.0  0.875702   77.189108   74.079747   58.998054
# 43809  11857200.0  2.0  0.319781   69.807814   67.590043   50.161291
# 43810   8961500.0  2.0  0.915705  134.927106  131.520086   53.906948
# 43811   4256000.0  2.0  0.418781  148.824533  143.067334   50.679820
#
#           cci_30       dx_30  close_30_sma  close_60_sma        vix  \
# 0      66.666667  100.000000     25.364523     25.364523  20.040001
# 1      66.666667  100.000000     37.747677     37.747677  20.040001
# 2      66.666667  100.000000      9.344017      9.344017  20.040001
# 3      66.666667  100.000000     21.793045     21.793045  20.040001
# 4      66.666667  100.000000     19.110201     19.110201  20.040001
# ...          ...         ...           ...           ...        ...
# 43807  46.442993    6.225843    147.699630    143.517544  18.340000
# 43808  93.547472   22.508083     74.795711     73.269686  18.340000
# 43809   8.126302    8.132944     67.692193     66.656867  18.340000
# 43810  54.096702    6.687990    131.318106    129.596837  18.340000
# 43811  23.335247    0.925005    145.369260    145.068298  18.340000
#
#        turbulence
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ...           ...
# 43807    4.220001
# 43808    4.220001
# 43809    4.220001
# 43810    4.220001
# 43811    4.220001
#
# [30204 rows x 18 columns]

# %%
#prediction 업로드시 확인 필요부분
prediction_5 = pd.read_csv('prediction_5.csv').set_index('Unnamed: 0')
prediction_10 = pd.read_csv('prediction_10.csv').set_index('Unnamed: 0')
prediction_30 = pd.read_csv('prediction_30.csv').set_index('Unnamed: 0')

# %%
#prediction 업로드시 확인 필요부분


prediction_5_list = []
for i in range(len(prediction_5)):
    for j in range(len(tickers)):
        prediction_5_list.append(prediction_5.iloc[i,j])
        
for i in range((len(processed_full)-len(prediction_5_list))//len(tickers)):
    for j in range(len(tickers)):
        prediction_5_list.append(prediction_5.iloc[-1,j])

prediction_10_list = []
for i in range(len(prediction_10)):
    for j in range(len(tickers)):
        prediction_10_list.append(prediction_10.iloc[i,j])

for i in range((len(processed_full)-len(prediction_10_list))//len(tickers)):
    for j in range(len(tickers)):
        prediction_10_list.append(prediction_10.iloc[-1,j])
    
prediction_30_list = []
for i in range(len(prediction_30)):
    for j in range(len(tickers)):
        prediction_30_list.append(prediction_30.iloc[i,j])
for i in range((len(processed_full)-len(prediction_30_list))//len(tickers)):
    for j in range(len(tickers)):
        prediction_30_list.append(prediction_30.iloc[-1,j])
        
print(len(prediction_5_list))
# Out:
# 30204

# %%
#prediction 업로드시 확인 필요부분

processed_full['prediction_5']=prediction_5_list
processed_full['prediction_10']=prediction_10_list
processed_full['prediction_30']=prediction_30_list

processed_full
# Out:
#              date  tic        open        high         low       close  \
# 0      2010-01-04  XLB   33.580002   34.020000   33.450001   25.364523
# 1      2010-01-04  XLE   57.919998   58.810001   57.790001   37.747677
# 2      2010-01-04  XLF   11.795288   11.965881   11.770918    9.344017
# 3      2010-01-04  XLI   28.090000   28.320000   27.959999   21.793045
# 4      2010-01-04  XLK   23.139999   23.290001   23.100000   19.110201
# ...           ...  ...         ...         ...         ...         ...
# 43807  2023-05-03  XLK  149.690002  150.660004  148.179993  147.940125
# 43808  2023-05-03  XLP   77.059998   77.379997   76.639999   76.119987
# 43809  2023-05-03  XLU   68.639999   69.050003   67.989998   67.526855
# 43810  2023-05-03  XLV  134.259995  134.899994  133.270004  132.912888
# 43811  2023-05-03  XLY  145.940002  147.889999  145.279999  145.098145
#
#            volume  day      macd     boll_ub  ...      rsi_30     cci_30  \
# 0       7567500.0  0.0  0.000000   25.521519  ...  100.000000  66.666667
# 1      16928400.0  0.0  0.000000   25.521519  ...  100.000000  66.666667
# 2      92942347.0  0.0  0.000000   25.521519  ...  100.000000  66.666667
# 3       7471500.0  0.0  0.000000   25.521519  ...  100.000000  66.666667
# 4       8449400.0  0.0  0.000000   25.521519  ...  100.000000  66.666667
# ...           ...  ...       ...         ...  ...         ...        ...
# 43807   5815100.0  2.0  1.101265  151.344400  ...   55.182961  46.442993
# 43808  11656600.0  2.0  0.875702   77.189108  ...   58.998054  93.547472
# 43809  11857200.0  2.0  0.319781   69.807814  ...   50.161291   8.126302
# 43810   8961500.0  2.0  0.915705  134.927106  ...   53.906948  54.096702
# 43811   4256000.0  2.0  0.418781  148.824533  ...   50.679820  23.335247
#
#             dx_30  close_30_sma  close_60_sma        vix  turbulence  \
# 0      100.000000     25.364523     25.364523  20.040001    0.000000
# 1      100.000000     37.747677     37.747677  20.040001    0.000000
# 2      100.000000      9.344017      9.344017  20.040001    0.000000
# 3      100.000000     21.793045     21.793045  20.040001    0.000000
# 4      100.000000     19.110201     19.110201  20.040001    0.000000
# ...           ...           ...           ...        ...         ...
# 43807    6.225843    147.699630    143.517544  18.340000    4.220001
# 43808   22.508083     74.795711     73.269686  18.340000    4.220001
# 43809    8.132944     67.692193     66.656867  18.340000    4.220001
# 43810    6.687990    131.318106    129.596837  18.340000    4.220001
# 43811    0.925005    145.369260    145.068298  18.340000    4.220001
#
#        prediction_5  prediction_10  prediction_30
# 0         24.808691      25.736322      28.809017
# 1         43.465008      40.742596      41.320526
# 2          9.345718       8.834105      10.960411
# 3         25.776966      26.768536      29.518600
# 4         23.978970      25.238838      25.585352
# ...             ...            ...            ...
# 43807    159.986050     199.206280     229.873230
# 43808     77.597080      82.179405      84.626710
# 43809     71.436134      72.501410      82.259230
# 43810    131.845380     142.892330     185.067350
# 43811    158.775710     165.053760     216.694090
#
# [30204 rows x 21 columns]

# %%
#prediction 업로드시 확인 필요부분


INDICATORS += ['prediction_5','prediction_10','prediction_30']

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 26613
# 3591

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension #현재 상태를 나타내는 state를 정의. 1+ ticker 개수 x2 + 인디케이터 개수 x ticker개수
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 9, State Space: 118

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 10000,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
print(buy_cost_list)
num_stock_shares
# Out:
# [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 0.001]
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %%
agent = DRLAgent(env = env_train)

if_using_a2c = True ##a2c만 사용해보자
if_using_ddpg = False
if_using_ppo = False
if_using_td3 = False
if_using_sac = False

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c,
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ----------------------------------------
# | time/                 |              |
# |    fps                | 190          |
# |    iterations         | 100          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -12.7        |
# |    explained_variance | -0.18        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -24.5        |
# |    reward             | 0.0073237848 |
# |    std                | 0.992        |
# |    value_loss         | 4.8          |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 200      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -12.7    |
# |    explained_variance | -0.395   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 3.27     |
# |    reward             | 0.639551 |
# |    std                | 0.992    |
# |    value_loss         | 1.07     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 180        |
# |    iterations         | 300        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -12.7      |
# |    explained_variance | 0.0386     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -6.59      |
# |    reward             | -1.6576111 |
# |    std                | 0.992      |
# |    value_loss         | 1.43       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 177         |
# |    iterations         | 400         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -12.7       |
# |    explained_variance | -0.253      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -9          |
# |    reward             | -0.22640552 |
# |    std                | 0.996       |
# |    value_loss         | 0.849       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 171         |
# |    iterations         | 500         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -12.7       |
# |    explained_variance | -0.274      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -0.234      |
# |    reward             | -0.26938117 |
# |    std                | 0.998       |
# |    value_loss         | 0.2         |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 167         |
# |    iterations         | 600         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -12.7       |
# |    explained_variance | -5.84       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 7.19        |
# |    reward             | -0.07025275 |
# |    std                | 0.997       |
# |    value_loss         | 0.303       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 159         |
# |    iterations         | 700         |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | -4.32       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -0.0178     |
# |    reward             | -0.13077122 |
# |    std                | 1           |
# |    value_loss         | 0.0462      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 157          |
# |    iterations         | 800          |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 4000         |
# | train/                |              |
# |    entropy_loss       | -12.8        |
# |    explained_variance | -286         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 799          |
# |    policy_loss        | 0.954        |
# |    reward             | -0.011568706 |
# |    std                | 1            |
# |    value_loss         | 0.138        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 155        |
# |    iterations         | 900        |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | -2.81      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -3.14      |
# |    reward             | 0.23277768 |
# |    std                | 1.01       |
# |    value_loss         | 0.0826     |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 154       |
# |    iterations         | 1000      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | -0.394    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -8.1      |
# |    reward             | 0.2301647 |
# |    std                | 1.02      |
# |    value_loss         | 0.747     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 152         |
# |    iterations         | 1100        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -13         |
# |    explained_variance | -0.00931    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 6.04        |
# |    reward             | 0.025117584 |
# |    std                | 1.02        |
# |    value_loss         | 0.211       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 149        |
# |    iterations         | 1200       |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | -0.825     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -5.07      |
# |    reward             | -0.6596635 |
# |    std                | 1.02       |
# |    value_loss         | 0.447      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 147         |
# |    iterations         | 1300        |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -13         |
# |    explained_variance | -0.169      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -4.14       |
# |    reward             | 0.088079266 |
# |    std                | 1.02        |
# |    value_loss         | 0.112       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 1400       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | -1.44      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 16.5       |
# |    reward             | 0.12252164 |
# |    std                | 1.02       |
# |    value_loss         | 1.66       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 1500       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | 0.2        |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 5.8        |
# |    reward             | 0.30616233 |
# |    std                | 1.02       |
# |    value_loss         | 0.439      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 141         |
# |    iterations         | 1600        |
# |    time_elapsed       | 56          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -13         |
# |    explained_variance | -0.185      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -1.94       |
# |    reward             | -0.26176012 |
# |    std                | 1.03        |
# |    value_loss         | 0.125       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 140        |
# |    iterations         | 1700       |
# |    time_elapsed       | 60         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -13        |
# |    explained_variance | -0.119     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 18         |
# |    reward             | 0.95784104 |
# |    std                | 1.03       |
# |    value_loss         | 2.64       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 1800      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -13       |
# |    explained_variance | 0.0844    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -5.8      |
# |    reward             | 0.1525393 |
# |    std                | 1.03      |
# |    value_loss         | 0.439     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 139         |
# |    iterations         | 1900        |
# |    time_elapsed       | 68          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -13         |
# |    explained_variance | -0.73       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -2.61       |
# |    reward             | 0.068894744 |
# |    std                | 1.03        |
# |    value_loss         | 0.121       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 139          |
# |    iterations         | 2000         |
# |    time_elapsed       | 71           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -13.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1999         |
# |    policy_loss        | 0.287        |
# |    reward             | 0.0069615003 |
# |    std                | 1.04         |
# |    value_loss         | 0.00449      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 139        |
# |    iterations         | 2100       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -13.1      |
# |    explained_variance | 0.172      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | -1.86      |
# |    reward             | 0.34684548 |
# |    std                | 1.04       |
# |    value_loss         | 0.057      |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 141          |
# |    iterations         | 2200         |
# |    time_elapsed       | 77           |
# |    total_timesteps    | 11000        |
# | train/                |              |
# |    entropy_loss       | -13.1        |
# |    explained_variance | -1.07        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2199         |
# |    policy_loss        | 7.5          |
# |    reward             | -0.087215826 |
# |    std                | 1.04         |
# |    value_loss         | 0.609        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 141        |
# |    iterations         | 2300       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -13.1      |
# |    explained_variance | 0.681      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | 9.05       |
# |    reward             | 0.42321944 |
# |    std                | 1.04       |
# |    value_loss         | 0.478      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 142         |
# |    iterations         | 2400        |
# |    time_elapsed       | 84          |
# |    total_timesteps    | 12000       |
# | train/                |             |
# |    entropy_loss       | -13.2       |
# |    explained_variance | 0.097       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2399        |
# |    policy_loss        | 1.72        |
# |    reward             | 0.029563958 |
# |    std                | 1.05        |
# |    value_loss         | 0.0306      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 2500       |
# |    time_elapsed       | 87         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -13.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -1.32      |
# |    reward             | 0.14128263 |
# |    std                | 1.06       |
# |    value_loss         | 0.0268     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 144        |
# |    iterations         | 2600       |
# |    time_elapsed       | 90         |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -13.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 1.56       |
# |    reward             | 0.11017618 |
# |    std                | 1.07       |
# |    value_loss         | 0.0416     |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 145         |
# |    iterations         | 2700        |
# |    time_elapsed       | 93          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -13.3       |
# |    explained_variance | -0.119      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | -1.9        |
# |    reward             | -0.16034456 |
# |    std                | 1.07        |
# |    value_loss         | 0.0267      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 144         |
# |    iterations         | 2800        |
# |    time_elapsed       | 96          |
# |    total_timesteps    | 14000       |
# | train/                |             |
# |    entropy_loss       | -13.4       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2799        |
# |    policy_loss        | -5.42       |
# |    reward             | -0.11843852 |
# |    std                | 1.07        |
# |    value_loss         | 0.187       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 144          |
# |    iterations         | 2900         |
# |    time_elapsed       | 100          |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -13.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | 3.17         |
# |    reward             | -0.049025018 |
# |    std                | 1.07         |
# |    value_loss         | 1            |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 143          |
# |    iterations         | 3000         |
# |    time_elapsed       | 104          |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -13.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | 1.14         |
# |    reward             | -0.046367325 |
# |    std                | 1.07         |
# |    value_loss         | 0.00848      |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 3100       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -13.5      |
# |    explained_variance | 0.0529     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -4.81      |
# |    reward             | 0.06856581 |
# |    std                | 1.08       |
# |    value_loss         | 0.198      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 3200       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -13.5      |
# |    explained_variance | 0.00569    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | 7.75       |
# |    reward             | 0.17754868 |
# |    std                | 1.09       |
# |    value_loss         | 0.538      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 140        |
# |    iterations         | 3300       |
# |    time_elapsed       | 117        |
# |    total_timesteps    | 16500      |
# | train/                |            |
# |    entropy_loss       | -13.5      |
# |    explained_variance | -0.418     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3299       |
# |    policy_loss        | -0.97      |
# |    reward             | -0.2473078 |
# |    std                | 1.09       |
# |    value_loss         | 0.0247     |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 140          |
# |    iterations         | 3400         |
# |    time_elapsed       | 120          |
# |    total_timesteps    | 17000        |
# | train/                |              |
# |    entropy_loss       | -13.6        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 3399         |
# |    policy_loss        | -7.48        |
# |    reward             | -0.021579202 |
# |    std                | 1.09         |
# |    value_loss         | 2.67         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 139         |
# |    iterations         | 3500        |
# |    time_elapsed       | 125         |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 13.8        |
# |    reward             | -0.40781188 |
# |    std                | 1.1         |
# |    value_loss         | 1.87        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 139         |
# |    iterations         | 3600        |
# |    time_elapsed       | 129         |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -13.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | 0.727       |
# |    reward             | -0.02601814 |
# |    std                | 1.1         |
# |    value_loss         | 0.00698     |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 139        |
# |    iterations         | 3700       |
# |    time_elapsed       | 133        |
# |    total_timesteps    | 18500      |
# | train/                |            |
# |    entropy_loss       | -13.7      |
# |    explained_variance | 0.691      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3699       |
# |    policy_loss        | -0.295     |
# |    reward             | -0.0749451 |
# |    std                | 1.11       |
# |    value_loss         | 0.00879    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 138         |
# |    iterations         | 3800        |
# |    time_elapsed       | 136         |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -13.8       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3799        |
# |    policy_loss        | 4.26        |
# |    reward             | -0.05655954 |
# |    std                | 1.12        |
# |    value_loss         | 0.311       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 138        |
# |    iterations         | 3900       |
# |    time_elapsed       | 140        |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -13.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | 1.3        |
# |    reward             | 0.14666797 |
# |    std                | 1.12       |
# |    value_loss         | 0.0384     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 138        |
# |    iterations         | 4000       |
# |    time_elapsed       | 144        |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -13.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -12.3      |
# |    reward             | -1.4012225 |
# |    std                | 1.13       |
# |    value_loss         | 0.899      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 138       |
# |    iterations         | 4100      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -13.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -17.9     |
# |    reward             | 0.6649005 |
# |    std                | 1.13      |
# |    value_loss         | 1.84      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 4200        |
# |    time_elapsed       | 152         |
# |    total_timesteps    | 21000       |
# | train/                |             |
# |    entropy_loss       | -13.9       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4199        |
# |    policy_loss        | -1.25       |
# |    reward             | -0.21515265 |
# |    std                | 1.14        |
# |    value_loss         | 0.0256      |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 137          |
# |    iterations         | 4300         |
# |    time_elapsed       | 156          |
# |    total_timesteps    | 21500        |
# | train/                |              |
# |    entropy_loss       | -14          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4299         |
# |    policy_loss        | 0.833        |
# |    reward             | -0.064344786 |
# |    std                | 1.14         |
# |    value_loss         | 0.00584      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 137         |
# |    iterations         | 4400        |
# |    time_elapsed       | 160         |
# |    total_timesteps    | 22000       |
# | train/                |             |
# |    entropy_loss       | -14         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4399        |
# |    policy_loss        | -1.13       |
# |    reward             | -0.32181722 |
# |    std                | 1.15        |
# |    value_loss         | 0.0109      |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 137      |
# |    iterations         | 4500     |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -14.1    |
# |    explained_variance | -0.214   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 4.65     |
# |    reward             | 0.466038 |
# |    std                | 1.16     |
# |    value_loss         | 0.114    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 4600       |
# |    time_elapsed       | 167        |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -14.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 4.94       |
# |    reward             | 0.09726987 |
# |    std                | 1.16       |
# |    value_loss         | 0.232      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 4700        |
# |    time_elapsed       | 171         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -14.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | 14.8        |
# |    reward             | -0.13292608 |
# |    std                | 1.16        |
# |    value_loss         | 1.04        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 4800        |
# |    time_elapsed       | 175         |
# |    total_timesteps    | 24000       |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0.814       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4799        |
# |    policy_loss        | 0.739       |
# |    reward             | -0.24502248 |
# |    std                | 1.17        |
# |    value_loss         | 0.00556     |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 136         |
# |    iterations         | 4900        |
# |    time_elapsed       | 180         |
# |    total_timesteps    | 24500       |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4899        |
# |    policy_loss        | 5.47        |
# |    reward             | -0.05331961 |
# |    std                | 1.18        |
# |    value_loss         | 0.142       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 5000      |
# |    time_elapsed       | 183       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -14.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -3.68     |
# |    reward             | 0.2161306 |
# |    std                | 1.18      |
# |    value_loss         | 0.0832    |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 5100       |
# |    time_elapsed       | 187        |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.243      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | 5.05       |
# |    reward             | 0.10440056 |
# |    std                | 1.19       |
# |    value_loss         | 0.182      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 5200        |
# |    time_elapsed       | 191         |
# |    total_timesteps    | 26000       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 0.558       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5199        |
# |    policy_loss        | 6.28        |
# |    reward             | -0.09809183 |
# |    std                | 1.19        |
# |    value_loss         | 0.18        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 135         |
# |    iterations         | 5300        |
# |    time_elapsed       | 196         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -14.2       |
# |    explained_variance | -0.000645   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | 16          |
# |    reward             | -0.28284156 |
# |    std                | 1.18        |
# |    value_loss         | 1.58        |
# ---------------------------------------
# day: 2956, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 633197.50
# total_reward: -366802.50
# total_cost: 115452.82
# total_trades: 15112
# Sharpe: 0.227
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 134        |
# |    iterations         | 5400       |
# |    time_elapsed       | 200        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -11.8      |
# |    reward             | -0.3408292 |
# |    std                | 1.18       |
# |    value_loss         | 0.871      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 134         |
# |    iterations         | 5500        |
# |    time_elapsed       | 204         |
# |    total_timesteps    | 27500       |
# | train/                |             |
# |    entropy_loss       | -14.3       |
# |    explained_variance | 0.33        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5499        |
# |    policy_loss        | 9.86        |
# |    reward             | -0.13943532 |
# |    std                | 1.18        |
# |    value_loss         | 0.559       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 5600       |
# |    time_elapsed       | 209        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.15       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -3.24      |
# |    reward             | 0.28705278 |
# |    std                | 1.19       |
# |    value_loss         | 1.06       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 5700       |
# |    time_elapsed       | 213        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.142      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | 10.4       |
# |    reward             | 0.15820989 |
# |    std                | 1.19       |
# |    value_loss         | 1.27       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 5800       |
# |    time_elapsed       | 217        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 0.426      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | 5.83       |
# |    reward             | 0.34404832 |
# |    std                | 1.19       |
# |    value_loss         | 0.531      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 5900       |
# |    time_elapsed       | 220        |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -14.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | -6.33      |
# |    reward             | -0.6860282 |
# |    std                | 1.19       |
# |    value_loss         | 1.01       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 6000       |
# |    time_elapsed       | 224        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | -17.3      |
# |    reward             | 0.21614061 |
# |    std                | 1.2        |
# |    value_loss         | 1.39       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 6100       |
# |    time_elapsed       | 228        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | -0.426     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | 4.68       |
# |    reward             | 0.13143754 |
# |    std                | 1.2        |
# |    value_loss         | 0.24       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 6200       |
# |    time_elapsed       | 232        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -28.4      |
# |    reward             | -0.9941376 |
# |    std                | 1.2        |
# |    value_loss         | 5.6        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 133        |
# |    iterations         | 6300       |
# |    time_elapsed       | 236        |
# |    total_timesteps    | 31500      |
# | train/                |            |
# |    entropy_loss       | -14.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6299       |
# |    policy_loss        | -0.0605    |
# |    reward             | 0.17143936 |
# |    std                | 1.2        |
# |    value_loss         | 0.111      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 133      |
# |    iterations         | 6400     |
# |    time_elapsed       | 240      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -14.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 26.7     |
# |    reward             | 1.192594 |
# |    std                | 1.2      |
# |    value_loss         | 4.63     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 133         |
# |    iterations         | 6500        |
# |    time_elapsed       | 244         |
# |    total_timesteps    | 32500       |
# | train/                |             |
# |    entropy_loss       | -14.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6499        |
# |    policy_loss        | 40.7        |
# |    reward             | -0.35293815 |
# |    std                | 1.2         |
# |    value_loss         | 7.6         |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 133         |
# |    iterations         | 6600        |
# |    time_elapsed       | 247         |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | -7.82       |
# |    reward             | -0.47082487 |
# |    std                | 1.21        |
# |    value_loss         | 0.323       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 6700       |
# |    time_elapsed       | 251        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -3.47      |
# |    reward             | 0.22743696 |
# |    std                | 1.21       |
# |    value_loss         | 0.0631     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 6800       |
# |    time_elapsed       | 255        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -14.5      |
# |    explained_variance | 1.13e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | 18.5       |
# |    reward             | -0.4278716 |
# |    std                | 1.22       |
# |    value_loss         | 1.9        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 132         |
# |    iterations         | 6900        |
# |    time_elapsed       | 259         |
# |    total_timesteps    | 34500       |
# | train/                |             |
# |    entropy_loss       | -14.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6899        |
# |    policy_loss        | -18.1       |
# |    reward             | -0.29560244 |
# |    std                | 1.22        |
# |    value_loss         | 1.49        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7000       |
# |    time_elapsed       | 263        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 6.03       |
# |    reward             | 0.42797297 |
# |    std                | 1.23       |
# |    value_loss         | 0.186      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7100       |
# |    time_elapsed       | 267        |
# |    total_timesteps    | 35500      |
# | train/                |            |
# |    entropy_loss       | -14.6      |
# |    explained_variance | -6.78      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7099       |
# |    policy_loss        | 2.55       |
# |    reward             | 0.09683122 |
# |    std                | 1.23       |
# |    value_loss         | 0.0789     |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 132      |
# |    iterations         | 7200     |
# |    time_elapsed       | 271      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -14.7    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 1.79     |
# |    reward             | 0.0      |
# |    std                | 1.24     |
# |    value_loss         | 0.0219   |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7300       |
# |    time_elapsed       | 275        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -14.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | 6.11       |
# |    reward             | 0.06304429 |
# |    std                | 1.25       |
# |    value_loss         | 0.184      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7400       |
# |    time_elapsed       | 279        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -14.8      |
# |    explained_variance | 0.0188     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -9.47      |
# |    reward             | 0.36653763 |
# |    std                | 1.25       |
# |    value_loss         | 0.619      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7500       |
# |    time_elapsed       | 282        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -14.8      |
# |    explained_variance | -2.68      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | -5.55      |
# |    reward             | 0.26810217 |
# |    std                | 1.26       |
# |    value_loss         | 0.173      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 132         |
# |    iterations         | 7600        |
# |    time_elapsed       | 286         |
# |    total_timesteps    | 38000       |
# | train/                |             |
# |    entropy_loss       | -14.8       |
# |    explained_variance | -0.342      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7599        |
# |    policy_loss        | 3.16        |
# |    reward             | 0.102085926 |
# |    std                | 1.26        |
# |    value_loss         | 0.115       |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 132          |
# |    iterations         | 7700         |
# |    time_elapsed       | 290          |
# |    total_timesteps    | 38500        |
# | train/                |              |
# |    entropy_loss       | -14.8        |
# |    explained_variance | -0.261       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7699         |
# |    policy_loss        | 1.43         |
# |    reward             | -0.010419519 |
# |    std                | 1.26         |
# |    value_loss         | 0.0102       |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 132          |
# |    iterations         | 7800         |
# |    time_elapsed       | 294          |
# |    total_timesteps    | 39000        |
# | train/                |              |
# |    entropy_loss       | -14.9        |
# |    explained_variance | 0.256        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7799         |
# |    policy_loss        | 1.83         |
# |    reward             | -0.052500326 |
# |    std                | 1.27         |
# |    value_loss         | 0.0274       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 7900       |
# |    time_elapsed       | 298        |
# |    total_timesteps    | 39500      |
# | train/                |            |
# |    entropy_loss       | -14.9      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7899       |
# |    policy_loss        | -7.29      |
# |    reward             | 0.03570634 |
# |    std                | 1.28       |
# |    value_loss         | 0.208      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 132         |
# |    iterations         | 8000        |
# |    time_elapsed       | 302         |
# |    total_timesteps    | 40000       |
# | train/                |             |
# |    entropy_loss       | -14.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7999        |
# |    policy_loss        | -4.98       |
# |    reward             | -0.53246605 |
# |    std                | 1.27        |
# |    value_loss         | 0.123       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 132       |
# |    iterations         | 8100      |
# |    time_elapsed       | 306       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -15       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -9.49     |
# |    reward             | 0.6463862 |
# |    std                | 1.28      |
# |    value_loss         | 0.95      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 8200       |
# |    time_elapsed       | 310        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -15.1      |
# |    explained_variance | 0.0432     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | -49.3      |
# |    reward             | -1.0278805 |
# |    std                | 1.29       |
# |    value_loss         | 12.2       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 131          |
# |    iterations         | 8300         |
# |    time_elapsed       | 314          |
# |    total_timesteps    | 41500        |
# | train/                |              |
# |    entropy_loss       | -15          |
# |    explained_variance | -1.24        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8299         |
# |    policy_loss        | 1.15         |
# |    reward             | -0.092232995 |
# |    std                | 1.29         |
# |    value_loss         | 0.157        |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 131          |
# |    iterations         | 8400         |
# |    time_elapsed       | 318          |
# |    total_timesteps    | 42000        |
# | train/                |              |
# |    entropy_loss       | -15.1        |
# |    explained_variance | 0.455        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 8399         |
# |    policy_loss        | -3.28        |
# |    reward             | -0.058320772 |
# |    std                | 1.3          |
# |    value_loss         | 0.0605       |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 8500       |
# |    time_elapsed       | 322        |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -15.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | 2.06       |
# |    reward             | 0.19435874 |
# |    std                | 1.31       |
# |    value_loss         | 0.0377     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 8600       |
# |    time_elapsed       | 326        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -15.2      |
# |    explained_variance | 0.0484     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 1.22       |
# |    reward             | 0.37429276 |
# |    std                | 1.31       |
# |    value_loss         | 0.0361     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 8700       |
# |    time_elapsed       | 329        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -15.3      |
# |    explained_variance | 0.00475    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | -12.6      |
# |    reward             | 0.46502385 |
# |    std                | 1.33       |
# |    value_loss         | 0.916      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 8800       |
# |    time_elapsed       | 333        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -15.3      |
# |    explained_variance | 0.0659     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | 23         |
# |    reward             | 0.31314334 |
# |    std                | 1.33       |
# |    value_loss         | 2.41       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 8900      |
# |    time_elapsed       | 338       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -15.3     |
# |    explained_variance | 0.437     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 1.22      |
# |    reward             | 0.2520551 |
# |    std                | 1.33      |
# |    value_loss         | 0.0132    |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 9000        |
# |    time_elapsed       | 341         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -15.3       |
# |    explained_variance | -0.169      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 3.39        |
# |    reward             | -0.05547982 |
# |    std                | 1.34        |
# |    value_loss         | 0.0458      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 9100        |
# |    time_elapsed       | 345         |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -15.4       |
# |    explained_variance | 0.437       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | 3.08        |
# |    reward             | 0.039684635 |
# |    std                | 1.35        |
# |    value_loss         | 0.0365      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 9200       |
# |    time_elapsed       | 349        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -15.5      |
# |    explained_variance | 0.466      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | 5.29       |
# |    reward             | 0.17420843 |
# |    std                | 1.35       |
# |    value_loss         | 0.121      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 9300      |
# |    time_elapsed       | 353       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -15.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9299      |
# |    policy_loss        | 5.31      |
# |    reward             | 0.6132886 |
# |    std                | 1.36      |
# |    value_loss         | 0.184     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 9400      |
# |    time_elapsed       | 357       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -15.5     |
# |    explained_variance | 0.141     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9399      |
# |    policy_loss        | 10.1      |
# |    reward             | 0.8387826 |
# |    std                | 1.36      |
# |    value_loss         | 0.677     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 9500        |
# |    time_elapsed       | 361         |
# |    total_timesteps    | 47500       |
# | train/                |             |
# |    entropy_loss       | -15.5       |
# |    explained_variance | -0.6        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9499        |
# |    policy_loss        | 2.5         |
# |    reward             | 0.007161954 |
# |    std                | 1.36        |
# |    value_loss         | 0.0377      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 9600        |
# |    time_elapsed       | 365         |
# |    total_timesteps    | 48000       |
# | train/                |             |
# |    entropy_loss       | -15.6       |
# |    explained_variance | -0.0673     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9599        |
# |    policy_loss        | 2.52        |
# |    reward             | -0.27986297 |
# |    std                | 1.37        |
# |    value_loss         | 0.0663      |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 131         |
# |    iterations         | 9700        |
# |    time_elapsed       | 369         |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -15.6       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | -0.225      |
# |    reward             | -0.08059246 |
# |    std                | 1.38        |
# |    value_loss         | 0.0233      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 9800       |
# |    time_elapsed       | 373        |
# |    total_timesteps    | 49000      |
# | train/                |            |
# |    entropy_loss       | -15.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9799       |
# |    policy_loss        | -19.8      |
# |    reward             | -0.1531736 |
# |    std                | 1.38       |
# |    value_loss         | 1.56       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 131        |
# |    iterations         | 9900       |
# |    time_elapsed       | 377        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -15.7      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | -13.4      |
# |    reward             | -0.2756995 |
# |    std                | 1.38       |
# |    value_loss         | 0.837      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 131       |
# |    iterations         | 10000     |
# |    time_elapsed       | 381       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -15.7     |
# |    explained_variance | 0.0264    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 32.3      |
# |    reward             | -4.693988 |
# |    std                | 1.39      |
# |    value_loss         | 5.39      |
# -------------------------------------

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])


e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trained_model = trained_a2c
df_account_value_a2c, df_actions_a2c = DRLAgent.DRL_prediction(
    model=trained_model,
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value_a2c.shape
# Out:
# (399, 2)

# %%
df_result_a2c = df_account_value_a2c.set_index(df_account_value_a2c.columns[0])
df_account_value_a2c.to_csv("df_account_value_a2c.csv")
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)
stats = backtest_stats(df_dji_, value_col_name = 'close')
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value_a2c['date']
df_dji['account_value'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

result = pd.DataFrame(df_result_a2c)

"""result = pd.merge(df_result_a2c, df_result_ddpg, left_index=True, right_index=True)
result = pd.merge(result, df_result_td3, left_index=True, right_index=True)
result = pd.merge(result, df_result_ppo, left_index=True, right_index=True)
result = pd.merge(result, df_result_sac, left_index=True, right_index=True)
result = pd.merge(result, MVO_result, left_index=True, right_index=True)"""
result = pd.merge(result, df_dji, left_index=True, right_index=True)


result.columns = ['a2c','dji']

print("result: ", result)
result.to_csv("result.csv")
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (400, 8)
# Annual return         -0.022145
# Cumulative returns    -0.034921
# Annual volatility      0.176822
# Sharpe ratio          -0.038668
# Calmar ratio          -0.100930
# Stability              0.215672
# Max drawdown          -0.219408
# Omega ratio            0.993578
# Sortino ratio         -0.053987
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.003436
# Daily value at risk   -0.022305
# dtype: float64
# result:                       a2c           dji
# date
# 2021-10-01  1.000000e+06  1.000000e+06
# 2021-10-04  9.837809e+05  9.905746e+05
# 2021-10-05  9.896655e+05  9.996566e+05
# 2021-10-06  9.878612e+05  1.002637e+06
# 2021-10-07  1.000963e+06  1.012483e+06
# ...                  ...           ...
# 2023-04-27  1.063093e+06  9.854252e+05
# 2023-04-28  1.072166e+06  9.933491e+05
# 2023-05-01  1.077706e+06  9.919956e+05
# 2023-05-02  1.073049e+06  9.812993e+05
# 2023-05-03  1.071603e+06  9.734251e+05
#
# [399 rows x 2 columns]
# c:\Users\se99a\anaconda3\lib\site-packages\pyfolio\timeseries.py:724: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   stats = pd.Series()

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();

# %%
df_result_a2c.iloc[-1,0]
# Out:
# 1071603.2714578744

# %%
print('A2C로 얻은 투자 수익률>>', round((df_result_a2c.iloc[-1,0]/df_result_a2c.iloc[0,0]-1)*100,2),'%')
# Out:
# A2C로 얻은 투자 수익률>> 7.16 %

# %%
df_daily_return = df_account_value_a2c
df_daily_return
# Out:
#            date  account_value
# 0    2021-10-01   1.000000e+06
# 1    2021-10-04   9.837809e+05
# 2    2021-10-05   9.896655e+05
# 3    2021-10-06   9.878612e+05
# 4    2021-10-07   1.000963e+06
# ..          ...            ...
# 394  2023-04-27   1.063093e+06
# 395  2023-04-28   1.072166e+06
# 396  2023-05-01   1.077706e+06
# 397  2023-05-02   1.073049e+06
# 398  2023-05-03   1.071603e+06
#
# [399 rows x 2 columns]

# %%
df_actions_a2c
# Out:
#             XLB  XLE  XLF  XLI  XLK  XLP  XLU   XLV  XLY
# date
# 2021-10-01    0    0    1    0    0    0    0  8062    0
# 2021-10-04    0    0    0    0    0    0    0     0    0
# 2021-10-05    0    0    0    0    0    0    0     0    0
# 2021-10-06    0    0    0    0    0    0    0     0    0
# 2021-10-07    0    0    0    0    0    0    0     0    0
# ...         ...  ...  ...  ...  ...  ...  ...   ...  ...
# 2023-04-26    0    0    0    0    0    0    0     0    0
# 2023-04-27    0    0    0    0    0    0    0     0    0
# 2023-04-28    0    0    0    0    0    0    0     0    0
# 2023-05-01    0    0    0    0    0    0    0     0    0
# 2023-05-02    0    0    0    0    0    0    0     0    0
#
# [398 rows x 9 columns]
