# %%
# ## install finrl library
# !pip install wrds
# !pip install swig

# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (3.1.6)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds) (1.22.4)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds) (1.5.1)
# Requirement already satisfied: psycopg2-binary in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds) (2.9.5)
# Requirement already satisfied: scipy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds) (1.10.1)
# Requirement already satisfied: sqlalchemy<2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds) (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pandas->wrds) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->wrds) (1.15.0)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# Requirement already satisfied: swig in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.1.1)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\user\appdata\local\temp\pip-req-build-h3ug1lrf
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 34e2c921e573e1cf213f780f48b87a4499ad7fb4
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\user\appdata\local\temp\pip-install-eby4my_p\elegantrl_bbfdde5d15bd49249acdb458f7e09164
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit a1fb03d20f2cb2811514b88290b3b1c4d7c1a5a9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: alpaca-trade-api<4,>=3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (3.0.0)
# Requirement already satisfied: ccxt<4,>=3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (3.0.104)
# Requirement already satisfied: exchange-calendars<5,>=4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (4.2.7)
# Requirement already satisfied: jqdatasdk<2,>=1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (1.8.11)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (0.9.2)
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (1.5.5)
# Requirement already satisfied: ray[default,tune]<3,>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (2.5.1)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (1.2.1)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (2.0.0a5)
# Requirement already satisfied: stockstats<0.6,>=0.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (0.5.2)
# Requirement already satisfied: wrds<4,>=3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (3.1.6)
# Requirement already satisfied: yfinance<0.3,>=0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from finrl==0.3.6) (0.2.18)
# Requirement already satisfied: pandas>=0.18.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.1)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.22.4)
# Requirement already satisfied: requests<3,>2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.28.1)
# Requirement already satisfied: urllib3<2,>1.24 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.14)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.5.1)
# Requirement already satisfied: websockets<11,>=9.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: aiohttp==3.8.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.8.1)
# Requirement already satisfied: PyYAML==6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.0)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (65.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (2022.9.24)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (40.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: pyluach in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: python-dateutil in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: pytz in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2022.7.1)
# Requirement already satisfied: toolz in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: korean-lunar-calendar in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.15.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.4.46)
# Requirement already satisfied: thriftpy2>=0.3.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.16)
# Requirement already satisfied: pymysql>=0.7.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.0.2)
# Requirement already satisfied: ipython>=3.2.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.7.0)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.10.1)
# Requirement already satisfied: seaborn>=0.7.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Requirement already satisfied: empyrical>=0.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.3)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.12.0)
# Requirement already satisfied: jsonschema in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.17.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.19.6)
# Requirement already satisfied: grpcio<=1.51.3,>=1.42.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.51.3)
# Requirement already satisfied: aiohttp-cors in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: colorful in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.1)
# Requirement already satisfied: opencensus in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.2)
# Requirement already satisfied: pydantic in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.10.6)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.16.0)
# Requirement already satisfied: smart-open in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.3.0)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.21.0)
# Requirement already satisfied: tensorboardX>=1.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6)
# Requirement already satisfied: pyarrow<7.0.0,>=6.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.1.0)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.28.1)
# Requirement already satisfied: torch>=1.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: cloudpickle in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.13.0)
# Requirement already satisfied: psutil in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.4)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.64.1)
# Requirement already satisfied: rich in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.3.5)
# Requirement already satisfied: shimmy[atari]~=0.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.2.1)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (8.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: pygame in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: psycopg2-binary in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: gym in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.26.2)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.3.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.4)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from click>=7.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.15.1)
# Requirement already satisfied: osqp>=0.4.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.2.post9)
# Requirement already satisfied: ecos>=2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.3)
# Collecting setuptools>=60.9.0 (from ccxt<4,>=3->finrl==0.3.6)
#   Using cached setuptools-68.0.0-py3-none-any.whl (804 kB)
# Requirement already satisfied: pandas-datareader>=0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (11.495.46)
# Requirement already satisfied: blessed>=1.17.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.20.0)
# Requirement already satisfied: webencodings in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: backcall in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: decorator in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.3.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.40.0)
# Requirement already satisfied: ply<4.0,>=3.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=2.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: swig==4.* in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.19.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: importlib-resources in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.12.0)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.6)
# Requirement already satisfied: jinxed>=1.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: ansicon in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinxed>=1.1.0->blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.89.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed setuptools-68.0.0
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-h3ug1lrf'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\user\AppData\Local\Temp\pip-install-eby4my_p\elegantrl_bbfdde5d15bd49249acdb458f7e09164'
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)

# %%
# !pip install -r requirements.txt
# !pip install SQLAlchemy==1.4.46
# Out:
# Collecting finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72 (from -r requirements.txt (line 12))
#   Using cached finrl-0.3.5-py3-none-any.whl
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl@68bf0ea4ef3fb461026ece8897deabb92aeead32 (from -r requirements.txt (line 13))
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\user\appdata\local\temp\pip-install-lx9y4rcs\elegantrl_2b705d8bb6b24e5e892ef2607b69f17f
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit a1fb03d20f2cb2811514b88290b3b1c4d7c1a5a9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gym@ git+https://github.com/openai/gym.git@9180d12e1b66e7e2a1a622614f787a6ec147ac40 (from -r requirements.txt (line 28))
#   Using cached gym-0.21.0-py3-none-any.whl
# Requirement already satisfied: wrds==3.1.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 1)) (3.1.6)
# Collecting pandas==1.4.4 (from -r requirements.txt (line 2))
#   Using cached pandas-1.4.4-cp310-cp310-win_amd64.whl (10.0 MB)
# Requirement already satisfied: scipy==1.10.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: sqlalchemy==1.4.46 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 4)) (1.4.46)
# Requirement already satisfied: psycopg2-binary==2.9.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 5)) (2.9.5)
# Requirement already satisfied: numpy==1.22.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 6)) (1.22.4)
# Requirement already satisfied: greenlet==2.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 7)) (2.0.2)
# Requirement already satisfied: pytz==2022.7.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 8)) (2022.7.1)
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: six==1.15.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 10)) (1.15.0)
# Requirement already satisfied: swig==4.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 11)) (4.1.1)
# Requirement already satisfied: pyfolio==0.9.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 14)) (0.9.2)
# Collecting matplotlib==3.5.3 (from -r requirements.txt (line 15))
#   Using cached matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting exchange_calendars==3.6.3 (from -r requirements.txt (line 16))
#   Using cached exchange_calendars-3.6.3-py3-none-any.whl
# Collecting ray[default,tune]==2.3.0 (from -r requirements.txt (line 17))
#   Using cached ray-2.3.0-cp310-cp310-win_amd64.whl (21.7 MB)
# Collecting scikit-learn==1.2.2 (from -r requirements.txt (line 18))
#   Using cached scikit_learn-1.2.2-cp310-cp310-win_amd64.whl (8.3 MB)
# Collecting stable-baselines3==1.7.0 (from -r requirements.txt (line 19))
#   Using cached stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
# Requirement already satisfied: gputil==1.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 20)) (1.4.0)
# Requirement already satisfied: stockstats==0.5.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 21)) (0.5.2)
# Requirement already satisfied: jqdatasdk==1.8.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 22)) (1.8.11)
# Collecting ccxt==3.0.4 (from -r requirements.txt (line 23))
#   Using cached ccxt-3.0.4-py2.py3-none-any.whl (3.5 MB)
# Collecting yfinance==0.2.12 (from -r requirements.txt (line 24))
#   Using cached yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: tensorboardX==2.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 25)) (2.6)
# Requirement already satisfied: alpaca_trade_api==3.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 26)) (3.0.0)
# Collecting importlib-metadata==4.13.0 (from -r requirements.txt (line 27))
#   Using cached importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting lz4==4.3.2 (from -r requirements.txt (line 30))
#   Using cached lz4-4.3.2-cp310-cp310-win_amd64.whl (99 kB)
# Requirement already satisfied: pyluach==2.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 32)) (2.2.0)
# Requirement already satisfied: korean-lunar-calendar==0.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 33)) (0.3.1)
# Requirement already satisfied: toolz==0.12.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 34)) (0.12.0)
# Requirement already satisfied: zipp==3.15.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 37)) (3.15.0)
# Requirement already satisfied: urllib3==1.26.14 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 38)) (1.26.14)
# Requirement already satisfied: msgpack==1.0.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 39)) (1.0.3)
# Collecting requests==2.28.2 (from -r requirements.txt (line 40))
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Requirement already satisfied: deprecation==2.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 41)) (2.1.0)
# Requirement already satisfied: websockets==10.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 42)) (10.4)
# Requirement already satisfied: aiohttp==3.8.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 43)) (3.8.1)
# Requirement already satisfied: PyYAML==6.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 44)) (6.0)
# Requirement already satisfied: websocket-client==1.5.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 45)) (1.5.1)
# Requirement already satisfied: async-timeout==4.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 46)) (4.0.2)
# Requirement already satisfied: aiosignal==1.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 47)) (1.3.1)
# Collecting attrs==22.2.0 (from -r requirements.txt (line 48))
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Requirement already satisfied: multidict==6.0.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 49)) (6.0.4)
# Collecting yarl==1.8.2 (from -r requirements.txt (line 50))
#   Using cached yarl-1.8.2-cp310-cp310-win_amd64.whl (56 kB)
# Requirement already satisfied: frozenlist==1.3.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 51)) (1.3.3)
# Requirement already satisfied: charset-normalizer==2.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 52)) (2.1.1)
# Requirement already satisfied: packaging==23.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 53)) (23.0)
# Collecting setuptools==65.5.0 (from -r requirements.txt (line 54))
#   Using cached setuptools-65.5.0-py3-none-any.whl (1.2 MB)
# Collecting cryptography==39.0.2 (from -r requirements.txt (line 55))
#   Using cached cryptography-39.0.2-cp36-abi3-win_amd64.whl (2.5 MB)
# Collecting certifi==2022.12.7 (from -r requirements.txt (line 56))
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Requirement already satisfied: aiodns==3.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 57)) (3.0.0)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 58)) (2.2.1)
# Requirement already satisfied: virtualenv==20.21.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 59)) (20.21.0)
# Collecting filelock==3.9.0 (from -r requirements.txt (line 61))
#   Using cached filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: protobuf==3.19.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 62)) (3.19.6)
# Collecting jsonschema==4.3.3 (from -r requirements.txt (line 63))
#   Using cached jsonschema-4.3.3-py3-none-any.whl (71 kB)
# Requirement already satisfied: click==8.1.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 64)) (8.1.3)
# Requirement already satisfied: tabulate==0.8.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 65)) (0.8.10)
# Requirement already satisfied: smart-open==6.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 66)) (6.3.0)
# Requirement already satisfied: pydantic==1.10.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 67)) (1.10.6)
# Requirement already satisfied: opencensus==0.11.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 68)) (0.11.2)
# Requirement already satisfied: py-spy==0.3.14 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 69)) (0.3.14)
# Requirement already satisfied: aiohttp-cors==0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 70)) (0.7.0)
# Requirement already satisfied: prometheus-client==0.16.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 71)) (0.16.0)
# Collecting gpustat==1.0.0 (from -r requirements.txt (line 72))
#   Using cached gpustat-1.0.0-py3-none-any.whl
# Requirement already satisfied: colorful==0.5.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 73)) (0.5.5)
# Requirement already satisfied: threadpoolctl==3.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 74)) (3.1.0)
# Collecting joblib==1.1.1 (from -r requirements.txt (line 75))
#   Using cached joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Requirement already satisfied: torch==1.13.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 77)) (1.13.1)
# Requirement already satisfied: pymysql==1.0.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 78)) (1.0.2)
# Requirement already satisfied: thriftpy2==0.4.16 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 81)) (0.4.16)
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 82)) (1.4.4)
# Requirement already satisfied: pillow==8.4.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 83)) (8.4.0)
# Collecting fonttools==4.39.0 (from -r requirements.txt (line 84))
#   Using cached fonttools-4.39.0-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: cycler==0.11.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 85)) (0.11.0)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 86)) (3.0.9)
# Collecting ipython==7.9.0 (from -r requirements.txt (line 87))
#   Using cached ipython-7.9.0-py3-none-any.whl (775 kB)
# Collecting seaborn==0.11.2 (from -r requirements.txt (line 88))
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: empyrical==0.5.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 89)) (0.5.5)
# Requirement already satisfied: multitasking==0.0.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 90)) (0.0.11)
# Requirement already satisfied: appdirs==1.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 91)) (1.4.4)
# Collecting beautifulsoup4==4.11.2 (from -r requirements.txt (line 92))
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Collecting frozendict==2.3.5 (from -r requirements.txt (line 93))
#   Using cached frozendict-2.3.5-cp310-cp310-win_amd64.whl (35 kB)
# Requirement already satisfied: html5lib==1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 94)) (1.1)
# Requirement already satisfied: lxml==4.9.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 95)) (4.9.2)
# Requirement already satisfied: pycares==4.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 96)) (4.3.0)
# Requirement already satisfied: soupsieve==2.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 97)) (2.4)
# Requirement already satisfied: cffi==1.15.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 98)) (1.15.1)
# Requirement already satisfied: pandas-datareader==0.10.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 99)) (0.10.0)
# Requirement already satisfied: nvidia-ml-py==11.495.46 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 100)) (11.495.46)
# Requirement already satisfied: psutil==5.9.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 101)) (5.9.4)
# Requirement already satisfied: blessed==1.20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 102)) (1.20.0)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 103)) (0.5.1)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 104)) (0.7.5)
# Collecting prompt-toolkit==2.0.10 (from -r requirements.txt (line 105))
#   Using cached prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
# Requirement already satisfied: backcall==0.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 106)) (0.2.0)
# Requirement already satisfied: pexpect==4.8.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 107)) (4.8.0)
# Requirement already satisfied: jedi==0.18.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 108)) (0.18.2)
# Requirement already satisfied: traitlets==5.7.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 109)) (5.7.1)
# Collecting decorator==4.4.2 (from -r requirements.txt (line 110))
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting pygments==2.6.1 (from -r requirements.txt (line 111))
#   Using cached Pygments-2.6.1-py3-none-any.whl (914 kB)
# Collecting idna==2.10 (from -r requirements.txt (line 112))
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: ply==3.11 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 114)) (3.11)
# Requirement already satisfied: typing-extensions==4.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 115)) (4.5.0)
# Requirement already satisfied: distlib==0.3.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 116)) (0.3.6)
# Requirement already satisfied: platformdirs==3.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 117)) (3.1.0)
# Requirement already satisfied: pyglet==2.0.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 118)) (2.0.5)
# Requirement already satisfied: box2d-py==2.3.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 119)) (2.3.5)
# Requirement already satisfied: pyrsistent==0.19.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 120)) (0.19.3)
# Requirement already satisfied: opencensus-context==0.1.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 121)) (0.1.3)
# Requirement already satisfied: google-api-core==2.11.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 122)) (2.11.0)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 123)) (0.2.6)
# Requirement already satisfied: pycparser==2.21 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 124)) (2.21)
# Collecting googleapis-common-protos==1.58.0 (from -r requirements.txt (line 125))
#   Using cached googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# Collecting google-auth==2.16.2 (from -r requirements.txt (line 126))
#   Using cached google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
# Requirement already satisfied: parso==0.8.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 127)) (0.8.3)
# Requirement already satisfied: ptyprocess==0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 128)) (0.7.0)
# Requirement already satisfied: cachetools==5.3.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 129)) (5.3.0)
# Requirement already satisfied: pyasn1-modules==0.2.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 130)) (0.2.8)
# Requirement already satisfied: rsa==4.9 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 131)) (4.9)
# Requirement already satisfied: pyasn1==0.4.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 132)) (0.4.8)
# Requirement already satisfied: tensorboard in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 134)) (2.13.0)
# Requirement already satisfied: grpcio>=1.42.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ray[default,tune]==2.3.0->-r requirements.txt (line 17)) (1.51.3)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from click==8.1.3->-r requirements.txt (line 64)) (0.4.6)
# Requirement already satisfied: jinxed>=1.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from blessed==1.20.0->-r requirements.txt (line 102)) (1.2.0)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72->-r requirements.txt (line 12))
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\user\appdata\local\temp\pip-install-lx9y4rcs\elegantrl_9133d97e386c4b69ae110a084b06abc3
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit a1fb03d20f2cb2811514b88290b3b1c4d7c1a5a9
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2 (from finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72->-r requirements.txt (line 12))
#   Cloning https://github.com/quantopian/pyfolio.git to c:\users\user\appdata\local\temp\pip-install-lx9y4rcs\pyfolio_329304674ebb4c5c8ebdce748d987484
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (2.3.4)
# Requirement already satisfied: wheel>=0.26 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (0.40.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 134)) (1.3.1)
# Requirement already satisfied: ansicon in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jinxed>=1.1.0->blessed==1.20.0->-r requirements.txt (line 102)) (1.89.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 134)) (2.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 134)) (3.2.2)
# Building wheels for collected packages: pyfolio
#   Building wheel for pyfolio (setup.py): started
#   Building wheel for pyfolio (setup.py): finished with status 'done'
#   Created wheel for pyfolio: filename=pyfolio-0.9.2+75.g4b901f6-py3-none-any.whl size=76272 sha256=9442fb0d09cf09f62f728ddbea8f45f6485b232c3bad82f7faee827ab553c1e0
#   Stored in directory: C:\Users\user\AppData\Local\Temp\pip-ephem-wheel-cache-47fsvne5\wheels\c4\1d\91\8ab5d1c88a11b06a63dcd6a69ea81547e2247123232949bb26
# Successfully built pyfolio
# Installing collected packages: setuptools, pygments, prompt-toolkit, lz4, joblib, importlib-metadata, idna, gym, googleapis-common-protos, frozendict, fonttools, filelock, decorator, certifi, beautifulsoup4, attrs, yarl, scikit-learn, requests, pandas, matplotlib, jsonschema, ipython, google-auth, cryptography, yfinance, stable-baselines3, seaborn, ray, gpustat, exchange_calendars, ccxt, pyfolio, finrl
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.0.0
#     Uninstalling setuptools-68.0.0:
#       Successfully uninstalled setuptools-68.0.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.15.1
#     Uninstalling Pygments-2.15.1:
#       Successfully uninstalled Pygments-2.15.1
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.2.0
#     Uninstalling joblib-1.2.0:
#       Successfully uninstalled joblib-1.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: gym
#     Found existing installation: gym 0.26.2
#     Uninstalling gym-0.26.2:
#       Successfully uninstalled gym-0.26.2
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.59.0
#     Uninstalling googleapis-common-protos-1.59.0:
#       Successfully uninstalled googleapis-common-protos-1.59.0
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.3.8
#     Uninstalling frozendict-2.3.8:
#       Successfully uninstalled frozendict-2.3.8
# DEPRECATION: git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl@68bf0ea4ef3fb461026ece8897deabb92aeead32 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\user\AppData\Local\Temp\pip-install-lx9y4rcs\elegantrl_2b705d8bb6b24e5e892ef2607b69f17f'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\user\AppData\Local\Temp\pip-install-lx9y4rcs\elegantrl_9133d97e386c4b69ae110a084b06abc3'
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git 'C:\Users\user\AppData\Local\Temp\pip-install-lx9y4rcs\pyfolio_329304674ebb4c5c8ebdce748d987484'
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\~rozendict\\_frozendict.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: SQLAlchemy==1.4.46 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy==1.4.46) (2.0.2)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
# instantiate train/test date
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TRADE_START_DATE = '2021-10-01'
TRADE_END_DATE = '2023-05-03'

# %%
print(TEST_START_DATE,TEST_END_DATE)
# Out:
# 2020-08-01 2021-10-01

# %%
# preprocess 
import yfinance as yf

ticker = ['XLB','XLE','XLF','XLI','XLK','XLP','XLU','XLV','XLY']
stocks = yf.download(ticker, start = TRAIN_START_DATE, end = TRADE_END_DATE )

df =  YahooDownloader(start_date = TRAIN_START_DATE,
                      end_date = TRADE_END_DATE,
                      ticker_list = ticker).fetch_data()
# Out:
# [*********************100%***********************]  9 of 9 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (30195, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close    volume  tic  day
# 0  2010-01-04  33.580002  34.020000  33.450001  25.364521   7567500  XLB    0
# 1  2010-01-04  57.919998  58.810001  57.790001  37.747688  16928400  XLE    0
# 2  2010-01-04  11.795288  11.965881  11.770918   9.344017  92942347  XLF    0
# 3  2010-01-04  28.090000  28.320000  27.959999  21.793047   7471500  XLI    0
# 4  2010-01-04  23.139999  23.290001  23.100000  19.110197   8449400  XLK    0

# %%
fe = FeatureEngineer(
    use_technical_indicator = True,
    tech_indicator_list = INDICATORS,
    use_vix=True,
    use_turbulence=True,
    user_defined_feature=False
)
processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3354, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
processed.head()
# Out:
#          date       open       high        low      close    volume  tic  day  \
# 0  2010-01-04  33.580002  34.020000  33.450001  25.364521   7567500  XLB    0
# 1  2010-01-04  57.919998  58.810001  57.790001  37.747688  16928400  XLE    0
# 2  2010-01-04  11.795288  11.965881  11.770918   9.344017  92942347  XLF    0
# 3  2010-01-04  28.090000  28.320000  27.959999  21.793047   7471500  XLI    0
# 4  2010-01-04  23.139999  23.290001  23.100000  19.110197   8449400  XLK    0
#
#    macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0   0.0  25.521513  25.289543   100.0  66.666667  100.0     25.364521
# 1   0.0  25.521513  25.289543   100.0  66.666667  100.0     37.747688
# 2   0.0  25.521513  25.289543   100.0  66.666667  100.0      9.344017
# 3   0.0  25.521513  25.289543   100.0  66.666667  100.0     21.793047
# 4   0.0  25.521513  25.289543   100.0  66.666667  100.0     19.110197
#
#    close_60_sma        vix  turbulence
# 0     25.364521  20.040001         0.0
# 1     37.747688  20.040001         0.0
# 2      9.344017  20.040001         0.0
# 3     21.793047  20.040001         0.0
# 4     19.110197  20.040001         0.0

# %%
list_ticker = processed["tic"].unique().tolist() # ticker list
list_date = list(pd.date_range(processed['date'].min(), processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

process_full = pd.DataFrame(combination, columns=['date','tic']).merge(processed, on=['date','tic'],how='left')
process_full = process_full[process_full['date'].isin(processed['date'])]
process_full = process_full.sort_values(['date','tic'])

process_full = process_full.fillna(0)

mvo_df = process_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
mvo_df.head(10) # 종가만
# Out:
#          date  tic      close
# 0  2010-01-04  XLB  25.364521
# 1  2010-01-04  XLE  37.747688
# 2  2010-01-04  XLF   9.344017
# 3  2010-01-04  XLI  21.793047
# 4  2010-01-04  XLK  19.110197
# 5  2010-01-04  XLP  18.586605
# 6  2010-01-04  XLU  19.326471
# 7  2010-01-04  XLV  25.110271
# 8  2010-01-04  XLY  25.176529
# 9  2010-01-05  XLB  25.446535

# %%
process_full.head()
# Out:
#          date  tic       open       high        low      close      volume  \
# 0  2010-01-04  XLB  33.580002  34.020000  33.450001  25.364521   7567500.0
# 1  2010-01-04  XLE  57.919998  58.810001  57.790001  37.747688  16928400.0
# 2  2010-01-04  XLF  11.795288  11.965881  11.770918   9.344017  92942347.0
# 3  2010-01-04  XLI  28.090000  28.320000  27.959999  21.793047   7471500.0
# 4  2010-01-04  XLK  23.139999  23.290001  23.100000  19.110197   8449400.0
#
#    day  macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  0.0   0.0  25.521513  25.289543   100.0  66.666667  100.0     25.364521
# 1  0.0   0.0  25.521513  25.289543   100.0  66.666667  100.0     37.747688
# 2  0.0   0.0  25.521513  25.289543   100.0  66.666667  100.0      9.344017
# 3  0.0   0.0  25.521513  25.289543   100.0  66.666667  100.0     21.793047
# 4  0.0   0.0  25.521513  25.289543   100.0  66.666667  100.0     19.110197
#
#    close_60_sma        vix  turbulence
# 0     25.364521  20.040001         0.0
# 1     37.747688  20.040001         0.0
# 2      9.344017  20.040001         0.0
# 3     21.793047  20.040001         0.0
# 4     19.110197  20.040001         0.0

# %%
# data split
train = data_split(process_full, TRAIN_START_DATE, TRAIN_END_DATE)
trade = data_split(process_full, TRADE_START_DATE, TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 26613
# 3573

# %% [markdown]
# # Env

# %% [markdown]
# ## Overview
#
# State Space = [p,h,b]. stock price p, stock shares h, remaining balance b
#
# Action Space = [sell, buy] (hold action realized by remaining balance )
#
# Reward : Change of pf value (depending on a,s,s')
#
# Policy
#
# Value function
#
# Action function
#
# Reward Hypothesis? Maximize pf value

# %% [markdown]
# ## Env Setting
#
# State Space : 8(INDICATORS) * 9(NUMBER of stocks) + 2(stock price p, stock shares h) * 9(NUMBER of stocks) + 1(remaining balance b)
#
# 1. Balance b : 현금계좌 잔고
#
# 2. Stock price : p
#
# 3. Shares : 보유량
#
# ---
#
# 4. MACD : SMA - LMA, signal = rolling by k days (closed price)
#
# 5. CCI : 주가가 MA에서 얼마나 떨어져 있는지 (과매수, 과매도 측정)
#
# 6. ADX : 추세의 강도를 측정
#
# 7. RSI
#
# 8. Bollinger band
#
# Action Space : (2k+1)^9, k <= h_max (h_max는 사용자 설정 hp)
#
# {-k,...,-1,0,1,...,k}
#
# hmax : 한번에 살수있는 주식의 최대 share

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}
# Out:
# Stock Dimension: 9, State Space: 91

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

TD3_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }
SAC_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 100_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000,
                 'td3' : 10_000,
                 'sac' : 10_000
                 }

# %%
# DRL models from Stable Baselines 3
from __future__ import annotations

import time

import numpy as np
import pandas as pd
from stable_baselines3 import A2C
from stable_baselines3 import DDPG
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import TD3
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.noise import OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.vec_env import DummyVecEnv

from finrl import config
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.preprocessor.preprocessors import data_split

MODELS = {"a2c": A2C, "ddpg": DDPG, "td3": TD3, "sac": SAC, "ppo": PPO}

MODEL_KWARGS = {x: config.__dict__[f"{x.upper()}_PARAMS"] for x in MODELS.keys()}

NOISE = {
    "normal": NormalActionNoise,
    "ornstein_uhlenbeck": OrnsteinUhlenbeckActionNoise,
}


class TensorboardCallback(BaseCallback):
    """
    Custom callback for plotting additional values in tensorboard.
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self) -> bool:
        try:
            self.logger.record(key="train/reward", value=self.locals["rewards"][0])
        except BaseException:
            self.logger.record(key="train/reward", value=self.locals["reward"][0])
        return True


class DRLAgent:
    """Provides implementations for DRL algorithms

    Attributes
    ----------
        env: gym environment class
            user-defined class

    Methods
    -------
        get_model()
            setup DRL algorithms
        train_model()
            train DRL algorithms in a train dataset
            and output the trained model
        DRL_prediction()
            make a prediction in a test dataset and get results
    """

    def __init__(self, env):
        self.env = env

    def get_model(
        self,
        model_name,
        policy="MlpPolicy",
        policy_kwargs=None,
        model_kwargs=None,
        verbose=1,
        seed=None,
        tensorboard_log=None,
    ):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")

        if model_kwargs is None:
            model_kwargs = MODEL_KWARGS[model_name]

        if "action_noise" in model_kwargs:
            n_actions = self.env.action_space.shape[-1]
            model_kwargs["action_noise"] = NOISE[model_kwargs["action_noise"]](
                mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions)
            )
        print(model_kwargs)
        return MODELS[model_name](
            policy=policy,
            env=self.env,
            tensorboard_log=tensorboard_log,
            verbose=verbose,
            policy_kwargs=policy_kwargs,
            seed=seed,
            **model_kwargs,
        )

    def train_model(self, model, tb_log_name, total_timesteps=5000):
        model = model.learn(
            total_timesteps=total_timesteps,
            tb_log_name=tb_log_name,
            callback=TensorboardCallback(),
        )
        return model

    @staticmethod
    def DRL_prediction(model, environment, deterministic=True):
        test_env, test_obs = environment.get_sb_env()
        """make a prediction"""
        account_memory = []
        actions_memory = []
        #         state_memory=[] #add memory pool to store states
        test_env.reset()
        for i in range(len(environment.df.index.unique())):
            action, _states = model.predict(test_obs, deterministic=deterministic)
            # account_memory = test_env.env_method(method_name="save_asset_memory")
            # actions_memory = test_env.env_method(method_name="save_action_memory")
            test_obs, rewards, dones, info = test_env.step(action)
            if i == (len(environment.df.index.unique()) - 2):
                account_memory = test_env.env_method(method_name="save_asset_memory")
                actions_memory = test_env.env_method(method_name="save_action_memory")
            #                 state_memory=test_env.env_method(method_name="save_state_memory") # add current state to state memory
            if dones[0]:
                print("hit end!")
                break
        return account_memory[0], actions_memory[0]

    @staticmethod
    def DRL_prediction_load_from_file(model_name, environment, cwd, deterministic=True):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")
        try:
            # load agent
            model = MODELS[model_name].load(cwd)
            print("Successfully load model", cwd)
        except BaseException:
            raise ValueError("Fail to load agent!")

        # test on the testing env
        state = environment.reset()
        episode_returns = []  # the cumulative_return / initial_account
        episode_total_assets = [environment.initial_total_asset]
        done = False
        while not done:
            action = model.predict(state, deterministic=deterministic)[0]
            state, reward, done, _ = environment.step(action)

            total_asset = (
                environment.amount
                + (environment.price_ary[environment.day] * environment.stocks).sum()
            )
            episode_total_assets.append(total_asset)
            episode_return = total_asset / environment.initial_total_asset
            episode_returns.append(episode_return)

        print("episode_return", episode_return)
        print("Test Finished!")
        return episode_total_assets


class DRLEnsembleAgent:
    @staticmethod
    def get_model(
        model_name,
        env,
        policy="MlpPolicy",
        policy_kwargs=None,
        model_kwargs=None,
        seed=None,
        verbose=1,
    ):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")

        if model_kwargs is None:
            temp_model_kwargs = MODEL_KWARGS[model_name]
        else:
            temp_model_kwargs = model_kwargs.copy()

        if "action_noise" in temp_model_kwargs:
            n_actions = env.action_space.shape[-1]
            temp_model_kwargs["action_noise"] = NOISE[
                temp_model_kwargs["action_noise"]
            ](mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
        print(temp_model_kwargs)
        return MODELS[model_name](
            policy=policy,
            env=env,
            tensorboard_log=f"{config.TENSORBOARD_LOG_DIR}/{model_name}",
            verbose=verbose,
            policy_kwargs=policy_kwargs,
            seed=seed,
            **temp_model_kwargs,
        )

    @staticmethod
    def train_model(model, model_name, tb_log_name, iter_num, total_timesteps=5000):
        model = model.learn(
            total_timesteps=total_timesteps,
            tb_log_name=tb_log_name,
            callback=TensorboardCallback(),
        )
        model.save(
            f"{config.TRAINED_MODEL_DIR}/{model_name.upper()}_{total_timesteps // 1000}k_{iter_num}"
        )
        return model

    @staticmethod
    def get_validation_sharpe(iteration, model_name):
        """Calculate Sharpe ratio based on validation results"""
        df_total_value = pd.read_csv(
            f"results/account_value_validation_{model_name}_{iteration}.csv"
        )
        # If the agent did not make any transaction
        if df_total_value["daily_return"].var() == 0:
            if df_total_value["daily_return"].mean() > 0:
                return np.inf
            else:
                return 0.0
        else:
            return (
                (4**0.5)
                * df_total_value["daily_return"].mean()
                / df_total_value["daily_return"].std()
            )

    def __init__(
        self,
        df,
        train_period,
        val_test_period,
        rebalance_window,
        validation_window,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        print_verbosity,
    ):
        self.df = df
        self.train_period = train_period
        self.val_test_period = val_test_period

        self.unique_trade_date = df[
            (df.date > val_test_period[0]) & (df.date <= val_test_period[1])
        ].date.unique()
        self.rebalance_window = rebalance_window
        self.validation_window = validation_window

        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.print_verbosity = print_verbosity

    def DRL_validation(self, model, test_data, test_env, test_obs):
        """validation process"""
        for _ in range(len(test_data.index.unique())):
            action, _states = model.predict(test_obs)
            test_obs, rewards, dones, info = test_env.step(action)

    def DRL_prediction(
        self, model, name, last_state, iter_num, turbulence_threshold, initial
    ):
        """make a prediction based on trained model"""

        ## trading env
        trade_data = data_split(
            self.df,
            start=self.unique_trade_date[iter_num - self.rebalance_window],
            end=self.unique_trade_date[iter_num],
        )
        trade_env = DummyVecEnv(
            [
                lambda: StockTradingEnv(
                    df=trade_data,
                    stock_dim=self.stock_dim,
                    hmax=self.hmax,
                    initial_amount=self.initial_amount,
                    num_stock_shares=[0] * self.stock_dim,
                    buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                    sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                    reward_scaling=self.reward_scaling,
                    state_space=self.state_space,
                    action_space=self.action_space,
                    tech_indicator_list=self.tech_indicator_list,
                    turbulence_threshold=turbulence_threshold,
                    initial=initial,
                    previous_state=last_state,
                    model_name=name,
                    mode="trade",
                    iteration=iter_num,
                    print_verbosity=self.print_verbosity,
                )
            ]
        )

        trade_obs = trade_env.reset()

        for i in range(len(trade_data.index.unique())):
            action, _states = model.predict(trade_obs)
            trade_obs, rewards, dones, info = trade_env.step(action)
            if i == (len(trade_data.index.unique()) - 2):
                # print(env_test.render())
                last_state = trade_env.envs[0].render()

        df_last_state = pd.DataFrame({"last_state": last_state})
        # 수정(06/28): run_ensemble_strategy 실행시 ValueError: If using all scalar values, you must pass an index 오류 출력됨.
        # 수정: df_last_state가 run_ensemble_strategy를 시행하는데 있어서 쓰이지 않음. 따라서 제거해주고 시행해봄. 그 결과 동일한 오류 발생
        df_last_state.to_csv(f"results/last_state_{name}_{i}.csv", index=False)
        # 수정 : 다시 풀어줌. requirements.txt issue인게 밝혀짐.
        # 수정 : last_state = trade_env.render() --> trade_env.evns[0].render() 로 바꿔줌
        return last_state

    def run_ensemble_strategy_(
        self, A2C_model_kwargs, PPO_model_kwargs, DDPG_model_kwargs, TD3_model_kwargs, SAC_model_kwargs, timesteps_dict
    ):
        """Ensemble Strategy that combines PPO, A2C and DDPG"""
        print("============Start Ensemble Strategy============")
        # for ensemble model, it's necessary to feed the last state
        # of the previous model to the current model as the initial state
        last_state_ensemble = []

        ppo_sharpe_list = []
        ddpg_sharpe_list = []
        a2c_sharpe_list = []
        td3_sharpe_list = []
        sac_sharpe_list = []

        model_use = []
        validation_start_date_list = []
        validation_end_date_list = []
        iteration_list = []

        insample_turbulence = self.df[
            (self.df.date < self.train_period[1])
            & (self.df.date >= self.train_period[0])
        ]
        insample_turbulence_threshold = np.quantile(
            insample_turbulence.turbulence.values, 0.90
        )

        start = time.time()
        for i in range(
            self.rebalance_window + self.validation_window,
            len(self.unique_trade_date),
            self.rebalance_window,
        ):
            validation_start_date = self.unique_trade_date[
                i - self.rebalance_window - self.validation_window
            ]
            validation_end_date = self.unique_trade_date[i - self.rebalance_window]

            validation_start_date_list.append(validation_start_date)
            validation_end_date_list.append(validation_end_date)
            iteration_list.append(i)

            print("============================================")
            ## initial state is empty
            if i - self.rebalance_window - self.validation_window == 0:
                # inital state
                initial = True
            else:
                # previous state
                initial = False

            # Tuning trubulence index based on historical data
            # Turbulence lookback window is one quarter (63 days)
            end_date_index = self.df.index[
                self.df["date"]
                == self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ]
            ].to_list()[-1]
            start_date_index = end_date_index - 63 + 1

            historical_turbulence = self.df.iloc[
                start_date_index : (end_date_index + 1), :
            ]

            historical_turbulence = historical_turbulence.drop_duplicates(
                subset=["date"]
            )

            historical_turbulence_mean = np.mean(
                historical_turbulence.turbulence.values
            )

            # print(historical_turbulence_mean)

            if historical_turbulence_mean > insample_turbulence_threshold:
                # if the mean of the historical data is greater than the 90% quantile of insample turbulence data
                # then we assume that the current market is volatile,
                # therefore we set the 90% quantile of insample turbulence data as the turbulence threshold
                # meaning the current turbulence can't exceed the 90% quantile of insample turbulence data
                turbulence_threshold = insample_turbulence_threshold
            else:
                # if the mean of the historical data is less than the 90% quantile of insample turbulence data
                # then we tune up the turbulence_threshold, meaning we lower the risk
                turbulence_threshold = np.quantile(
                    insample_turbulence.turbulence.values, 1
                )

            turbulence_threshold = np.quantile(
                insample_turbulence.turbulence.values, 0.99
            )
            print("turbulence_threshold: ", turbulence_threshold)

            ############## Environment Setup starts ##############
            ## training env
            train = data_split(
                self.df,
                start=self.train_period[0],
                end=self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
            )
            self.train_env = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=train,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )

            validation = data_split(
                self.df,
                start=self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
                end=self.unique_trade_date[i - self.rebalance_window],
            )
            ############## Environment Setup ends ##############

            ############## Training and Validation starts ##############
            print(
                "======Model training from: ",
                self.train_period[0],
                "to ",
                self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
            )
            # print("training: ",len(data_split(df, start=20090000, end=test.datadate.unique()[i-rebalance_window]) ))
            # print("==============Model Training===========")
            print("======A2C Training========")
            model_a2c = self.get_model(
                "a2c", self.train_env, policy="MlpPolicy", model_kwargs=A2C_model_kwargs
            )
            model_a2c = self.train_model(
                model_a2c,
                "a2c",
                tb_log_name=f"a2c_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["a2c"],
            )  # 100_000

            print(
                "======A2C Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_a2c = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="A2C",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_a2c = val_env_a2c.reset()
            self.DRL_validation(
                model=model_a2c,
                test_data=validation,
                test_env=val_env_a2c,
                test_obs=val_obs_a2c,
            )
            sharpe_a2c = self.get_validation_sharpe(i, model_name="A2C")
            print("A2C Sharpe Ratio: ", sharpe_a2c)

            print("======PPO Training========")
            model_ppo = self.get_model(
                "ppo", self.train_env, policy="MlpPolicy", model_kwargs=PPO_model_kwargs
            )
            model_ppo = self.train_model(
                model_ppo,
                "ppo",
                tb_log_name=f"ppo_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["ppo"],
            )  # 100_000
            print(
                "======PPO Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_ppo = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="PPO",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_ppo = val_env_ppo.reset()
            self.DRL_validation(
                model=model_ppo,
                test_data=validation,
                test_env=val_env_ppo,
                test_obs=val_obs_ppo,
            )
            sharpe_ppo = self.get_validation_sharpe(i, model_name="PPO")
            print("PPO Sharpe Ratio: ", sharpe_ppo)

            print("======DDPG Training========")
            model_ddpg = self.get_model(
                "ddpg",
                self.train_env,
                policy="MlpPolicy",
                model_kwargs=DDPG_model_kwargs,
            )
            model_ddpg = self.train_model(
                model_ddpg,
                "ddpg",
                tb_log_name=f"ddpg_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["ddpg"],
            )  # 50_000
            print(
                "======DDPG Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_ddpg = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="DDPG",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_ddpg = val_env_ddpg.reset()
            self.DRL_validation(
                model=model_ddpg,
                test_data=validation,
                test_env=val_env_ddpg,
                test_obs=val_obs_ddpg,
            )
            sharpe_ddpg = self.get_validation_sharpe(i, model_name="DDPG")

            print("======SAC Training========")
            model_sac = self.get_model(
                "sac", self.train_env, policy="MlpPolicy", model_kwargs=SAC_model_kwargs
            )
            model_sac = self.train_model(
                model_sac,
                "sac",
                tb_log_name=f"sac_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["sac"],
                # 100_000
            )

            print(
                "======SAC Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_sac = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="SAC",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_sac = val_env_sac.reset()
            self.DRL_validation(
                model=model_sac,
                test_data=validation,
                test_env=val_env_sac,
                test_obs=val_obs_sac,
            )
            sharpe_sac = self.get_validation_sharpe(i, model_name="SAC")
            print("SAC Sharpe Ratio : ", sharpe_sac)

            print("======TD3 Training========")
            model_td3 = self.get_model(
                "td3", self.train_env, policy="MlpPolicy", model_kwargs=TD3_model_kwargs
            )
            model_td3 = self.train_model(
                model_td3,
                "td3",
                tb_log_name=f"td3_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["td3"],
                # 100_000
            )

            print(
                "======TD3 Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_td3 = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="TD3",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_td3 = val_env_td3.reset()
            self.DRL_validation(
                model=model_td3,
                test_data=validation,
                test_env=val_env_td3,
                test_obs=val_obs_td3,
            )
            sharpe_td3 = self.get_validation_sharpe(i, model_name="TD3")
            print("TD3 Sharpe Ratio : ", sharpe_td3)

            ppo_sharpe_list.append(sharpe_ppo)
            a2c_sharpe_list.append(sharpe_a2c)
            ddpg_sharpe_list.append(sharpe_ddpg)
            sac_sharpe_list.append(sharpe_sac)
            td3_sharpe_list.append(sharpe_td3)

            print(
                "======Best Model Retraining from: ",
                self.train_period[0],
                "to ",
                self.unique_trade_date[i - self.rebalance_window],
            )
            # Environment setup for model retraining up to first trade date
            # train_full = data_split(self.df, start=self.train_period[0], end=self.unique_trade_date[i - self.rebalance_window])
            # self.train_full_env = DummyVecEnv([lambda: StockTradingEnv(train_full,
            #                                                    self.stock_dim,
            #                                                    self.hmax,
            #                                                    self.initial_amount,
            #                                                    self.buy_cost_pct,
            #                                                    self.sell_cost_pct,
            #                                                    self.reward_scaling,
            #                                                    self.state_space,
            #                                                    self.action_space,
            #                                                    self.tech_indicator_list,
            #                                                    print_verbosity=self.print_verbosity)])
            # Model Selection based on sharpe ratio
            if (sharpe_ppo >= sharpe_a2c) & (sharpe_ppo >= sharpe_ddpg) & (sharpe_ppo >= sharpe_sac) & (sharpe_ppo >= sharpe_td3):
                model_use.append("PPO")
                model_ensemble = model_ppo

                # model_ensemble = self.get_model("ppo",self.train_full_env,policy="MlpPolicy",model_kwargs=PPO_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['ppo']) #100_000
            elif (sharpe_a2c > sharpe_ppo) & (sharpe_a2c > sharpe_ddpg) & (sharpe_a2c >= sharpe_sac) & (sharpe_a2c >= sharpe_td3):
                model_use.append("A2C")
                model_ensemble = model_a2c

                # model_ensemble = self.get_model("a2c",self.train_full_env,policy="MlpPolicy",model_kwargs=A2C_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['a2c']) #100_000
            elif (sharpe_ddpg > sharpe_ppo) & (sharpe_ddpg > sharpe_a2c) & (sharpe_ddpg >= sharpe_sac) & (sharpe_ddpg >= sharpe_td3):
                model_use.append("DDPG")
                model_ensemble = model_ddpg

                # model_ensemble = self.get_model("ddpg",self.train_full_env,policy="MlpPolicy",model_kwargs=DDPG_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['ddpg']) #50_000#

            elif (sharpe_sac > sharpe_ppo) & (sharpe_sac > sharpe_a2c) & (sharpe_sac >= sharpe_ddpg) & (sharpe_sac >= sharpe_td3):
                model_use.append("SAC")
                model_ensemble = model_sac
            
            else:
                model_use.append("TD3")
                model_ensemble = model_td3
            ############## Training and Validation ends ##############

            ############## Trading starts ##############
            print(
                "======Trading from: ",
                self.unique_trade_date[i - self.rebalance_window],
                "to ",
                self.unique_trade_date[i],
            )
            # print("Used Model: ", model_ensemble)
            last_state_ensemble = self.DRL_prediction(
                model=model_ensemble,
                name="ensemble",
                last_state=last_state_ensemble,
                iter_num=i,
                turbulence_threshold=turbulence_threshold,
                initial=initial,
            )
            ############## Trading ends #############

        end = time.time()
        print("Ensemble Strategy took: ", (end - start) / 60, " minutes")

        df_summary = pd.DataFrame(
            [
                iteration_list,
                validation_start_date_list,
                validation_end_date_list,
                model_use,
                a2c_sharpe_list,
                ppo_sharpe_list,
                ddpg_sharpe_list,
                sac_sharpe_list,
                td3_sharpe_list
            ]
        ).T
        df_summary.columns = [
            "Iter",
            "Val Start",
            "Val End",
            "Model Used",
            "A2C Sharpe",
            "PPO Sharpe",
            "DDPG Sharpe",
            "SAC Sharpe",
            "TD3 Sharpe"
        ]

        return df_summary

# %%
DRLEnsembleAgent.run_ensemble_strategy_
# Out:
# <function __main__.DRLEnsembleAgent.run_ensemble_strategy_(self, A2C_model_kwargs, PPO_model_kwargs, DDPG_model_kwargs, TD3_model_kwargs, SAC_model_kwargs, timesteps_dict)>

# %%
rebalance_window = 63 # number of days to retrain the model
validation_window = 63 # number of days to do validation 

ensemble_agent = DRLEnsembleAgent(df=processed,
                                train_period = (TRAIN_START_DATE, TRAIN_END_DATE),
                                val_test_period = (TRADE_START_DATE, TRADE_END_DATE),
                                rebalance_window=rebalance_window,
                                validation_window=validation_window,
                                **env_kwargs )

# %% [markdown]
# 여기서 말하는 validation test period가 test period임. 우리가 설정해놓은 TRADE_START_DATE, TRADE_END_DATE.

# %%
# df_summary = ensemble_agent.run_ensemble_strategy_(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 오류 fix
#
# 해당 issue에 대해 대처하는 방법 두가지
# 1. source_code들어가서 필요하지 않은 부분 제거함
# 2. requirements issue 로 발생함.
#
# 다음 명령으로 손쉽게 requirements.txt 생성이 가능함
# $ pip freeze > requirements.txt
#
# 다음 명령을 실행하면 모든 패키지를 한번에 설치해준다.
# $ pip install -r requirements.txt

# %%
df_summary = ensemble_agent.run_ensemble_strategy_(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  52.59985945892213
# ======Model training from:  2010-01-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_12
# ---------------------------------------
# | time/                 |             |
# |    fps                | 159         |
# |    iterations         | 100         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -24.6       |
# |    reward             | -0.06904276 |
# |    std                | 1           |
# |    value_loss         | 2.97        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 200       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -2.48     |
# |    reward             | 0.9956503 |
# |    std                | 1         |
# |    value_loss         | 1.14      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 160        |
# |    iterations         | 300        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.0303    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -18.4      |
# |    reward             | -2.6723936 |
# |    std                | 1          |
# |    value_loss         | 4.11       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 400       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0.16      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 8.08      |
# |    reward             | 0.1008361 |
# |    std                | 1         |
# |    value_loss         | 1.33      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 161         |
# |    iterations         | 500         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | 0.0525      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -17.5       |
# |    reward             | -0.95261914 |
# |    std                | 1           |
# |    value_loss         | 3.37        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 158         |
# |    iterations         | 600         |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | -1.8        |
# |    reward             | 0.062635995 |
# |    std                | 1           |
# |    value_loss         | 0.0328      |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 156        |
# |    iterations         | 700        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -0.141     |
# |    reward             | 0.23614848 |
# |    std                | 1.01       |
# |    value_loss         | 0.0304     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 155        |
# |    iterations         | 800        |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0.187      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 1.25       |
# |    reward             | 0.17843483 |
# |    std                | 1.01       |
# |    value_loss         | 0.64       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 155        |
# |    iterations         | 900        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | -0.0532    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -22.5      |
# |    reward             | 0.16321747 |
# |    std                | 1.01       |
# |    value_loss         | 7.18       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 1000      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -74.8     |
# |    reward             | 0.5452882 |
# |    std                | 1.01      |
# |    value_loss         | 91.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 155       |
# |    iterations         | 1100      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | 0.848     |
# |    reward             | 4.8778214 |
# |    std                | 1.02      |
# |    value_loss         | 16.9      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 155          |
# |    iterations         | 1200         |
# |    time_elapsed       | 38           |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -12.9        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | -3.96        |
# |    reward             | 4.786287e-05 |
# |    std                | 1.02         |
# |    value_loss         | 0.13         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 155         |
# |    iterations         | 1300        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -12.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | -2.2        |
# |    reward             | 0.028720982 |
# |    std                | 1.02        |
# |    value_loss         | 0.476       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 155        |
# |    iterations         | 1400       |
# |    time_elapsed       | 45         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | -0.133     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 20.6       |
# |    reward             | -1.7847219 |
# |    std                | 1.02       |
# |    value_loss         | 4.21       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 153       |
# |    iterations         | 1500      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 29.8      |
# |    reward             | 0.6082442 |
# |    std                | 1.02      |
# |    value_loss         | 6.64      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 151       |
# |    iterations         | 1600      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | -0.00844  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -22.5     |
# |    reward             | 2.4260824 |
# |    std                | 1.02      |
# |    value_loss         | 13.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 150       |
# |    iterations         | 1700      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 0.000136  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -71.8     |
# |    reward             | 2.8257794 |
# |    std                | 1.02      |
# |    value_loss         | 85.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 150        |
# |    iterations         | 1800       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -3.76      |
# |    reward             | 0.25982586 |
# |    std                | 1.01       |
# |    value_loss         | 0.264      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 150       |
# |    iterations         | 1900      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | -0.162    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 6.79      |
# |    reward             | 0.9135674 |
# |    std                | 1.01      |
# |    value_loss         | 1.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 149        |
# |    iterations         | 2000       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -12.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 10.8       |
# |    reward             | 0.69416136 |
# |    std                | 1.01       |
# |    value_loss         | 1.35       |
# --------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.3868088085580676
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_126_11
# -----------------------------------
# | time/              |            |
# |    fps             | 195        |
# |    iterations      | 1          |
# |    time_elapsed    | 10         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.17712525 |
# -----------------------------------
# day: 2957, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2859499.91
# total_reward: 1859499.91
# total_cost: 76459.48
# total_trades: 26068
# Sharpe: 0.768
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 2           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009095017 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.0462     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.49        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0111     |
# |    reward               | 0.37259838  |
# |    std                  | 1           |
# |    value_loss           | 3.01        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 3            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0072138617 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.00135     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.87         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00667     |
# |    reward               | 0.031821556  |
# |    std                  | 1            |
# |    value_loss           | 18.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008218338 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.00827    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00779    |
# |    reward               | 1.9862547   |
# |    std                  | 1           |
# |    value_loss           | 24.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 5           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008374352 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.0143     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.18        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00714    |
# |    reward               | -0.07789457 |
# |    std                  | 1.01        |
# |    value_loss           | 6.41        |
# -----------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.26041286754624327
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_126_11
# day: 2957, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3455066.94
# total_reward: 2455066.94
# total_cost: 1132.97
# total_trades: 11828
# Sharpe: 0.645
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 65        |
# |    time_elapsed    | 180       |
# |    total_timesteps | 11832     |
# | train/             |           |
# |    actor_loss      | 200       |
# |    critic_loss     | 1.84e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 8874      |
# |    reward          | 4.3220954 |
# ----------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======SAC Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac\sac_126_1
# day: 2957, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 3913185.01
# total_reward: 2913185.01
# total_cost: 1341.35
# total_trades: 14931
# Sharpe: 0.815
# =================================
# ======SAC Validation from:  2021-10-04 to  2022-01-03
# SAC Sharpe Ratio :  0.4387129088382542
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3\td3_126_1
# day: 2957, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4436663.84
# total_reward: 3436663.84
# total_cost: 999.00
# total_trades: 11828
# Sharpe: 0.896
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 65        |
# |    time_elapsed    | 181       |
# |    total_timesteps | 11832     |
# | train/             |           |
# |    actor_loss      | 435       |
# |    critic_loss     | 4.63e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 8874      |
# |    reward          | 3.0973537 |
# ----------------------------------
# ======TD3 Validation from:  2021-10-04 to  2022-01-03
# TD3 Sharpe Ratio :  0.2718976053221052
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  52.59985945892213
# ======Model training from:  2010-01-01 to  2022-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_189_5
# --------------------------------------
# | time/                 |            |
# |    fps                | 118        |
# |    iterations         | 100        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0.0607     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -44        |
# |    reward             | 0.34541845 |
# |    std                | 1          |
# |    value_loss         | 9.23       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 130        |
# |    iterations         | 200        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0.0159     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -0.301     |
# |    reward             | 0.16225101 |
# |    std                | 1.01       |
# |    value_loss         | 1.27       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 300       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | -0.145    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -12.7     |
# |    reward             | -2.827863 |
# |    std                | 1.01      |
# |    value_loss         | 7.85      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 146         |
# |    iterations         | 400         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 11.6        |
# |    reward             | -0.37723476 |
# |    std                | 1.01        |
# |    value_loss         | 2.86        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 150         |
# |    iterations         | 500         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -12.8       |
# |    explained_variance | 0.0639      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -16.2       |
# |    reward             | -0.16661258 |
# |    std                | 1.01        |
# |    value_loss         | 2.57        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 151       |
# |    iterations         | 600       |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 37        |
# |    reward             | 3.3345723 |
# |    std                | 1         |
# |    value_loss         | 10.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 152        |
# |    iterations         | 700        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.0261    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -59.2      |
# |    reward             | -0.7262484 |
# |    std                | 1          |
# |    value_loss         | 20.3       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 800      |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -12.8    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 18.5     |
# |    reward             | 1.435973 |
# |    std                | 0.998    |
# |    value_loss         | 2.83     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 155        |
# |    iterations         | 900        |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -25.4      |
# |    reward             | -1.2822897 |
# |    std                | 1          |
# |    value_loss         | 6.2        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 157        |
# |    iterations         | 1000       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 18.5       |
# |    reward             | -0.7591114 |
# |    std                | 1          |
# |    value_loss         | 2.26       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 157       |
# |    iterations         | 1100      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -33.4     |
# |    reward             | 2.0124495 |
# |    std                | 0.999     |
# |    value_loss         | 7.27      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 158        |
# |    iterations         | 1200       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -12.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 32.6       |
# |    reward             | -1.4809847 |
# |    std                | 0.996      |
# |    value_loss         | 7.88       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1300      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 13.2      |
# |    reward             | 1.4096401 |
# |    std                | 0.996     |
# |    value_loss         | 2.24      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 158         |
# |    iterations         | 1400        |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -12.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 8.32        |
# |    reward             | -0.34755445 |
# |    std                | 0.996       |
# |    value_loss         | 2.01        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 158        |
# |    iterations         | 1500       |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -12.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 21.3       |
# |    reward             | 0.14109522 |
# |    std                | 0.994      |
# |    value_loss         | 3.7        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1600      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 14.5      |
# |    reward             | 1.2326202 |
# |    std                | 0.993     |
# |    value_loss         | 2.01      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1700      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -63       |
# |    reward             | 1.4862989 |
# |    std                | 0.992     |
# |    value_loss         | 24.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1800      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -73.5     |
# |    reward             | 4.4396753 |
# |    std                | 0.992     |
# |    value_loss         | 33.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 158       |
# |    iterations         | 1900      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 5.4       |
# |    reward             | 1.1546528 |
# |    std                | 0.994     |
# |    value_loss         | 1.65      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 159          |
# |    iterations         | 2000         |
# |    time_elapsed       | 62           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -12.7        |
# |    explained_variance | -2.38e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1999         |
# |    policy_loss        | 10.6         |
# |    reward             | -0.036985047 |
# |    std                | 0.994        |
# |    value_loss         | 1.28         |
# ----------------------------------------
# ======A2C Validation from:  2022-01-03 to  2022-04-04
# A2C Sharpe Ratio:  -0.16598291904944387
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_189_5
# ----------------------------------
# | time/              |           |
# |    fps             | 219       |
# |    iterations      | 1         |
# |    time_elapsed    | 9         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.4673961 |
# ----------------------------------
# day: 3020, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2531217.34
# total_reward: 1531217.34
# total_cost: 80054.05
# total_trades: 26490
# Sharpe: 0.676
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 212          |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0057778396 |
# |    clip_fraction        | 0.0652       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.385        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00415     |
# |    reward               | -0.64183503  |
# |    std                  | 1            |
# |    value_loss           | 1.16         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 3           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006182474 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.0165     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.44        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0069     |
# |    reward               | -0.237384   |
# |    std                  | 1           |
# |    value_loss           | 12.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 219         |
# |    iterations           | 4           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007322989 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.000877   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00718    |
# |    reward               | -0.28759092 |
# |    std                  | 1           |
# |    value_loss           | 25.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 220          |
# |    iterations           | 5            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0069913534 |
# |    clip_fraction        | 0.079        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | 0.0592       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.19         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00932     |
# |    reward               | -1.1306753   |
# |    std                  | 1            |
# |    value_loss           | 4.07         |
# ------------------------------------------
# ======PPO Validation from:  2022-01-03 to  2022-04-04
# PPO Sharpe Ratio:  0.0940015171114526
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_189_5
# day: 3020, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7266607.78
# total_reward: 6266607.78
# total_cost: 999.00
# total_trades: 11906
# Sharpe: 1.003
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 57        |
# |    time_elapsed    | 208       |
# |    total_timesteps | 12084     |
# | train/             |           |
# |    actor_loss      | 154       |
# |    critic_loss     | 2.83e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9063      |
# |    reward          | -2.439617 |
# ----------------------------------
# ======DDPG Validation from:  2022-01-03 to  2022-04-04
# ======SAC Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac\sac_189_1
# day: 3020, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 5308782.42
# total_reward: 4308782.42
# total_cost: 1649.05
# total_trades: 12392
# Sharpe: 0.928
# =================================
# ======SAC Validation from:  2022-01-03 to  2022-04-04
# SAC Sharpe Ratio :  -0.2393984068634288
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3\td3_189_1
# day: 3020, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5980354.20
# total_reward: 4980354.20
# total_cost: 1332.03
# total_trades: 12256
# Sharpe: 0.959
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 62          |
# |    time_elapsed    | 193         |
# |    total_timesteps | 12084       |
# | train/             |             |
# |    actor_loss      | 328         |
# |    critic_loss     | 8.9e+03     |
# |    learning_rate   | 0.0005      |
# |    n_updates       | 9063        |
# |    reward          | -0.68368167 |
# ------------------------------------
# ======TD3 Validation from:  2022-01-03 to  2022-04-04
# TD3 Sharpe Ratio :  -0.1597904267522113
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  52.59985945892213
# ======Model training from:  2010-01-01 to  2022-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_252_2
# --------------------------------------
# | time/                 |            |
# |    fps                | 88         |
# |    iterations         | 100        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0.262      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -14.2      |
# |    reward             | 0.20053454 |
# |    std                | 1.01       |
# |    value_loss         | 1.72       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 104        |
# |    iterations         | 200        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.369     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -13.9      |
# |    reward             | 0.80133975 |
# |    std                | 1          |
# |    value_loss         | 4.9        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 113        |
# |    iterations         | 300        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.00499   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -6.54      |
# |    reward             | -3.2904701 |
# |    std                | 1.01       |
# |    value_loss         | 3.75       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 121       |
# |    iterations         | 400       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -15       |
# |    reward             | 0.8075738 |
# |    std                | 1.01      |
# |    value_loss         | 2.83      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 124        |
# |    iterations         | 500        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -17.5      |
# |    reward             | -1.9138681 |
# |    std                | 1          |
# |    value_loss         | 6.15       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 127      |
# |    iterations         | 600      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -12.8    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -26.9    |
# |    reward             | 3.693061 |
# |    std                | 1        |
# |    value_loss         | 10.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 700       |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -61.3     |
# |    reward             | 1.7763112 |
# |    std                | 1.01      |
# |    value_loss         | 27.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 130        |
# |    iterations         | 800        |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -46.7      |
# |    reward             | 0.33643392 |
# |    std                | 1.01       |
# |    value_loss         | 20.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 132        |
# |    iterations         | 900        |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -27.6      |
# |    reward             | -0.8861562 |
# |    std                | 1.01       |
# |    value_loss         | 9.19       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 135       |
# |    iterations         | 1000      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -3.83     |
# |    reward             | 1.9336839 |
# |    std                | 1.01      |
# |    value_loss         | 0.524     |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 137           |
# |    iterations         | 1100          |
# |    time_elapsed       | 39            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -12.9         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -50.9         |
# |    reward             | 0.00091830554 |
# |    std                | 1.01          |
# |    value_loss         | 21.3          |
# -----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 1200      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 60.4      |
# |    reward             | -2.228233 |
# |    std                | 1.01      |
# |    value_loss         | 30.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 140        |
# |    iterations         | 1300       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 14.7       |
# |    reward             | 0.56386834 |
# |    std                | 1.01       |
# |    value_loss         | 1.55       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 1400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -38.4     |
# |    reward             | 0.7054027 |
# |    std                | 1.01      |
# |    value_loss         | 9.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 1500      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# ...
# |    policy_loss        | -22.7       |
# |    reward             | 0.043676306 |
# |    std                | 1.01        |
# |    value_loss         | 8.69        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 600      |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -12.8    |
# |    explained_variance | 0.0327   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -12.2    |
# |    reward             | 8.421608 |
# |    std                | 1        |
# |    value_loss         | 4.96     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 161       |
# |    iterations         | 700       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 11        |
# |    reward             | 1.0152793 |
# |    std                | 1         |
# |    value_loss         | 1.05      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 162        |
# |    iterations         | 800        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 2.47       |
# |    reward             | -2.2228901 |
# |    std                | 1          |
# |    value_loss         | 0.0527     |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 163        |
# |    iterations         | 900        |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 15.4       |
# |    reward             | 0.40935165 |
# |    std                | 1          |
# |    value_loss         | 1.97       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 162       |
# |    iterations         | 1000      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0.448     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 1.47      |
# |    reward             | 1.5854148 |
# |    std                | 1         |
# |    value_loss         | 0.269     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 163        |
# |    iterations         | 1100       |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.00857   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 53.1       |
# |    reward             | 0.27402145 |
# |    std                | 1          |
# |    value_loss         | 26.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 163        |
# |    iterations         | 1200       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0.0875     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -167       |
# |    reward             | -1.2887509 |
# |    std                | 1.01       |
# |    value_loss         | 202        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 163       |
# |    iterations         | 1300      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -12.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -3.4      |
# |    reward             | 0.5886037 |
# |    std                | 1.01      |
# |    value_loss         | 0.115     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 163        |
# |    iterations         | 1400       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.00606   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -10.1      |
# |    reward             | -0.9457846 |
# |    std                | 1.01       |
# |    value_loss         | 1.29       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 1500     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -12.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -63.2    |
# |    reward             | 1.891015 |
# |    std                | 1.01     |
# |    value_loss         | 38.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 164       |
# |    iterations         | 1600      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 11.1      |
# |    reward             | 0.1795298 |
# |    std                | 1         |
# |    value_loss         | 6.66      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 1700     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -12.8    |
# |    explained_variance | -0.0326  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.352   |
# |    reward             | 4.83362  |
# |    std                | 1.01     |
# |    value_loss         | 6.91     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 163        |
# |    iterations         | 1800       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 213        |
# |    reward             | -3.2331283 |
# |    std                | 1.01       |
# |    value_loss         | 461        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 164       |
# |    iterations         | 1900      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 92.1      |
# |    reward             | 4.6281514 |
# |    std                | 1.01      |
# |    value_loss         | 116       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 163         |
# |    iterations         | 2000        |
# |    time_elapsed       | 61          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -12.9       |
# |    explained_variance | 0.0939      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -19.1       |
# |    reward             | -0.69095075 |
# |    std                | 1.01        |
# |    value_loss         | 2.55        |
# ---------------------------------------
# ======A2C Validation from:  2022-10-04 to  2023-01-04
# A2C Sharpe Ratio:  -0.0040591106135823285
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo\ppo_378_1
# -----------------------------------
# | time/              |            |
# |    fps             | 232        |
# |    iterations      | 1          |
# |    time_elapsed    | 8          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.25585875 |
# -----------------------------------
# day: 3209, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1944297.08
# total_reward: 944297.08
# total_cost: 91023.61
# total_trades: 28286
# Sharpe: 0.595
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006515827 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.177       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00439    |
# |    reward               | 0.118917935 |
# |    std                  | 1.01        |
# |    value_loss           | 0.698       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 3          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00559419 |
# |    clip_fraction        | 0.0559     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -12.8      |
# |    explained_variance   | -0.00728   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.97       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00341   |
# |    reward               | 0.9376831  |
# |    std                  | 1.01       |
# |    value_loss           | 7.99       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 4            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0071193194 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.8        |
# |    explained_variance   | -0.0284      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.65         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00609     |
# |    reward               | 0.2869098    |
# |    std                  | 1.01         |
# |    value_loss           | 12           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 5           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009238958 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.8       |
# |    explained_variance   | -0.0134     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.05        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0105     |
# |    reward               | 0.37755004  |
# |    std                  | 1.01        |
# |    value_loss           | 6.77        |
# -----------------------------------------
# ======PPO Validation from:  2022-10-04 to  2023-01-04
# PPO Sharpe Ratio:  0.0589626372760347
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg\ddpg_378_1
# day: 3209, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4002699.62
# total_reward: 3002699.62
# total_cost: 998.99
# total_trades: 12721
# Sharpe: 0.652
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 41       |
# |    time_elapsed    | 308      |
# |    total_timesteps | 12840    |
# | train/             |          |
# |    actor_loss      | -201     |
# |    critic_loss     | 2.72e+03 |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 9630     |
# |    reward          | 9.173291 |
# ---------------------------------
# ======DDPG Validation from:  2022-10-04 to  2023-01-04
# ======SAC Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac\sac_378_1
# day: 3209, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 3636810.01
# total_reward: 2636810.01
# total_cost: 998.98
# total_trades: 12836
# Sharpe: 0.652
# =================================
# ======SAC Validation from:  2022-10-04 to  2023-01-04
# SAC Sharpe Ratio :  0.048520460460999164
# ======TD3 Training========
# {'buffer_size': 100000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3\td3_378_1
# day: 3209, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4152970.24
# total_reward: 3152970.24
# total_cost: 999.00
# total_trades: 16045
# Sharpe: 0.802
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 60        |
# |    time_elapsed    | 212       |
# |    total_timesteps | 12840     |
# | train/             |           |
# |    actor_loss      | 560       |
# |    critic_loss     | 2.1e+03   |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9630      |
# |    reward          | 6.2189603 |
# ----------------------------------
# ======TD3 Validation from:  2022-10-04 to  2023-01-04
# TD3 Sharpe Ratio :  0.0711733934157467
# ======Best Model Retraining from:  2010-01-01 to  2023-01-04
# ======Trading from:  2023-01-04 to  2023-04-05
# Ensemble Strategy took:  79.25368833939234  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-10-04  2022-01-03        SAC   0.386809   0.260413    0.237952
# 1  189  2022-01-03  2022-04-04        PPO  -0.165983   0.094002   -0.189615
# 2  252  2022-04-04  2022-07-06        A2C  -0.280681   -0.30666   -0.282064
# 3  315  2022-07-06  2022-10-04        TD3  -0.102888  -0.135858   -0.110452
# 4  378  2022-10-04  2023-01-04        TD3  -0.004059   0.058963   -0.071376
#
#   SAC Sharpe TD3 Sharpe
# 0   0.438713   0.271898
# 1  -0.239398   -0.15979
# 2  -0.312768  -0.348928
# 3  -0.158056  -0.094352
# 4    0.04852   0.071173

# %% [markdown]
# # Backtest

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.405016694220508

# %%
df_account_value.head()
# Out:
#     account_value        date  daily_return    datadate
# 0  1000000.000000  2022-01-03           NaN  2020-10-30
# 1   999914.146792  2022-01-04     -0.000086  2020-11-02
# 2   998383.636916  2022-01-05     -0.001531  2020-11-03
# 3   997147.903264  2022-01-06     -0.001238  2020-11-04
# 4   996398.871774  2022-01-07     -0.000751  2020-11-05

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.213466
# Cumulative returns    -0.164805
# Annual volatility      0.162353
# Sharpe ratio          -1.405017
# Calmar ratio          -1.164985
# Stability              0.707832
# Max drawdown          -0.183235
# Omega ratio            0.768861
# Sortino ratio         -1.784727
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.895274
# Daily value at risk   -0.021360
# dtype: float64

# %%
# backtest_stats 주소
backtest_stats
# Out:
# <function finrl.plot.backtest_stats(account_value, value_col_name='account_value')>

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (188, 8)
# Annual return         -0.276886
# Cumulative returns    -0.214829
# Annual volatility      0.195309
# Sharpe ratio          -1.570180
# Calmar ratio          -1.261966
# Stability              0.601336
# Max drawdown          -0.219408
# Omega ratio            0.774115
# Sortino ratio         -2.014744
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.773392
# Daily value at risk   -0.025824
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")

df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv("df_account_value.csv")

print("df_dji:",df_dji)
# Out:
# df_dji:                      dji
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.005866e+06
# 2022-01-05  9.951360e+05
# 2022-01-06  9.904718e+05
# 2022-01-07  9.903404e+05
# ...                  ...
# 2022-09-27  7.963631e+05
# 2022-09-28  8.113624e+05
# 2022-09-29  7.988400e+05
# 2022-09-30  7.851705e+05
# 2022-10-03           NaN
#
# [189 rows x 1 columns]

# %%
# plot
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date' : df_account_value['date'], 'ensemble' : df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')
print("df_result_ensemble.columns: ", df_result_ensemble.columns)

print("df_trade_date : ", df_trade_date)

df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble:", df_result_ensemble)

print("==============Compare to DJIA===========")
result = pd.DataFrame()
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date :         datadate
# 0    2020-08-03
# 1    2020-08-04
# 2    2020-08-05
# 3    2020-08-06
# 4    2020-08-07
# ..          ...
# 290  2021-09-27
# 291  2021-09-28
# 292  2021-09-29
# 293  2021-09-30
# 294  2021-10-01
#
# [295 rows x 1 columns]
# df_result_ensemble:                   ensemble
# date
# 2022-01-03  1000000.000000
# 2022-01-04   999914.146792
# 2022-01-05   998383.636916
# 2022-01-06   997147.903264
# 2022-01-07   996398.871774
# ...                    ...
# 2022-09-27   819629.531875
# 2022-09-28   836975.998100
# 2022-09-29   827955.891195
# 2022-09-30   816764.637831
# 2022-10-03   835195.134182
#
# [189 rows x 1 columns]
# ==============Compare to DJIA===========

# %% [markdown]
# # Comments

# %% [markdown]
# - test data가 상승장인 경우로 특이한 케이스임. too specific 함. Should we go (1) more general ? Or (2) more specified to certain scenarios ?
#
# - Where does randomness come from?
#     - Exploration of policy 인듯. episode도 5개밖에 안되고 training 도 15분 남짓이라 n_step, episode늘려서 더 해봐도 좋은 결과 나올거 같음. 다만 train 에 too dependent 하지 않게. depdendent 하더라도, 그 scenario에 맞다는 걸 검증할 수 있으면 좋을텐데.
#
#     - scenario를 나누고 그에 대해 검증해볼까? 진짜 time series classification?
#
# - SAC랑 TD3에 대해서도 할거임
