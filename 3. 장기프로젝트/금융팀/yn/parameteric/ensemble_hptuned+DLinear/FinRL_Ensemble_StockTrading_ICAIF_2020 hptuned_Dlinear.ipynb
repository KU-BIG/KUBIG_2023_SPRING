# %%
# ## install finrl library
# %pip install wrds
# %pip install swig

# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# %pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (3.1.6)
# Requirement already satisfied: numpy in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds) (1.24.3)
# Requirement already satisfied: pandas in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds) (2.0.2)
# Requirement already satisfied: psycopg2-binary in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds) (2.9.6)
# Requirement already satisfied: scipy in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds) (1.10.1)
# Requirement already satisfied: sqlalchemy<2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds) (1.4.48)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from sqlalchemy<2->wrds) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pandas->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pandas->wrds) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pandas->wrds) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from python-dateutil>=2.8.2->pandas->wrds) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: swig in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (4.1.1)
# Note: you may need to restart the kernel to use updated packages.
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\ansem\appdata\local\temp\pip-req-build-hqfm2bun
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit cfdbe462627bd6355dccee215c1aac65873c6d67
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\ansem\appdata\local\temp\pip-install-pus84ora\elegantrl_5c9e1100e3324630b14ccef00a97430d
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 59fe4b4a1cca0a28e8a5fa4fb80eed9b5d472978
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting alpaca-trade-api<4,>=3 (from finrl==0.3.6)
#   Downloading alpaca_trade_api-3.0.2-py3-none-any.whl (34 kB)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Downloading ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
#                                               0.0/4.0 MB ? eta -:--:--
#                                               0.1/4.0 MB 1.7 MB/s eta 0:00:03
#      -----                                    0.5/4.0 MB 8.3 MB/s eta 0:00:01
#      ----------                               1.0/4.0 MB 9.3 MB/s eta 0:00:01
#      ---------------                          1.5/4.0 MB 9.6 MB/s eta 0:00:01
#      --------------------                     2.0/4.0 MB 9.8 MB/s eta 0:00:01
#      -------------------------                2.5/4.0 MB 9.9 MB/s eta 0:00:01
#      -----------------------------            3.0/4.0 MB 10.0 MB/s eta 0:00:01
#      -----------------------------------      3.5/4.0 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------  4.0/4.0 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------- 4.0/4.0 MB 10.1 MB/s eta 0:00:00
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Using cached exchange_calendars-4.2.8-py3-none-any.whl (191 kB)
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Using cached jqdatasdk-1.8.11-py3-none-any.whl (158 kB)
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Using cached pyfolio-0.9.2-py3-none-any.whl
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from finrl==0.3.6) (1.5.5)
# Collecting ray[default,tune]<3,>=2 (from finrl==0.3.6)
#   Downloading ray-2.5.1-cp310-cp310-win_amd64.whl (22.0 MB)
#                                               0.0/22.0 MB ? eta -:--:--
#                                               0.4/22.0 MB 12.9 MB/s eta 0:00:02
#      -                                        0.9/22.0 MB 11.3 MB/s eta 0:00:02
#      --                                       1.4/22.0 MB 10.7 MB/s eta 0:00:02
#      ---                                      1.9/22.0 MB 11.0 MB/s eta 0:00:02
#      ----                                     2.4/22.0 MB 10.8 MB/s eta 0:00:02
#      -----                                    2.9/22.0 MB 10.7 MB/s eta 0:00:02
#      ------                                   3.3/22.0 MB 10.7 MB/s eta 0:00:02
#      ------                                   3.8/22.0 MB 10.7 MB/s eta 0:00:02
#      -------                                  4.3/22.0 MB 11.1 MB/s eta 0:00:02
#      --------                                 4.8/22.0 MB 11.1 MB/s eta 0:00:02
#      ---------                                5.3/22.0 MB 11.0 MB/s eta 0:00:02
#      ----------                               5.8/22.0 MB 10.9 MB/s eta 0:00:02
#      -----------                              6.3/22.0 MB 10.9 MB/s eta 0:00:02
#      ------------                             6.8/22.0 MB 10.9 MB/s eta 0:00:02
#      -------------                            7.3/22.0 MB 10.9 MB/s eta 0:00:02
#      --------------                           7.8/22.0 MB 10.8 MB/s eta 0:00:02
#      ---------------                          8.3/22.0 MB 10.8 MB/s eta 0:00:02
#      ---------------                          8.8/22.0 MB 10.8 MB/s eta 0:00:02
#      ----------------                         9.2/22.0 MB 10.9 MB/s eta 0:00:02
#      -----------------                        9.7/22.0 MB 10.9 MB/s eta 0:00:02
#      ------------------                      10.2/22.0 MB 10.9 MB/s eta 0:00:02
#      -------------------                     10.7/22.0 MB 10.9 MB/s eta 0:00:02
#      -------------------                     11.2/22.0 MB 10.9 MB/s eta 0:00:01
#      --------------------                    11.6/22.0 MB 10.9 MB/s eta 0:00:01
#      ---------------------                   12.1/22.0 MB 10.7 MB/s eta 0:00:01
#      ----------------------                  12.5/22.0 MB 10.7 MB/s eta 0:00:01
#      -----------------------                 13.0/22.0 MB 10.6 MB/s eta 0:00:01
#      -----------------------                 13.4/22.0 MB 10.7 MB/s eta 0:00:01
#      ------------------------                13.8/22.0 MB 10.6 MB/s eta 0:00:01
#      ------------------------                14.1/22.0 MB 10.2 MB/s eta 0:00:01
#      -------------------------               14.5/22.0 MB 10.2 MB/s eta 0:00:01
#      ---------------------------             15.2/22.0 MB 10.4 MB/s eta 0:00:01
#      ----------------------------            15.8/22.0 MB 10.6 MB/s eta 0:00:01
#      ----------------------------            16.3/22.0 MB 10.6 MB/s eta 0:00:01
#      -----------------------------           16.8/22.0 MB 10.4 MB/s eta 0:00:01
#      ------------------------------          17.2/22.0 MB 10.4 MB/s eta 0:00:01
#      -------------------------------         17.7/22.0 MB 10.6 MB/s eta 0:00:01
#      --------------------------------        18.2/22.0 MB 10.6 MB/s eta 0:00:01
#      ---------------------------------       18.7/22.0 MB 10.6 MB/s eta 0:00:01
#      ----------------------------------      19.2/22.0 MB 10.6 MB/s eta 0:00:01
#      ----------------------------------      19.7/22.0 MB 10.6 MB/s eta 0:00:01
#      -----------------------------------     20.2/22.0 MB 10.6 MB/s eta 0:00:01
#      ------------------------------------    20.7/22.0 MB 10.6 MB/s eta 0:00:01
#      -------------------------------------   21.0/22.0 MB 10.4 MB/s eta 0:00:01
#      -------------------------------------   21.0/22.0 MB 10.4 MB/s eta 0:00:01
#      --------------------------------------   21.0/22.0 MB 9.5 MB/s eta 0:00:01
#      ---------------------------------------  21.5/22.0 MB 9.5 MB/s eta 0:00:01
#      ---------------------------------------  21.9/22.0 MB 9.6 MB/s eta 0:00:01
#      ---------------------------------------  22.0/22.0 MB 9.5 MB/s eta 0:00:01
#      ---------------------------------------- 22.0/22.0 MB 9.1 MB/s eta 0:00:00
# Collecting scikit-learn<2,>=1 (from finrl==0.3.6)
#   Downloading scikit_learn-1.3.0-cp310-cp310-win_amd64.whl (9.2 MB)
#                                               0.0/9.2 MB ? eta -:--:--
#      --                                       0.5/9.2 MB 10.5 MB/s eta 0:00:01
#      ----                                     1.0/9.2 MB 10.6 MB/s eta 0:00:01
#      ------                                   1.5/9.2 MB 11.7 MB/s eta 0:00:01
#      --------                                 2.0/9.2 MB 11.4 MB/s eta 0:00:01
#      ----------                               2.5/9.2 MB 11.2 MB/s eta 0:00:01
#      ------------                             2.9/9.2 MB 11.1 MB/s eta 0:00:01
#      --------------                           3.4/9.2 MB 11.0 MB/s eta 0:00:01
#      ----------------                         3.9/9.2 MB 10.9 MB/s eta 0:00:01
#      -------------------                      4.4/9.2 MB 10.9 MB/s eta 0:00:01
#      --------------------                     4.8/9.2 MB 10.6 MB/s eta 0:00:01
#      ----------------------                   5.3/9.2 MB 10.6 MB/s eta 0:00:01
#      -------------------------                5.8/9.2 MB 10.9 MB/s eta 0:00:01
#      ---------------------------              6.3/9.2 MB 10.9 MB/s eta 0:00:01
#      -----------------------------            6.8/9.2 MB 10.8 MB/s eta 0:00:01
#      -------------------------------          7.3/9.2 MB 10.8 MB/s eta 0:00:01
#      ---------------------------------        7.8/9.2 MB 10.8 MB/s eta 0:00:01
#      -----------------------------------      8.3/9.2 MB 10.8 MB/s eta 0:00:01
#      -------------------------------------    8.8/9.2 MB 10.8 MB/s eta 0:00:01
#      ---------------------------------------  9.2/9.2 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 9.2/9.2 MB 10.5 MB/s eta 0:00:00
# Collecting stable-baselines3[extra]>=2.0.0a5 (from finrl==0.3.6)
#   Using cached stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Using cached stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: wrds<4,>=3 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from finrl==0.3.6) (3.1.6)
# Collecting yfinance<0.3,>=0.2 (from finrl==0.3.6)
#   Downloading yfinance-0.2.22-py2.py3-none-any.whl (63 kB)
#                                               0.0/63.2 kB ? eta -:--:--
#      ---------------------------------------- 63.2/63.2 kB ? eta 0:00:00
# Requirement already satisfied: pandas>=0.18.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.0.2)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.24.3)
# Requirement already satisfied: requests<3,>2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Collecting websocket-client<2,>=0.56.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#                                               0.0/56.9 kB ? eta -:--:--
#      ---------------------------------------- 56.9/56.9 kB ? eta 0:00:00
# Collecting websockets<11,>=9.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached websockets-10.4-cp310-cp310-win_amd64.whl (101 kB)
# Collecting msgpack==1.0.3 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached msgpack-1.0.3-cp310-cp310-win_amd64.whl (69 kB)
# Collecting aiohttp==3.8.2 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading aiohttp-3.8.2-cp310-cp310-win_amd64.whl (319 kB)
#                                               0.0/319.7 kB ? eta -:--:--
#      ------------------------------------- 319.7/319.7 kB 10.0 MB/s eta 0:00:00
# Collecting PyYAML==6.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
# Collecting deprecation==2.1.0 (from alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting attrs>=17.3.0 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<3.0,>=2.0 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting multidict<6.0,>=4.5 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Downloading multidict-5.2.0-cp310-cp310-win_amd64.whl (45 kB)
#                                               0.0/45.4 kB ? eta -:--:--
#      ---------------------------------------- 45.4/45.4 kB 2.2 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp==3.8.2->alpaca-trade-api<4,>=3->finrl==0.3.6)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: packaging in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.1)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (67.8.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ccxt<4,>=3->finrl==0.3.6) (2023.5.7)
# Collecting cryptography>=2.6.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Using cached cryptography-41.0.1-cp37-abi3-win_amd64.whl (2.6 MB)
# Collecting aiodns>=1.1.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Collecting pyluach (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Using cached pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: python-dateutil in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: pytz in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2023.3)
# Collecting toolz (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Collecting korean-lunar-calendar (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.4.48)
# Collecting thriftpy2>=0.3.9 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Using cached thriftpy2-0.4.16-py2.py3-none-any.whl
# Collecting pymysql>=0.7.6 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#                                               0.0/44.8 kB ? eta -:--:--
#      ---------------------------------------- 44.8/44.8 kB ? eta 0:00:00
# Requirement already satisfied: ipython>=3.2.3 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.14.0)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.10.1)
# Collecting seaborn>=0.7.1 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting empyrical>=0.5.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Using cached empyrical-0.5.5-py3-none-any.whl
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.3)
# Collecting filelock (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading filelock-3.12.2-py3-none-any.whl (10 kB)
# Collecting jsonschema (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading protobuf-4.23.3-cp310-abi3-win_amd64.whl (422 kB)
#                                               0.0/422.5 kB ? eta -:--:--
#      ---------------------                  235.5/422.5 kB 7.0 MB/s eta 0:00:01
#      -------------------------------------- 422.5/422.5 kB 5.2 MB/s eta 0:00:00
# Collecting grpcio<=1.51.3,>=1.42.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached grpcio-1.51.3-cp310-cp310-win_amd64.whl (3.7 MB)
# Collecting tensorboardX>=1.9 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached tensorboardX-2.6.1-py2.py3-none-any.whl (101 kB)
# Collecting pyarrow<7.0.0,>=6.0.1 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading pyarrow-6.0.1-cp310-cp310-win_amd64.whl (15.5 MB)
#                                               0.0/15.5 MB ? eta -:--:--
#      -                                        0.4/15.5 MB 8.7 MB/s eta 0:00:02
#      --                                       0.9/15.5 MB 11.6 MB/s eta 0:00:02
#      ---                                      1.4/15.5 MB 11.2 MB/s eta 0:00:02
#      ----                                     1.9/15.5 MB 10.9 MB/s eta 0:00:02
#      ------                                   2.4/15.5 MB 10.9 MB/s eta 0:00:02
#      -------                                  2.9/15.5 MB 10.8 MB/s eta 0:00:02
#      --------                                 3.4/15.5 MB 10.8 MB/s eta 0:00:02
#      ---------                                3.9/15.5 MB 10.7 MB/s eta 0:00:02
#      -----------                              4.4/15.5 MB 10.7 MB/s eta 0:00:02
#      ------------                             4.8/15.5 MB 10.7 MB/s eta 0:00:01
#      -------------                            5.3/15.5 MB 10.6 MB/s eta 0:00:01
#      --------------                           5.7/15.5 MB 10.7 MB/s eta 0:00:01
#      ---------------                          6.0/15.5 MB 10.4 MB/s eta 0:00:01
#      -----------------                        6.8/15.5 MB 10.8 MB/s eta 0:00:01
#      ------------------                       7.3/15.5 MB 10.8 MB/s eta 0:00:01
#      --------------------                     7.8/15.5 MB 10.8 MB/s eta 0:00:01
#      ---------------------                    8.3/15.5 MB 10.8 MB/s eta 0:00:01
#      ----------------------                   8.7/15.5 MB 10.7 MB/s eta 0:00:01
#      ----------------------                   8.8/15.5 MB 10.3 MB/s eta 0:00:01
#      -----------------------                  9.0/15.5 MB 9.9 MB/s eta 0:00:01
#      -----------------------                  9.3/15.5 MB 9.9 MB/s eta 0:00:01
#      ------------------------                 9.6/15.5 MB 9.7 MB/s eta 0:00:01
#      --------------------------               10.3/15.5 MB 9.9 MB/s eta 0:00:01
#      ---------------------------              10.8/15.5 MB 9.9 MB/s eta 0:00:01
#      -----------------------------            11.3/15.5 MB 9.9 MB/s eta 0:00:01
#      ------------------------------           11.8/15.5 MB 9.9 MB/s eta 0:00:01
#      -------------------------------          12.3/15.5 MB 9.9 MB/s eta 0:00:01
#      --------------------------------         12.8/15.5 MB 9.9 MB/s eta 0:00:01
#      ----------------------------------       13.3/15.5 MB 9.9 MB/s eta 0:00:01
#      -----------------------------------      13.7/15.5 MB 9.9 MB/s eta 0:00:01
#      -----------------------------------     14.2/15.5 MB 10.1 MB/s eta 0:00:01
#      -------------------------------------   14.7/15.5 MB 10.1 MB/s eta 0:00:01
#      --------------------------------------  15.2/15.5 MB 10.1 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 9.9 MB/s eta 0:00:01
#      ---------------------------------------- 15.5/15.5 MB 9.6 MB/s eta 0:00:00
# Collecting aiohttp-cors (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting py-spy>=0.2.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached py_spy-0.3.14-py2.py3-none-win_amd64.whl (1.4 MB)
# Collecting gpustat>=1.0.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached gpustat-1.1-py3-none-any.whl
# Collecting opencensus (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
# Collecting pydantic (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading pydantic-2.0-py3-none-any.whl (355 kB)
#                                               0.0/355.6 kB ? eta -:--:--
#      ---------------                        143.4/355.6 kB 4.2 MB/s eta 0:00:01
#      -------------------------------------- 355.6/355.6 kB 4.4 MB/s eta 0:00:00
# Collecting prometheus-client>=0.7.1 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached prometheus_client-0.17.0-py3-none-any.whl (60 kB)
# Collecting smart-open (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting virtualenv<20.21.1,>=20.0.24 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting joblib>=1.1.1 (from scikit-learn<2,>=1->finrl==0.3.6)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#                                               0.0/302.0 kB ? eta -:--:--
#      -------------------------------------- 302.0/302.0 kB 9.4 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit-learn<2,>=1->finrl==0.3.6)
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting gymnasium==0.28.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached gymnasium-0.28.1-py3-none-any.whl (925 kB)
# Collecting torch>=1.11 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached torch-2.0.1-cp310-cp310-win_amd64.whl (172.3 MB)
# Requirement already satisfied: cloudpickle in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.1)
# Collecting opencv-python (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
#                                               0.0/38.1 MB ? eta -:--:--
#                                               0.3/38.1 MB 16.6 MB/s eta 0:00:03
#                                               0.9/38.1 MB 11.5 MB/s eta 0:00:04
#      -                                        1.4/38.1 MB 11.4 MB/s eta 0:00:04
#      --                                       1.9/38.1 MB 11.1 MB/s eta 0:00:04
#      --                                       2.4/38.1 MB 11.0 MB/s eta 0:00:04
#      ---                                      2.9/38.1 MB 10.9 MB/s eta 0:00:04
#      ---                                      3.4/38.1 MB 10.8 MB/s eta 0:00:04
#      ----                                     3.9/38.1 MB 11.2 MB/s eta 0:00:04
#      ----                                     4.4/38.1 MB 11.1 MB/s eta 0:00:04
#      -----                                    4.9/38.1 MB 11.1 MB/s eta 0:00:03
#      -----                                    5.2/38.1 MB 10.7 MB/s eta 0:00:04
#      ------                                   5.9/38.1 MB 11.0 MB/s eta 0:00:03
#      ------                                   6.3/38.1 MB 10.9 MB/s eta 0:00:03
#      -------                                  6.8/38.1 MB 10.9 MB/s eta 0:00:03
#      -------                                  7.2/38.1 MB 10.7 MB/s eta 0:00:03
#      --------                                 7.8/38.1 MB 10.8 MB/s eta 0:00:03
#      --------                                 8.3/38.1 MB 10.8 MB/s eta 0:00:03
#      ---------                                8.8/38.1 MB 11.0 MB/s eta 0:00:03
#      ---------                                9.3/38.1 MB 11.0 MB/s eta 0:00:03
#      ----------                               9.8/38.1 MB 11.0 MB/s eta 0:00:03
#      ----------                              10.2/38.1 MB 10.8 MB/s eta 0:00:03
#      -----------                             10.8/38.1 MB 10.9 MB/s eta 0:00:03
#      -----------                             11.2/38.1 MB 10.9 MB/s eta 0:00:03
#      ------------                            11.7/38.1 MB 10.7 MB/s eta 0:00:03
#      ------------                            12.2/38.1 MB 10.7 MB/s eta 0:00:03
#      -------------                           12.7/38.1 MB 10.7 MB/s eta 0:00:03
#      -------------                           13.1/38.1 MB 10.9 MB/s eta 0:00:03
#      --------------                          13.7/38.1 MB 10.9 MB/s eta 0:00:03
#      --------------                          14.2/38.1 MB 10.9 MB/s eta 0:00:03
#      ---------------                         14.7/38.1 MB 10.9 MB/s eta 0:00:03
#      ---------------                         15.0/38.1 MB 10.7 MB/s eta 0:00:03
#      ---------------                         15.1/38.1 MB 10.2 MB/s eta 0:00:03
#      ----------------                         15.3/38.1 MB 9.9 MB/s eta 0:00:03
#      ----------------                        16.0/38.1 MB 10.2 MB/s eta 0:00:03
#      ----------------                        16.5/38.1 MB 10.1 MB/s eta 0:00:03
#      -----------------                       17.0/38.1 MB 10.1 MB/s eta 0:00:03
#      -----------------                       17.5/38.1 MB 10.4 MB/s eta 0:00:02
#      ------------------                      18.0/38.1 MB 10.2 MB/s eta 0:00:02
#      ------------------                      18.3/38.1 MB 10.1 MB/s eta 0:00:02
#      -------------------                     19.0/38.1 MB 10.2 MB/s eta 0:00:02
#      -------------------                     19.5/38.1 MB 10.2 MB/s eta 0:00:02
#      --------------------                    20.0/38.1 MB 10.2 MB/s eta 0:00:02
#      --------------------                    20.5/38.1 MB 10.2 MB/s eta 0:00:02
#      ---------------------                   21.0/38.1 MB 10.2 MB/s eta 0:00:02
#      ---------------------                   21.1/38.1 MB 10.2 MB/s eta 0:00:02
#      ---------------------                   21.1/38.1 MB 10.2 MB/s eta 0:00:02
#      ----------------------                   21.9/38.1 MB 9.6 MB/s eta 0:00:02
#      -----------------------                  22.5/38.1 MB 9.9 MB/s eta 0:00:02
#      ------------------------                 22.9/38.1 MB 9.8 MB/s eta 0:00:02
#      ------------------------                 23.3/38.1 MB 9.8 MB/s eta 0:00:02
#      -------------------------                23.8/38.1 MB 9.8 MB/s eta 0:00:02
#      -------------------------                24.3/38.1 MB 9.8 MB/s eta 0:00:02
#      --------------------------               24.8/38.1 MB 9.6 MB/s eta 0:00:02
#      -------------------------               25.3/38.1 MB 10.1 MB/s eta 0:00:02
#      --------------------------              25.8/38.1 MB 10.4 MB/s eta 0:00:02
#      --------------------------              26.3/38.1 MB 10.2 MB/s eta 0:00:02
#      ---------------------------             26.8/38.1 MB 10.2 MB/s eta 0:00:02
#      ---------------------------             27.3/38.1 MB 10.2 MB/s eta 0:00:02
#      ----------------------------            27.8/38.1 MB 10.2 MB/s eta 0:00:02
#      ----------------------------            28.2/38.1 MB 10.4 MB/s eta 0:00:01
#      -----------------------------           28.7/38.1 MB 10.4 MB/s eta 0:00:01
#      -----------------------------           29.2/38.1 MB 10.2 MB/s eta 0:00:01
#      ------------------------------          29.7/38.1 MB 10.2 MB/s eta 0:00:01
#      ------------------------------          30.2/38.1 MB 10.2 MB/s eta 0:00:01
#      -------------------------------         30.7/38.1 MB 10.2 MB/s eta 0:00:01
#      -------------------------------         31.2/38.1 MB 10.2 MB/s eta 0:00:01
#      --------------------------------        31.6/38.1 MB 10.7 MB/s eta 0:00:01
#      --------------------------------        32.1/38.1 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------       32.4/38.1 MB 10.6 MB/s eta 0:00:01
#      ---------------------------------       33.1/38.1 MB 10.7 MB/s eta 0:00:01
#      ----------------------------------      33.5/38.1 MB 10.9 MB/s eta 0:00:01
#      ----------------------------------      34.0/38.1 MB 10.7 MB/s eta 0:00:01
#      -----------------------------------     34.5/38.1 MB 10.7 MB/s eta 0:00:01
#      -----------------------------------     35.0/38.1 MB 10.7 MB/s eta 0:00:01
#      ------------------------------------    35.5/38.1 MB 10.7 MB/s eta 0:00:01
#      ------------------------------------    36.0/38.1 MB 10.7 MB/s eta 0:00:01
#      -------------------------------------   36.5/38.1 MB 10.7 MB/s eta 0:00:01
#      -------------------------------------   37.0/38.1 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  37.5/38.1 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  38.0/38.1 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  38.1/38.1 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 38.1/38.1 MB 9.9 MB/s eta 0:00:00
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: psutil in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.65.0)
# Collecting rich (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached rich-13.4.2-py3-none-any.whl (239 kB)
# Collecting shimmy[atari]~=0.2.1 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.5.0)
# Collecting autorom[accept-rom-license]~=0.6.0 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting pygame (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading pygame-2.5.0-cp310-cp310-win_amd64.whl (10.5 MB)
#                                               0.0/10.5 MB ? eta -:--:--
#      -                                        0.5/10.5 MB 9.6 MB/s eta 0:00:02
#      ---                                      1.0/10.5 MB 10.0 MB/s eta 0:00:01
#      -----                                    1.4/10.5 MB 10.2 MB/s eta 0:00:01
#      -------                                  1.9/10.5 MB 11.1 MB/s eta 0:00:01
#      ---------                                2.4/10.5 MB 10.9 MB/s eta 0:00:01
#      -----------                              2.9/10.5 MB 10.9 MB/s eta 0:00:01
#      ------------                             3.4/10.5 MB 10.8 MB/s eta 0:00:01
#      --------------                           3.9/10.5 MB 10.8 MB/s eta 0:00:01
#      ----------------                         4.4/10.5 MB 10.8 MB/s eta 0:00:01
#      ------------------                       4.9/10.5 MB 10.7 MB/s eta 0:00:01
#      --------------------                     5.4/10.5 MB 10.7 MB/s eta 0:00:01
#      ----------------------                   5.9/10.5 MB 10.7 MB/s eta 0:00:01
#      ------------------------                 6.3/10.5 MB 10.7 MB/s eta 0:00:01
#      -------------------------                6.8/10.5 MB 10.9 MB/s eta 0:00:01
#      ---------------------------              7.3/10.5 MB 10.8 MB/s eta 0:00:01
#      -----------------------------            7.8/10.5 MB 10.9 MB/s eta 0:00:01
#      -------------------------------          8.3/10.5 MB 10.8 MB/s eta 0:00:01
#      ---------------------------------        8.8/10.5 MB 10.8 MB/s eta 0:00:01
#      -----------------------------------      9.3/10.5 MB 10.8 MB/s eta 0:00:01
#      -------------------------------------    9.8/10.5 MB 10.8 MB/s eta 0:00:01
#      --------------------------------------  10.3/10.5 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  10.5/10.5 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------- 10.5/10.5 MB 10.6 MB/s eta 0:00:00
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.6.3)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: psycopg2-binary in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.6)
# Collecting multitasking>=0.0.7 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached lxml-4.9.2-cp310-cp310-win_amd64.whl (3.8 MB)
# Collecting appdirs>=1.4.4 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting frozendict>=2.3.4 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached frozendict-2.3.8-cp310-cp310-win_amd64.whl (35 kB)
# Collecting beautifulsoup4>=4.11.1 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting html5lib>=1.1 (from yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: gym in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.26.1)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6)
#   Using cached pycares-4.3.0-cp310-cp310-win_amd64.whl (76 kB)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: colorama in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from click>=7.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.6)
# Collecting cffi>=1.12 (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6)
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Requirement already satisfied: osqp>=0.4.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: ecos>=2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.3)
# Collecting pandas-datareader>=0.2 (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Collecting nvidia-ml-py>=11.450.129 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading nvidia_ml_py-11.525.131-py3-none-any.whl (35 kB)
# Collecting blessed>=1.17.1 (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Collecting webencodings (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: backcall in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from pandas>=0.18.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached ale_py-0.8.1-cp310-cp310-win_amd64.whl (952 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (2.0.2)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#                                               0.0/182.1 kB ? eta -:--:--
#      ------------------------------------- 182.1/182.1 kB 10.7 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Downloading Werkzeug-2.3.6-py3-none-any.whl (242 kB)
#                                               0.0/242.5 kB ? eta -:--:--
#      -------------------------------------- 242.5/242.5 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.40.0)
# Collecting ply<4.0,>=3.4 (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6)
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting sympy (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting jinja2 (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting distlib<1,>=0.3.6 (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# Requirement already satisfied: platformdirs<4,>=2.4 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (3.5.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6)
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pygame (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached pygame-2.1.0-cp310-cp310-win_amd64.whl (4.8 MB)
# Requirement already satisfied: swig==4.* in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.1.1)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached pyrsistent-0.19.3-cp310-cp310-win_amd64.whl (62 kB)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#                                               0.0/120.5 kB ? eta -:--:--
#      -------------------------------------- 120.5/120.5 kB 6.9 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.0.1 (from pydantic->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading pydantic_core-2.0.1-cp310-none-win_amd64.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#      ------------                             0.5/1.5 MB 14.9 MB/s eta 0:00:01
#      -------------------------                1.0/1.5 MB 12.1 MB/s eta 0:00:01
#      ---------------------------------------  1.5/1.5 MB 11.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 11.9 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: importlib-resources in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.12.0)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.6)
# Collecting jinxed>=1.1.0 (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached jinxed-1.2.0-py2.py3-none-any.whl (33 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading googleapis_common_protos-1.59.1-py2.py3-none-any.whl (224 kB)
#                                               0.0/224.5 kB ? eta -:--:--
#      ------------------------------------- 224.5/224.5 kB 13.4 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: qdldl in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from osqp>=0.4.1->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Collecting mpmath>=0.19 (from sympy->torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting ansicon (from jinxed>=1.1.0->blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached ansicon-1.89.0-py2.py3-none-any.whl (63 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: finrl, elegantrl, box2d-py
#   Building wheel for finrl (pyproject.toml): started
#   Building wheel for finrl (pyproject.toml): finished with status 'done'
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4670209 sha256=720c4fb35e48bc0b8ec8aacb445b3f943085bbe4726ce0b96212bd95be457a70
#   Stored in directory: C:\Users\ansem\AppData\Local\Temp\pip-ephem-wheel-cache-ultsrtmp\wheels\72\3b\1a\0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for elegantrl (setup.py): started
#   Building wheel for elegantrl (setup.py): finished with status 'done'
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=198359 sha256=56db04d44cee798e63715760b5dc57ce0e99ff9da654f224f529baaa6ef67b3e
#   Stored in directory: C:\Users\ansem\AppData\Local\Temp\pip-ephem-wheel-cache-ultsrtmp\wheels\c0\51\a5\b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Successfully built finrl elegantrl
# Failed to build box2d-py
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git 'C:\Users\ansem\AppData\Local\Temp\pip-req-build-hqfm2bun'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-pus84ora\elegantrl_5c9e1100e3324630b14ccef00a97430d'
# WARNING: The candidate selected for download or install is a yanked version: 'aiohttp' candidate (version 3.8.2 at https://files.pythonhosted.org/packages/91/be/9a1eb0525c3216b08d9ba5ec23d7a5fdaec665316121d8c364934f7899d7/aiohttp-3.8.2-cp310-cp310-win_amd64.whl (from https://pypi.org/simple/aiohttp/) (requires-python:>=3.6))
# Reason for being yanked: This version includes overly restrictive multidict upper boundary disallowing multidict v6+. The previous patch version didn't have that and this is now causing dependency resolution problems for the users who have an "incompatible" version pinned. This is not really necessary anymore and will be addressed in the next release v3.8.3
#
# https://github.com/aio-libs/aiohttp/pull/6950
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 67.8.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-310
#       creating build\lib.win-amd64-cpython-310\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-310\Box2D
#       copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-310\Box2D
#       creating build\lib.win-amd64-cpython-310\Box2D\b2
#       copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-310\Box2D\b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#       swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#       Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#       Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#       Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#       Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#       Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#       Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Could not build wheels for box2d-py, which is required to install pyproject.toml-based projects

# %%
# %pip install -r requirements.txt --user
# %pip install SQLAlchemy==1.4.46
# Out:
# Collecting finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72 (from -r requirements.txt (line 12))
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git (to revision 423f45f39d31df862e20b1d95a4da714e94e3a72) to c:\users\ansem\appdata\local\temp\pip-install-ogt2ibfm\finrl_bf5adbdc03a243569123e481e3f62fbc
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 423f45f39d31df862e20b1d95a4da714e94e3a72
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl@68bf0ea4ef3fb461026ece8897deabb92aeead32 (from -r requirements.txt (line 13))
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\ansem\appdata\local\temp\pip-install-ogt2ibfm\elegantrl_33380b1f0c594532872a4aedb9d42c61
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 59fe4b4a1cca0a28e8a5fa4fb80eed9b5d472978
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gym@ git+https://github.com/openai/gym.git@9180d12e1b66e7e2a1a622614f787a6ec147ac40 (from -r requirements.txt (line 28))
#   Cloning https://github.com/openai/gym.git (to revision 9180d12e1b66e7e2a1a622614f787a6ec147ac40) to c:\users\ansem\appdata\local\temp\pip-install-ogt2ibfm\gym_cff93245b136404ab2e09b564c5dc4cc
#   Resolved https://github.com/openai/gym.git to commit 9180d12e1b66e7e2a1a622614f787a6ec147ac40
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: wrds==3.1.6 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 1)) (3.1.6)
# Collecting pandas==1.4.4 (from -r requirements.txt (line 2))
#   Downloading pandas-1.4.4-cp310-cp310-win_amd64.whl (10.0 MB)
#                                               0.0/10.0 MB ? eta -:--:--
#                                               0.0/10.0 MB ? eta -:--:--
#                                              0.0/10.0 MB 435.7 kB/s eta 0:00:23
#                                               0.2/10.0 MB 1.8 MB/s eta 0:00:06
#      --                                       0.6/10.0 MB 4.1 MB/s eta 0:00:03
#      ----                                     1.2/10.0 MB 5.6 MB/s eta 0:00:02
#      ------                                   1.6/10.0 MB 6.6 MB/s eta 0:00:02
#      --------                                 2.1/10.0 MB 7.5 MB/s eta 0:00:02
#      ----------                               2.6/10.0 MB 7.9 MB/s eta 0:00:01
#      ------------                             3.1/10.0 MB 8.3 MB/s eta 0:00:01
#      --------------                           3.6/10.0 MB 8.5 MB/s eta 0:00:01
#      ----------------                         4.1/10.0 MB 8.7 MB/s eta 0:00:01
#      ------------------                       4.6/10.0 MB 8.9 MB/s eta 0:00:01
#      --------------------                     5.0/10.0 MB 8.9 MB/s eta 0:00:01
#      ----------------------                   5.5/10.0 MB 9.1 MB/s eta 0:00:01
#      -----------------------                  5.9/10.0 MB 9.1 MB/s eta 0:00:01
#      -------------------------                6.4/10.0 MB 9.3 MB/s eta 0:00:01
#      ---------------------------              6.9/10.0 MB 9.4 MB/s eta 0:00:01
#      ------------------------------           7.5/10.0 MB 9.6 MB/s eta 0:00:01
#      --------------------------------         8.0/10.0 MB 9.6 MB/s eta 0:00:01
#      ----------------------------------       8.5/10.0 MB 9.7 MB/s eta 0:00:01
#      ------------------------------------     9.0/10.0 MB 9.7 MB/s eta 0:00:01
#      --------------------------------------   9.5/10.0 MB 9.8 MB/s eta 0:00:01
#      ---------------------------------------  10.0/10.0 MB 9.8 MB/s eta 0:00:01
#      ---------------------------------------- 10.0/10.0 MB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: scipy==1.10.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 3)) (1.10.1)
# Collecting sqlalchemy==1.4.46 (from -r requirements.txt (line 4))
#   Downloading SQLAlchemy-1.4.46-cp310-cp310-win_amd64.whl (1.6 MB)
#                                               0.0/1.6 MB ? eta -:--:--
#      -------------                            0.5/1.6 MB 11.1 MB/s eta 0:00:01
#      --------------------------               1.0/1.6 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------   1.5/1.6 MB 10.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 11.1 MB/s eta 0:00:00
# Collecting psycopg2-binary==2.9.5 (from -r requirements.txt (line 5))
#   Downloading psycopg2_binary-2.9.5-cp310-cp310-win_amd64.whl (1.2 MB)
#                                               0.0/1.2 MB ? eta -:--:--
#      -------------                            0.4/1.2 MB 12.2 MB/s eta 0:00:01
#      ------------------------------           0.9/1.2 MB 11.2 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 9.3 MB/s eta 0:00:00
# Collecting numpy==1.22.4 (from -r requirements.txt (line 6))
#   Using cached numpy-1.22.4-cp310-cp310-win_amd64.whl (14.7 MB)
# Requirement already satisfied: greenlet==2.0.2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 7)) (2.0.2)
# Collecting pytz==2022.7.1 (from -r requirements.txt (line 8))
#   Downloading pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
#                                               0.0/499.4 kB ? eta -:--:--
#      ----------------------------          389.1/499.4 kB 11.8 MB/s eta 0:00:01
#      ------------------------------------- 499.4/499.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil==2.8.2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 9)) (2.8.2)
# Collecting six==1.15.0 (from -r requirements.txt (line 10))
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: swig==4.1.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 11)) (4.1.1)
# Collecting pyfolio==0.9.2 (from -r requirements.txt (line 14))
#   Using cached pyfolio-0.9.2-py3-none-any.whl
# Collecting matplotlib==3.5.3 (from -r requirements.txt (line 15))
#   Downloading matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
#                                               0.0/7.2 MB ? eta -:--:--
#      --                                       0.5/7.2 MB 10.5 MB/s eta 0:00:01
#      -----                                    1.0/7.2 MB 10.6 MB/s eta 0:00:01
#      ------                                   1.2/7.2 MB 8.4 MB/s eta 0:00:01
#      -------                                  1.4/7.2 MB 7.5 MB/s eta 0:00:01
#      -----------                              2.0/7.2 MB 8.4 MB/s eta 0:00:01
#      ------------                             2.3/7.2 MB 8.2 MB/s eta 0:00:01
#      -----------------                        3.1/7.2 MB 9.9 MB/s eta 0:00:01
#      -------------------                      3.6/7.2 MB 10.0 MB/s eta 0:00:01
#      ---------------------                    3.8/7.2 MB 9.8 MB/s eta 0:00:01
#      ---------------------                    3.9/7.2 MB 8.7 MB/s eta 0:00:01
#      -----------------------                  4.2/7.2 MB 8.4 MB/s eta 0:00:01
#      --------------------------               4.7/7.2 MB 8.6 MB/s eta 0:00:01
#      ----------------------------             5.2/7.2 MB 8.8 MB/s eta 0:00:01
#      -------------------------------          5.7/7.2 MB 8.9 MB/s eta 0:00:01
#      ----------------------------------       6.2/7.2 MB 9.1 MB/s eta 0:00:01
#      -------------------------------------    6.7/7.2 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  7.2/7.2 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------- 7.2/7.2 MB 9.2 MB/s eta 0:00:00
# Collecting exchange_calendars==3.6.3 (from -r requirements.txt (line 16))
#   Using cached exchange_calendars-3.6.3.tar.gz (152 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ray[default,tune]==2.3.0 (from -r requirements.txt (line 17))
#   Downloading ray-2.3.0-cp310-cp310-win_amd64.whl (21.7 MB)
#                                               0.0/21.7 MB ? eta -:--:--
#                                               0.5/21.7 MB 14.2 MB/s eta 0:00:02
#      -                                        0.9/21.7 MB 11.7 MB/s eta 0:00:02
#      --                                       1.4/21.7 MB 11.3 MB/s eta 0:00:02
#      ---                                      1.9/21.7 MB 11.1 MB/s eta 0:00:02
#      ----                                     2.4/21.7 MB 11.0 MB/s eta 0:00:02
#      -----                                    2.9/21.7 MB 11.0 MB/s eta 0:00:02
#      ------                                   3.4/21.7 MB 10.9 MB/s eta 0:00:02
#      -------                                  3.9/21.7 MB 10.8 MB/s eta 0:00:02
#      --------                                 4.4/21.7 MB 10.8 MB/s eta 0:00:02
#      --------                                 4.9/21.7 MB 11.1 MB/s eta 0:00:02
#      ---------                                5.4/21.7 MB 11.1 MB/s eta 0:00:02
#      ----------                               5.9/21.7 MB 11.0 MB/s eta 0:00:02
#      -----------                              6.3/21.7 MB 11.0 MB/s eta 0:00:02
#      ------------                             6.6/21.7 MB 10.8 MB/s eta 0:00:02
#      ------------                             6.7/21.7 MB 10.0 MB/s eta 0:00:02
#      ------------                             6.9/21.7 MB 9.5 MB/s eta 0:00:02
#      ------------                             7.0/21.7 MB 9.3 MB/s eta 0:00:02
#      -------------                            7.1/21.7 MB 9.0 MB/s eta 0:00:02
#      -------------                            7.4/21.7 MB 8.6 MB/s eta 0:00:02
#      --------------                           7.8/21.7 MB 8.8 MB/s eta 0:00:02
#      ---------------                          8.3/21.7 MB 8.8 MB/s eta 0:00:02
#      ----------------                         8.8/21.7 MB 8.9 MB/s eta 0:00:02
#      -----------------                        9.3/21.7 MB 9.0 MB/s eta 0:00:02
#      ------------------                       9.8/21.7 MB 9.1 MB/s eta 0:00:02
#      ------------------                       10.2/21.7 MB 9.0 MB/s eta 0:00:02
#      -------------------                      10.8/21.7 MB 9.1 MB/s eta 0:00:02
#      --------------------                     11.3/21.7 MB 9.1 MB/s eta 0:00:02
#      ---------------------                    11.7/21.7 MB 9.1 MB/s eta 0:00:02
#      ----------------------                   12.1/21.7 MB 9.0 MB/s eta 0:00:02
#      ----------------------                   12.3/21.7 MB 8.8 MB/s eta 0:00:02
#      ----------------------                   12.5/21.7 MB 8.6 MB/s eta 0:00:02
#      -----------------------                  12.6/21.7 MB 8.4 MB/s eta 0:00:02
#      -----------------------                  12.8/21.7 MB 8.2 MB/s eta 0:00:02
#      -----------------------                  13.0/21.7 MB 8.0 MB/s eta 0:00:02
#      ------------------------                 13.1/21.7 MB 7.9 MB/s eta 0:00:02
#      ------------------------                 13.3/21.7 MB 7.7 MB/s eta 0:00:02
#      ------------------------                 13.5/21.7 MB 7.4 MB/s eta 0:00:02
#      -------------------------                13.7/21.7 MB 7.3 MB/s eta 0:00:02
#      -------------------------                13.9/21.7 MB 7.2 MB/s eta 0:00:02
#      --------------------------               14.3/21.7 MB 7.2 MB/s eta 0:00:02
#      ---------------------------              14.9/21.7 MB 7.2 MB/s eta 0:00:01
#      ----------------------------             15.4/21.7 MB 7.2 MB/s eta 0:00:01
#      -----------------------------            15.9/21.7 MB 7.2 MB/s eta 0:00:01
#      ------------------------------           16.3/21.7 MB 7.2 MB/s eta 0:00:01
#      ------------------------------           16.7/21.7 MB 7.1 MB/s eta 0:00:01
#      -------------------------------          17.0/21.7 MB 7.3 MB/s eta 0:00:01
#      -------------------------------          17.3/21.7 MB 7.5 MB/s eta 0:00:01
#      --------------------------------         17.5/21.7 MB 7.7 MB/s eta 0:00:01
#      --------------------------------         17.7/21.7 MB 7.7 MB/s eta 0:00:01
#      ---------------------------------        18.1/21.7 MB 7.6 MB/s eta 0:00:01
#      ----------------------------------       18.6/21.7 MB 7.6 MB/s eta 0:00:01
#      -----------------------------------      19.0/21.7 MB 7.5 MB/s eta 0:00:01
#      -----------------------------------      19.4/21.7 MB 7.4 MB/s eta 0:00:01
#      ------------------------------------     19.9/21.7 MB 7.4 MB/s eta 0:00:01
#      -------------------------------------    20.4/21.7 MB 7.5 MB/s eta 0:00:01
#      --------------------------------------   20.9/21.7 MB 7.5 MB/s eta 0:00:01
#      --------------------------------------   21.1/21.7 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  21.6/21.7 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------  21.7/21.7 MB 7.4 MB/s eta 0:00:01
#      ---------------------------------------- 21.7/21.7 MB 7.1 MB/s eta 0:00:00
# Collecting scikit-learn==1.2.2 (from -r requirements.txt (line 18))
#   Using cached scikit_learn-1.2.2-cp310-cp310-win_amd64.whl (8.3 MB)
# Collecting stable-baselines3==1.7.0 (from -r requirements.txt (line 19))
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl (171 kB)
#                                               0.0/171.8 kB ? eta -:--:--
#      ------------------------------------- 171.8/171.8 kB 10.8 MB/s eta 0:00:00
# Collecting gputil==1.4.0 (from -r requirements.txt (line 20))
#   Using cached GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting stockstats==0.5.2 (from -r requirements.txt (line 21))
#   Using cached stockstats-0.5.2-py2.py3-none-any.whl (20 kB)
# Collecting jqdatasdk==1.8.11 (from -r requirements.txt (line 22))
#   Using cached jqdatasdk-1.8.11-py3-none-any.whl (158 kB)
# Collecting ccxt==3.0.4 (from -r requirements.txt (line 23))
#   Downloading ccxt-3.0.4-py2.py3-none-any.whl (3.5 MB)
#                                               0.0/3.5 MB ? eta -:--:--
#      --                                       0.2/3.5 MB 7.3 MB/s eta 0:00:01
#      ----                                     0.4/3.5 MB 5.0 MB/s eta 0:00:01
#      ------                                   0.6/3.5 MB 4.7 MB/s eta 0:00:01
#      ---------                                0.8/3.5 MB 4.6 MB/s eta 0:00:01
#      ------------                             1.1/3.5 MB 5.0 MB/s eta 0:00:01
#      -----------------                        1.5/3.5 MB 5.7 MB/s eta 0:00:01
#      ----------------------                   2.0/3.5 MB 6.3 MB/s eta 0:00:01
#      ------------------------------           2.7/3.5 MB 7.5 MB/s eta 0:00:01
#      -------------------------------------    3.3/3.5 MB 8.0 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 8.0 MB/s eta 0:00:00
# Collecting yfinance==0.2.12 (from -r requirements.txt (line 24))
#   Downloading yfinance-0.2.12-py2.py3-none-any.whl (59 kB)
#                                               0.0/59.2 kB ? eta -:--:--
#      ---------------------------------------- 59.2/59.2 kB ? eta 0:00:00
# Collecting tensorboardX==2.6 (from -r requirements.txt (line 25))
#   Using cached tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
# Collecting alpaca_trade_api==3.0.0 (from -r requirements.txt (line 26))
#   Using cached alpaca_trade_api-3.0.0-py3-none-any.whl (33 kB)
# Collecting importlib-metadata==4.13.0 (from -r requirements.txt (line 27))
#   Using cached importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Collecting lz4==4.3.2 (from -r requirements.txt (line 30))
#   Using cached lz4-4.3.2-cp310-cp310-win_amd64.whl (99 kB)
# Collecting pyluach==2.2.0 (from -r requirements.txt (line 32))
#   Using cached pyluach-2.2.0-py3-none-any.whl (25 kB)
# Collecting korean-lunar-calendar==0.3.1 (from -r requirements.txt (line 33))
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting toolz==0.12.0 (from -r requirements.txt (line 34))
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: zipp==3.15.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 37)) (3.15.0)
# Collecting urllib3==1.26.14 (from -r requirements.txt (line 38))
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting msgpack==1.0.3 (from -r requirements.txt (line 39))
#   Using cached msgpack-1.0.3-cp310-cp310-win_amd64.whl (69 kB)
# Collecting requests==2.28.2 (from -r requirements.txt (line 40))
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting deprecation==2.1.0 (from -r requirements.txt (line 41))
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting websockets==10.4 (from -r requirements.txt (line 42))
#   Using cached websockets-10.4-cp310-cp310-win_amd64.whl (101 kB)
# Collecting aiohttp==3.8.1 (from -r requirements.txt (line 43))
#   Using cached aiohttp-3.8.1-cp310-cp310-win_amd64.whl (555 kB)
# Collecting PyYAML==6.0 (from -r requirements.txt (line 44))
#   Using cached PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
# Collecting websocket-client==1.5.1 (from -r requirements.txt (line 45))
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#                                               0.0/55.9 kB ? eta -:--:--
#      ---------------------------------------- 55.9/55.9 kB ? eta 0:00:00
# Collecting async-timeout==4.0.2 (from -r requirements.txt (line 46))
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal==1.3.1 (from -r requirements.txt (line 47))
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs==22.2.0 (from -r requirements.txt (line 48))
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting multidict==6.0.4 (from -r requirements.txt (line 49))
#   Using cached multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Collecting yarl==1.8.2 (from -r requirements.txt (line 50))
#   Downloading yarl-1.8.2-cp310-cp310-win_amd64.whl (56 kB)
#                                               0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Collecting frozenlist==1.3.3 (from -r requirements.txt (line 51))
#   Using cached frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Collecting charset-normalizer==2.1.1 (from -r requirements.txt (line 52))
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting packaging==23.0 (from -r requirements.txt (line 53))
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#                                               0.0/42.7 kB ? eta -:--:--
#      ---------------------------------------- 42.7/42.7 kB ? eta 0:00:00
# Collecting setuptools==65.5.0 (from -r requirements.txt (line 54))
#   Using cached setuptools-65.5.0-py3-none-any.whl (1.2 MB)
# Collecting cryptography==39.0.2 (from -r requirements.txt (line 55))
#   Downloading cryptography-39.0.2-cp36-abi3-win_amd64.whl (2.5 MB)
#                                               0.0/2.5 MB ? eta -:--:--
#      ------                                   0.4/2.5 MB 11.9 MB/s eta 0:00:01
#      -------------                            0.8/2.5 MB 10.5 MB/s eta 0:00:01
#      ------------------                       1.1/2.5 MB 10.1 MB/s eta 0:00:01
#      ------------------------                 1.5/2.5 MB 9.6 MB/s eta 0:00:01
#      -------------------------------          1.9/2.5 MB 9.3 MB/s eta 0:00:01
#      --------------------------------------   2.4/2.5 MB 9.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 9.2 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from -r requirements.txt (line 56))
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#                                               0.0/155.3 kB ? eta -:--:--
#      -------------------------------------- 155.3/155.3 kB 4.5 MB/s eta 0:00:00
# Collecting aiodns==3.0.0 (from -r requirements.txt (line 57))
#   Using cached aiodns-3.0.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: cloudpickle==2.2.1 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 58)) (2.2.1)
# Collecting virtualenv==20.21.0 (from -r requirements.txt (line 59))
#   Using cached virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
# Collecting filelock==3.9.0 (from -r requirements.txt (line 61))
#   Using cached filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting protobuf==3.19.6 (from -r requirements.txt (line 62))
#   Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl (895 kB)
#                                               0.0/895.7 kB ? eta -:--:--
#      ----------------                      409.6/895.7 kB 12.9 MB/s eta 0:00:01
#      ------------------------------------  890.9/895.7 kB 11.3 MB/s eta 0:00:01
#      ------------------------------------- 895.7/895.7 kB 11.4 MB/s eta 0:00:00
# Collecting jsonschema==4.3.3 (from -r requirements.txt (line 63))
#   Downloading jsonschema-4.3.3-py3-none-any.whl (71 kB)
#                                               0.0/71.9 kB ? eta -:--:--
#      ---------------------------------------- 71.9/71.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: click==8.1.3 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 64)) (8.1.3)
# Collecting tabulate==0.8.10 (from -r requirements.txt (line 65))
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Collecting smart-open==6.3.0 (from -r requirements.txt (line 66))
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting pydantic==1.10.6 (from -r requirements.txt (line 67))
#   Downloading pydantic-1.10.6-cp310-cp310-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      --------                                 0.5/2.1 MB 14.2 MB/s eta 0:00:01
#      -----------------                        0.9/2.1 MB 11.7 MB/s eta 0:00:01
#      --------------------------               1.4/2.1 MB 11.2 MB/s eta 0:00:01
#      ------------------------------------     1.9/2.1 MB 11.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 11.2 MB/s eta 0:00:00
# Collecting opencensus==0.11.2 (from -r requirements.txt (line 68))
#   Using cached opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
# Collecting py-spy==0.3.14 (from -r requirements.txt (line 69))
#   Using cached py_spy-0.3.14-py2.py3-none-win_amd64.whl (1.4 MB)
# Collecting aiohttp-cors==0.7.0 (from -r requirements.txt (line 70))
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting prometheus-client==0.16.0 (from -r requirements.txt (line 71))
#   Downloading prometheus_client-0.16.0-py3-none-any.whl (122 kB)
#                                               0.0/122.5 kB ? eta -:--:--
#      -------------------------------------- 122.5/122.5 kB 7.0 MB/s eta 0:00:00
# Collecting gpustat==1.0.0 (from -r requirements.txt (line 72))
#   Downloading gpustat-1.0.0.tar.gz (90 kB)
#                                               0.0/90.5 kB ? eta -:--:--
#      ---------------------------------------- 90.5/90.5 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting colorful==0.5.5 (from -r requirements.txt (line 73))
#   Using cached colorful-0.5.5-py2.py3-none-any.whl (201 kB)
# Collecting threadpoolctl==3.1.0 (from -r requirements.txt (line 74))
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib==1.1.1 (from -r requirements.txt (line 75))
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
#                                               0.0/309.8 kB ? eta -:--:--
#      -------------------------------------- 309.8/309.8 kB 9.4 MB/s eta 0:00:00
# Collecting torch==1.13.1 (from -r requirements.txt (line 77))
#   Using cached torch-1.13.1-cp310-cp310-win_amd64.whl (162.6 MB)
# Collecting pymysql==1.0.2 (from -r requirements.txt (line 78))
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Collecting thriftpy2==0.4.16 (from -r requirements.txt (line 81))
#   Using cached thriftpy2-0.4.16-py2.py3-none-any.whl
# Requirement already satisfied: kiwisolver==1.4.4 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 82)) (1.4.4)
# Collecting pillow==8.4.0 (from -r requirements.txt (line 83))
#   Downloading Pillow-8.4.0-cp310-cp310-win_amd64.whl (3.2 MB)
#                                               0.0/3.2 MB ? eta -:--:--
#      ------                                   0.5/3.2 MB 10.7 MB/s eta 0:00:01
#      ------------                             1.0/3.2 MB 10.5 MB/s eta 0:00:01
#      ------------------                       1.5/3.2 MB 12.0 MB/s eta 0:00:01
#      ------------------------                 2.0/3.2 MB 11.5 MB/s eta 0:00:01
#      ---------------------------              2.2/3.2 MB 10.2 MB/s eta 0:00:01
#      ------------------------------           2.4/3.2 MB 9.1 MB/s eta 0:00:01
#      --------------------------------         2.6/3.2 MB 8.4 MB/s eta 0:00:01
#      -------------------------------------    3.0/3.2 MB 8.3 MB/s eta 0:00:01
#      ---------------------------------------- 3.2/3.2 MB 7.9 MB/s eta 0:00:00
# Collecting fonttools==4.39.0 (from -r requirements.txt (line 84))
#   Downloading fonttools-4.39.0-py3-none-any.whl (1.0 MB)
#                                               0.0/1.0 MB ? eta -:--:--
#      ------------                             0.3/1.0 MB 18.6 MB/s eta 0:00:01
#      --------------------------------         0.8/1.0 MB 12.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: cycler==0.11.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 85)) (0.11.0)
# Requirement already satisfied: pyparsing==3.0.9 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 86)) (3.0.9)
# Collecting ipython==7.9.0 (from -r requirements.txt (line 87))
#   Downloading ipython-7.9.0-py3-none-any.whl (775 kB)
#                                               0.0/775.3 kB ? eta -:--:--
#      ---------------                        317.4/775.3 kB 6.5 MB/s eta 0:00:01
#      ------------------------------         614.4/775.3 kB 7.7 MB/s eta 0:00:01
#      -------------------------------------- 775.3/775.3 kB 7.0 MB/s eta 0:00:00
# Collecting seaborn==0.11.2 (from -r requirements.txt (line 88))
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting empyrical==0.5.5 (from -r requirements.txt (line 89))
#   Using cached empyrical-0.5.5-py3-none-any.whl
# Collecting multitasking==0.0.11 (from -r requirements.txt (line 90))
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting appdirs==1.4.4 (from -r requirements.txt (line 91))
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting beautifulsoup4==4.11.2 (from -r requirements.txt (line 92))
#   Using cached beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
# Collecting frozendict==2.3.5 (from -r requirements.txt (line 93))
#   Downloading frozendict-2.3.5-cp310-cp310-win_amd64.whl (35 kB)
# Collecting html5lib==1.1 (from -r requirements.txt (line 94))
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Collecting lxml==4.9.2 (from -r requirements.txt (line 95))
#   Using cached lxml-4.9.2-cp310-cp310-win_amd64.whl (3.8 MB)
# Collecting pycares==4.3.0 (from -r requirements.txt (line 96))
#   Using cached pycares-4.3.0-cp310-cp310-win_amd64.whl (76 kB)
# Collecting soupsieve==2.4 (from -r requirements.txt (line 97))
#   Using cached soupsieve-2.4-py3-none-any.whl (37 kB)
# Collecting cffi==1.15.1 (from -r requirements.txt (line 98))
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Collecting pandas-datareader==0.10.0 (from -r requirements.txt (line 99))
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Collecting nvidia-ml-py==11.495.46 (from -r requirements.txt (line 100))
#   Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Collecting psutil==5.9.4 (from -r requirements.txt (line 101))
#   Downloading psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
#                                               0.0/252.5 kB ? eta -:--:--
#      -------------------------------------- 252.5/252.5 kB 7.8 MB/s eta 0:00:00
# Collecting blessed==1.20.0 (from -r requirements.txt (line 102))
#   Using cached blessed-1.20.0-py2.py3-none-any.whl (58 kB)
# Collecting webencodings==0.5.1 (from -r requirements.txt (line 103))
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pickleshare==0.7.5 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 104)) (0.7.5)
# Collecting prompt-toolkit==2.0.10 (from -r requirements.txt (line 105))
#   Downloading prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
#                                               0.0/340.0 kB ? eta -:--:--
#      ------------------------------------- 340.0/340.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: backcall==0.2.0 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 106)) (0.2.0)
# Collecting pexpect==4.8.0 (from -r requirements.txt (line 107))
#   Using cached pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Requirement already satisfied: jedi==0.18.2 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 108)) (0.18.2)
# Collecting traitlets==5.7.1 (from -r requirements.txt (line 109))
#   Downloading traitlets-5.7.1-py3-none-any.whl (109 kB)
#                                               0.0/109.9 kB ? eta -:--:--
#      ---------------------------------------- 109.9/109.9 kB ? eta 0:00:00
# Collecting decorator==4.4.2 (from -r requirements.txt (line 110))
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting pygments==2.6.1 (from -r requirements.txt (line 111))
#   Downloading Pygments-2.6.1-py3-none-any.whl (914 kB)
#                                               0.0/914.4 kB ? eta -:--:--
#      -----------------                     430.1/914.4 kB 13.5 MB/s eta 0:00:01
#      ------------------------------------  911.4/914.4 kB 11.6 MB/s eta 0:00:01
#      -------------------------------------- 914.4/914.4 kB 9.6 MB/s eta 0:00:00
# Collecting idna==2.10 (from -r requirements.txt (line 112))
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#                                               0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Collecting ply==3.11 (from -r requirements.txt (line 114))
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Collecting typing-extensions==4.5.0 (from -r requirements.txt (line 115))
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting distlib==0.3.6 (from -r requirements.txt (line 116))
#   Using cached distlib-0.3.6-py2.py3-none-any.whl (468 kB)
# Collecting platformdirs==3.1.0 (from -r requirements.txt (line 117))
#   Downloading platformdirs-3.1.0-py3-none-any.whl (14 kB)
# Collecting pyglet==2.0.5 (from -r requirements.txt (line 118))
#   Downloading pyglet-2.0.5-py3-none-any.whl (831 kB)
#                                               0.0/831.3 kB ? eta -:--:--
#      -----                                  122.9/831.3 kB 3.6 MB/s eta 0:00:01
#      ----------------------------           624.6/831.3 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------  829.4/831.3 kB 8.7 MB/s eta 0:00:01
#      -------------------------------------- 831.3/831.3 kB 5.8 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5 (from -r requirements.txt (line 119))
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrsistent==0.19.3 (from -r requirements.txt (line 120))
#   Using cached pyrsistent-0.19.3-cp310-cp310-win_amd64.whl (62 kB)
# Collecting opencensus-context==0.1.3 (from -r requirements.txt (line 121))
#   Using cached opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Collecting google-api-core==2.11.0 (from -r requirements.txt (line 122))
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Requirement already satisfied: wcwidth==0.2.6 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 123)) (0.2.6)
# Collecting pycparser==2.21 (from -r requirements.txt (line 124))
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting googleapis-common-protos==1.58.0 (from -r requirements.txt (line 125))
#   Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
#                                               0.0/223.0 kB ? eta -:--:--
#      ------------------------------------- 223.0/223.0 kB 13.3 MB/s eta 0:00:00
# Collecting google-auth==2.16.2 (from -r requirements.txt (line 126))
#   Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
#                                               0.0/177.2 kB ? eta -:--:--
#      -------------------------------------- 177.2/177.2 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: parso==0.8.3 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from -r requirements.txt (line 127)) (0.8.3)
# Collecting ptyprocess==0.7.0 (from -r requirements.txt (line 128))
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting cachetools==5.3.0 (from -r requirements.txt (line 129))
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules==0.2.8 (from -r requirements.txt (line 130))
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa==4.9 (from -r requirements.txt (line 131))
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1==0.4.8 (from -r requirements.txt (line 132))
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting tensorboard (from -r requirements.txt (line 134))
#   Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Collecting grpcio>=1.42.0 (from ray[default,tune]==2.3.0->-r requirements.txt (line 17))
#   Downloading grpcio-1.56.0-cp310-cp310-win_amd64.whl (4.2 MB)
#                                               0.0/4.2 MB ? eta -:--:--
#      -                                        0.2/4.2 MB 5.3 MB/s eta 0:00:01
#      -----                                    0.6/4.2 MB 7.1 MB/s eta 0:00:01
#      -----------                              1.2/4.2 MB 9.3 MB/s eta 0:00:01
#      -----------------                        1.9/4.2 MB 10.7 MB/s eta 0:00:01
#      ----------------------                   2.3/4.2 MB 10.6 MB/s eta 0:00:01
#      --------------------------               2.8/4.2 MB 10.6 MB/s eta 0:00:01
#      -------------------------------          3.3/4.2 MB 11.1 MB/s eta 0:00:01
#      -----------------------------------      3.8/4.2 MB 11.0 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 10.8 MB/s eta 0:00:01
#      ---------------------------------------- 4.2/4.2 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from click==8.1.3->-r requirements.txt (line 64)) (0.4.6)
# Collecting jinxed>=1.1.0 (from blessed==1.20.0->-r requirements.txt (line 102))
#   Using cached jinxed-1.2.0-py2.py3-none-any.whl (33 kB)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72->-r requirements.txt (line 12))
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\ansem\appdata\local\temp\pip-install-ogt2ibfm\elegantrl_a7a37d666ce4494a96a195f81a5c1bdf
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 59fe4b4a1cca0a28e8a5fa4fb80eed9b5d472978
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2 (from finrl@ git+https://github.com/AI4Finance-Foundation/FinRL.git@423f45f39d31df862e20b1d95a4da714e94e3a72->-r requirements.txt (line 12))
#   Cloning https://github.com/quantopian/pyfolio.git to c:\users\ansem\appdata\local\temp\pip-install-ogt2ibfm\pyfolio_5c30297b3bce4175af6689f6fd10c916
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting absl-py>=0.4 (from tensorboard->-r requirements.txt (line 134))
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard->-r requirements.txt (line 134))
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard->-r requirements.txt (line 134))
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->-r requirements.txt (line 134))
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->-r requirements.txt (line 134))
#   Using cached Werkzeug-2.3.6-py3-none-any.whl (242 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from tensorboard->-r requirements.txt (line 134)) (0.40.0)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 134))
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting ansicon (from jinxed>=1.1.0->blessed==1.20.0->-r requirements.txt (line 102))
#   Using cached ansicon-1.89.0-py2.py3-none-any.whl (63 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 134))
#   Using cached MarkupSafe-2.1.3-cp310-cp310-win_amd64.whl (17 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 134))
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: exchange_calendars, gputil, gym, gpustat, box2d-py, finrl, pyfolio, elegantrl
#   Building wheel for exchange_calendars (setup.py): started
#   Building wheel for exchange_calendars (setup.py): finished with status 'done'
#   Created wheel for exchange_calendars: filename=exchange_calendars-3.6.3-py3-none-any.whl size=182662 sha256=6fc8cc34a3ee2332398734b97fcba5762bd4b71024e7c911d147610d4580c036
#   Stored in directory: c:\users\ansem\appdata\local\pip\cache\wheels\93\ca\8f\1e1c90cc79fb3ca9b5413ff58e3fccf3baf2182c994c6dfd37
#   Building wheel for gputil (setup.py): started
#   Building wheel for gputil (setup.py): finished with status 'done'
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7401 sha256=13412bfe25086dea23b2ecb106cee8e73c177f2688b66acc696f37f579afdf06
#   Stored in directory: c:\users\ansem\appdata\local\pip\cache\wheels\a9\8a\bd\81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1625706 sha256=fc408cd2f7c05e765fc38adb92bcf390aa3dac116679b1f6a814ec22e6df39ec
#   Stored in directory: c:\users\ansem\appdata\local\pip\cache\wheels\f0\ee\c0\6742dc49f0af8513cbebcc9e5bccce66351fad2f8e093e3301
#   Building wheel for gpustat (setup.py): started
#   Building wheel for gpustat (setup.py): finished with status 'done'
#   Created wheel for gpustat: filename=gpustat-1.0.0-py3-none-any.whl size=19897 sha256=738b2038beeeafb290b7f23d53a046e20b52ac4fccd050e5b84e91b83e71e6e1
#   Stored in directory: c:\users\ansem\appdata\local\pip\cache\wheels\d2\48\27\33e31726d2001b997a11c23a7c76f7a48d8d96851f14ef0cd2
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
#   Building wheel for finrl (pyproject.toml): started
#   Building wheel for finrl (pyproject.toml): finished with status 'done'
#   Created wheel for finrl: filename=finrl-0.3.5-py3-none-any.whl size=2861819 sha256=240002b7cc75d4d4841400f6f875edaff568138699363a66f843eb9c7b943a45
#   Stored in directory: c:\users\ansem\appdata\local\pip\cache\wheels\1b\6a\36\74b427e0b410fe55ed3616e6f1c72eb80e762fe88bdb1f02dc
#   Building wheel for pyfolio (setup.py): started
#   Building wheel for pyfolio (setup.py): finished with status 'done'
#   Created wheel for pyfolio: filename=pyfolio-0.9.2+75.g4b901f6-py3-none-any.whl size=76272 sha256=c5d4c02d40c3463653e7f0bdd9347b774554c9ea1de911f27759b4c90642ce46
#   Stored in directory: C:\Users\ansem\AppData\Local\Temp\pip-ephem-wheel-cache-lw163fuh\wheels\c4\1d\91\8ab5d1c88a11b06a63dcd6a69ea81547e2247123232949bb26
#   Building wheel for elegantrl (setup.py): started
#   Building wheel for elegantrl (setup.py): finished with status 'done'
#   Created wheel for elegantrl: filename=elegantrl-0.3.6-py3-none-any.whl size=198359 sha256=c8cede56505fde62a72aabc0e614c11be87a07682722feb69669919535b30bc6
#   Stored in directory: C:\Users\ansem\AppData\Local\Temp\pip-ephem-wheel-cache-lw163fuh\wheels\c0\51\a5\b05f165548221bc570f7223babd33e2992fa873cdcebe2d229
# Successfully built exchange_calendars gputil gym gpustat finrl pyfolio elegantrl
# Failed to build box2d-py
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl@68bf0ea4ef3fb461026ece8897deabb92aeead32 contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-ogt2ibfm\finrl_bf5adbdc03a243569123e481e3f62fbc'
#   Running command git rev-parse -q --verify 'sha^423f45f39d31df862e20b1d95a4da714e94e3a72'
#   Running command git fetch -q https://github.com/AI4Finance-Foundation/FinRL.git 423f45f39d31df862e20b1d95a4da714e94e3a72
#   Running command git checkout -q 423f45f39d31df862e20b1d95a4da714e94e3a72
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-ogt2ibfm\elegantrl_33380b1f0c594532872a4aedb9d42c61'
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/gym.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-ogt2ibfm\gym_cff93245b136404ab2e09b564c5dc4cc'
#   Running command git rev-parse -q --verify 'sha^9180d12e1b66e7e2a1a622614f787a6ec147ac40'
#   Running command git fetch -q https://github.com/openai/gym.git 9180d12e1b66e7e2a1a622614f787a6ec147ac40
#   Running command git checkout -q 9180d12e1b66e7e2a1a622614f787a6ec147ac40
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-ogt2ibfm\elegantrl_a7a37d666ce4494a96a195f81a5c1bdf'
#   Running command git clone --filter=blob:none --quiet https://github.com/quantopian/pyfolio.git 'C:\Users\ansem\AppData\Local\Temp\pip-install-ogt2ibfm\pyfolio_5c30297b3bce4175af6689f6fd10c916'
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 67.8.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-310
#       creating build\lib.win-amd64-cpython-310\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-310\Box2D
#       copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-310\Box2D
#       creating build\lib.win-amd64-cpython-310\Box2D\b2
#       copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-310\Box2D\b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#       swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#       Box2D\Common\b2Math.h(67) : Warning 302: Identifier 'b2Vec2' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#       Box2D\Common\b2Math.h(158) : Warning 302: Identifier 'b2Vec3' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#       Box2D\Common\b2Math.h(197) : Warning 302: Identifier 'b2Mat22' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#       Box2D\Common\b2Math.h(271) : Warning 302: Identifier 'b2Mat33' redefined by %extend (ignored),
#       Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#       Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#       Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Could not build wheels for box2d-py, which is required to install pyproject.toml-based projects
# Collecting SQLAlchemy==1.4.46
#   Using cached SQLAlchemy-1.4.46-cp310-cp310-win_amd64.whl (1.6 MB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ansem\anaconda3\envs\ai4finance\lib\site-packages (from SQLAlchemy==1.4.46) (2.0.2)
# Installing collected packages: SQLAlchemy
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 1.4.48
#     Uninstalling SQLAlchemy-1.4.48:
#       Successfully uninstalled SQLAlchemy-1.4.48
# Successfully installed SQLAlchemy-1.4.46
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from stable_baselines3.common.logger import configure
from finrl.meta.data_processor import DataProcessor

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\compat\__init__.py:25
#      17 from pandas.compat._constants import (
#      18     IS64,
#      19     PY39,
#    (...)
#      22     PYPY,
#      23 )
#      24 import pandas.compat.compressors
# ---> 25 from pandas.compat.numpy import (
#      26     is_numpy_dev,
#      27     np_version_under1p21,
#      28 )
#      29 from pandas.compat.pyarrow import (
#      30     pa_version_under7p0,
#      31     pa_version_under8p0,
#      32     pa_version_under9p0,
#      33     pa_version_under11p0,
#      34 )
#      37 def set_function_name(f: F, name: str, cls) -> F:
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\compat\numpy\__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\util\__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\util\_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File c:\Users\ansem\anaconda3\envs\ai4finance\lib\site-packages\pandas\_libs\__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# ModuleNotFoundError: No module named 'pandas._libs.interval'

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %%
#model
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# instantiate train/test date
TRAIN_START_DATE = '2009-01-01' #실제 시작 시점은 2010년 0101이나, prediction용 1년치 추가함.
PREDICTION_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TRADE_START_DATE = '2021-10-01'
TRADE_END_DATE = '2023-05-05'

# %%
# preprocess 
import yfinance as yf

ticker = ['XLB','XLE','XLF','XLI','XLK','XLP','XLU','XLV','XLY']
stocks = yf.download(ticker, start = TRAIN_START_DATE, end = TRADE_END_DATE )

df =  YahooDownloader(start_date = TRAIN_START_DATE,
                      end_date = TRADE_END_DATE,
                      ticker_list = ticker).fetch_data()
# Out:
# [*********************100%***********************]  9 of 9 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (32481, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume  tic  day
# 0  2009-01-02  22.900000  23.709999  22.690001  17.207548    7110000  XLB    4
# 1  2009-01-02  48.200001  50.669998  48.080002  31.549149   34283700  XLE    4
# 2  2009-01-02  10.178716  10.406174   9.918765   7.878148  117919090  XLF    4
# 3  2009-01-02  23.520000  24.420000  23.270000  18.167879    6659500  XLI    4
# 4  2009-01-02  15.500000  16.070000  15.380000  12.912431    4479800  XLK    4

# %%
fe = FeatureEngineer(
    use_technical_indicator = True,
    tech_indicator_list = INDICATORS,
    use_vix=True,
    use_turbulence=True,
    user_defined_feature=False
)
processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3608, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
processed.head()
# Out:
#          date       open       high        low      close     volume  tic  \
# 0  2009-01-02  22.900000  23.709999  22.690001  17.207548    7110000  XLB
# 1  2009-01-02  48.200001  50.669998  48.080002  31.549149   34283700  XLE
# 2  2009-01-02  10.178716  10.406174   9.918765   7.878148  117919090  XLF
# 3  2009-01-02  23.520000  24.420000  23.270000  18.167879    6659500  XLI
# 4  2009-01-02  15.500000  16.070000  15.380000  12.912431    4479800  XLK
#
#    day  macd    boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0    4   0.0  17.277415  17.17418   100.0  66.666667  100.0     17.207548
# 1    4   0.0  17.277415  17.17418   100.0  66.666667  100.0     31.549149
# 2    4   0.0  17.277415  17.17418   100.0  66.666667  100.0      7.878148
# 3    4   0.0  17.277415  17.17418   100.0  66.666667  100.0     18.167879
# 4    4   0.0  17.277415  17.17418   100.0  66.666667  100.0     12.912431
#
#    close_60_sma        vix  turbulence
# 0     17.207548  39.189999         0.0
# 1     31.549149  39.189999         0.0
# 2      7.878148  39.189999         0.0
# 3     18.167879  39.189999         0.0
# 4     12.912431  39.189999         0.0

# %%
list_ticker = processed["tic"].unique().tolist() # ticker list
list_date = list(pd.date_range(processed['date'].min(), processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

process_full = pd.DataFrame(combination, columns=['date','tic']).merge(processed, on=['date','tic'],how='left')
process_full = process_full[process_full['date'].isin(processed['date'])]
process_full = process_full.sort_values(['date','tic'])

process_full = process_full.fillna(0)

mvo_df = process_full.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
mvo_df.head(10) # 종가만
# Out:
#          date  tic      close
# 0  2009-01-02  XLB  17.207548
# 1  2009-01-02  XLE  31.549149
# 2  2009-01-02  XLF   7.878148
# 3  2009-01-02  XLI  18.167879
# 4  2009-01-02  XLK  12.912431
# 5  2009-01-02  XLP  16.372381
# 6  2009-01-02  XLU  17.672314
# 7  2009-01-02  XLV  21.070589
# 8  2009-01-02  XLY  18.663010
# 9  2009-01-05  XLB  17.244047

# %%
process_full.head()
# Out:
#          date  tic       open       high        low      close       volume  \
# 0  2009-01-02  XLB  22.900000  23.709999  22.690001  17.207548    7110000.0
# 1  2009-01-02  XLE  48.200001  50.669998  48.080002  31.549149   34283700.0
# 2  2009-01-02  XLF  10.178716  10.406174   9.918765   7.878148  117919090.0
# 3  2009-01-02  XLI  23.520000  24.420000  23.270000  18.167879    6659500.0
# 4  2009-01-02  XLK  15.500000  16.070000  15.380000  12.912431    4479800.0
#
#    day  macd    boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  17.277415  17.17418   100.0  66.666667  100.0     17.207548
# 1  4.0   0.0  17.277415  17.17418   100.0  66.666667  100.0     31.549149
# 2  4.0   0.0  17.277415  17.17418   100.0  66.666667  100.0      7.878148
# 3  4.0   0.0  17.277415  17.17418   100.0  66.666667  100.0     18.167879
# 4  4.0   0.0  17.277415  17.17418   100.0  66.666667  100.0     12.912431
#
#    close_60_sma        vix  turbulence
# 0     17.207548  39.189999         0.0
# 1     31.549149  39.189999         0.0
# 2      7.878148  39.189999         0.0
# 3     18.167879  39.189999         0.0
# 4     12.912431  39.189999         0.0

# %%
# # data split
# train = data_split(process_full, TRAIN_START_DATE, TRAIN_END_DATE)
# trade = data_split(process_full, TRADE_START_DATE, TRADE_END_DATE)
# print(len(train))
# print(len(trade))
# Out:
# 28881
# 3591

# %% [markdown]
# # DLinear prediction

# %%
#종가 기준 Datasetting

data_for_pred = pd.DataFrame(index = range(len(df[df.tic==ticker[0]])), columns = ticker)
data_for_pred['date'] = df.date.unique()
for tic in ticker:
    data_for_pred[tic] = df[df.tic==tic].close.values
    
data_for_pred.head()
# Out:
#          XLB        XLE       XLF        XLI        XLK        XLP        XLU  \
# 0  17.207548  31.549149  7.878148  18.167879  12.912431  16.372381  17.672314
# 1  17.244047  32.291496  7.747468  18.025703  12.872057  16.440002  17.922136
# 2  17.630983  32.643784  7.871925  18.422297  13.170845  16.196550  17.666365
# 3  17.222151  31.259777  7.461215  17.599194  12.750927  16.034250  17.523602
# 4  17.463058  31.662390  7.430102  17.771299  12.839750  15.824604  17.434368
#
#          XLV        XLY        date
# 0  21.070589  18.663010  2009-01-02
# 1  20.969467  18.580608  2009-01-05
# 2  20.627235  18.893719  2009-01-06
# 3  20.440565  18.143909  2009-01-07
# 4  20.557240  18.251019  2009-01-08

# %%
prediction_start_index = data_for_pred[data_for_pred['date'] >= PREDICTION_START_DATE].index[0] 
test_start_index = data_for_pred[data_for_pred['date'] >= TRADE_START_DATE].index[0]

print(prediction_start_index)
print(test_start_index)
# Out:
# 252
# 3209

# %%
idx_date = data_for_pred['date']
def idx_date_mapper(idx_list):
    date_list = []
    for idx in idx_list:
        date_list.append(idx_date[idx])
    return date_list

data_for_pred = data_for_pred.drop('date',axis=1)
data_for_pred.head()
# Out:
#          XLB        XLE       XLF        XLI        XLK        XLP        XLU  \
# 0  17.207548  31.549149  7.878148  18.167879  12.912431  16.372381  17.672314
# 1  17.244047  32.291496  7.747468  18.025703  12.872057  16.440002  17.922136
# 2  17.630983  32.643784  7.871925  18.422297  13.170845  16.196550  17.666365
# 3  17.222151  31.259777  7.461215  17.599194  12.750927  16.034250  17.523602
# 4  17.463058  31.662390  7.430102  17.771299  12.839750  15.824604  17.434368
#
#          XLV        XLY
# 0  21.070589  18.663010
# 1  20.969467  18.580608
# 2  20.627235  18.893719
# 3  20.440565  18.143909
# 4  20.557240  18.251019

# %%
# Hyperparameters
WINDOW_SIZE = prediction_start_index
FORCAST_SIZE = 30
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


train_dataset = data_for_pred[:test_start_index]
test_dataset = data_for_pred[test_start_index-WINDOW_SIZE:]

print(len(train_dataset),len(test_dataset))
# Out:
# 3209 652

# %%
class moving_avg(torch.nn.Module):
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = torch.nn.AvgPool1d(kernel_size=kernel_size, stride=stride, padding=0)

    def forward(self, x):
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        x = torch.cat([front, x, end], dim=1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x

class series_decomp(torch.nn.Module):
    def __init__(self, kernel_size):
        super(series_decomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride=1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        residual = x - moving_mean
        return moving_mean, residual 
        
class LTSF_DLinear(torch.nn.Module):
    def __init__(self, window_size, forcast_size, kernel_size, individual, feature_size):
        super(LTSF_DLinear, self).__init__()
        self.window_size = window_size
        self.forcast_size = forcast_size
        self.decompsition = series_decomp(kernel_size)
        self.individual = individual
        self.channels = feature_size
        if self.individual:
            self.Linear_Seasonal = torch.nn.ModuleList()
            self.Linear_Trend = torch.nn.ModuleList()
            for i in range(self.channels):
                self.Linear_Trend.append(torch.nn.Linear(self.window_size, self.forcast_size))
                self.Linear_Trend[i].weight = torch.nn.Parameter((1/self.window_size)*torch.ones([self.forcast_size, self.window_size]))
                self.Linear_Seasonal.append(torch.nn.Linear(self.window_size, self.forcast_size))
                self.Linear_Seasonal[i].weight = torch.nn.Parameter((1/self.window_size)*torch.ones([self.forcast_size, self.window_size]))
        else:
            self.Linear_Trend = torch.nn.Linear(self.window_size, self.forcast_size)
            self.Linear_Trend.weight = torch.nn.Parameter((1/self.window_size)*torch.ones([self.forcast_size, self.window_size]))
            self.Linear_Seasonal = torch.nn.Linear(self.window_size,  self.forcast_size)
            self.Linear_Seasonal.weight = torch.nn.Parameter((1/self.window_size)*torch.ones([self.forcast_size, self.window_size]))

    def forward(self, x):
        trend_init, seasonal_init = self.decompsition(x)
        trend_init, seasonal_init = trend_init.permute(0,2,1), seasonal_init.permute(0,2,1)
        if self.individual:
            trend_output = torch.zeros([trend_init.size(0), trend_init.size(1), self.forcast_size], dtype=trend_init.dtype).to(trend_init.device)
            seasonal_output = torch.zeros([seasonal_init.size(0), seasonal_init.size(1), self.forcast_size], dtype=seasonal_init.dtype).to(seasonal_init.device)
            for idx in range(self.channels):
                trend_output[:, idx, :] = self.Linear_Trend[idx](trend_init[:, idx, :])
                seasonal_output[:, idx, :] = self.Linear_Seasonal[idx](seasonal_init[:, idx, :])                
        else:
            trend_output = self.Linear_Trend(trend_init)
            seasonal_output = self.Linear_Seasonal(seasonal_init)
        x = seasonal_output + trend_output
        return x.permute(0,2,1)

# %%
class Windowed_Dataset(Dataset):
    def __init__(self, data, window_size, forcast_size):
        self.data = data
        self.window_size = window_size
        self.forcast_size = forcast_size
        
    def __len__(self):
        return len(self.data) - self.window_size - self.forcast_size
    
    def __getitem__(self, idx):
        return torch.from_numpy(self.data[idx:idx+self.window_size].values).type(torch.FloatTensor), torch.from_numpy(self.data[idx+self.window_size:idx+self.window_size+self.forcast_size].values).type(torch.FloatTensor)

# %%
WD_train = Windowed_Dataset(train_dataset, WINDOW_SIZE, FORCAST_SIZE)
WD_test = Windowed_Dataset(test_dataset, WINDOW_SIZE, FORCAST_SIZE)
WD_all = Windowed_Dataset(data_for_pred, WINDOW_SIZE, FORCAST_SIZE)

train_loader = DataLoader(WD_train, batch_size=32, shuffle=False)
test_loader = DataLoader(WD_test, batch_size=32, shuffle=False)
all_loader = DataLoader(WD_all, batch_size=32, shuffle=False)

print(len(WD_train), len(WD_test), len(WD_all))
# Out:
# 2927 370 3327

# %%
import tqdm
model = LTSF_DLinear(WINDOW_SIZE, FORCAST_SIZE, 25, True, len(ticker))
model = model.to(device)

criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train(model, train_loader, criterion, optimizer, device, epochs, tolerance=0.0001):
    model.train()
    train_loss = 0
    for epoch in tqdm(range(epochs)):
        for X, y in train_loader:
            X = X.to(device)
            y = y.to(device)
            optimizer.zero_grad()
            output = model(X)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        if epoch % 10 == 0:
            print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch+1, loss.item()))
        if train_loss < tolerance:
            print('Training Loss: {:.6f}'.format(loss.item()))
            break
        train_loss = 0
            
    return model
            
def test(model, test_loader, criterion, device):
    model.eval()
    test_loss = 0
    predictions = []
    for X, y in tqdm(test_loader):
        X = X.to(device)
        y = y.to(device)
        with torch.no_grad():
            output = model(X)
            loss = criterion(output, y)
            test_loss += loss.item()
            predictions.append(output)
        
    print('Test Loss: {:.6f}'.format(loss.item()))
    return predictions

# %% [markdown]
# 여기서 RuntimeError: Numpy is not available 에러 생김.
#
# 인터프러터 버젼 3.10 이상일때 생기는 문제라고 해서 3.9 설치하고 선택해줬는데도 해결되지 않음.
#
# 그냥 나중에 한꺼번에 돌릴거 감안해서 뒷부분은 주석처리하고
#
# csv 파일 merge하기로 했음.

# %%
# from tqdm import tqdm
# !pip install numpy --upgrade --user
# import numpy as np
# model = train(model, train_loader, criterion, optimizer, device, 200, 1)
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.25.0)
#   0%|          | 0/200 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[94], line 4
#       2 get_ipython().system('pip install numpy --upgrade --user')
#       3 import numpy as np
# ----> 4 model = train(model, train_loader, criterion, optimizer, device, 200, 1)
#
# Cell In[88], line 11, in train(model, train_loader, criterion, optimizer, device, epochs, tolerance)
#       9 train_loss = 0
#      10 for epoch in tqdm(range(epochs)):
# ---> 11     for X, y in train_loader:
#      12         X = X.to(device)
#      13         y = y.to(device)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# Cell In[86], line 11, in Windowed_Dataset.__getitem__(self, idx)
#      10 def __getitem__(self, idx):
# ---> 11     return torch.from_numpy(self.data[idx:idx+self.window_size].values).type(torch.FloatTensor), torch.from_numpy(self.data[idx+self.window_size:idx+self.window_size+self.forcast_size].values).type(torch.FloatTensor)
#
# RuntimeError: Numpy is not available

# %%
# test_predictions = test(model, test_loader, criterion, device)

# %%
# test_predictions = torch.cat(test_predictions, dim=0)
# test_predictions.shape

# %%
# plt.figure(figsize=(12,8))
# plt.title('LTSF-DLinear')
# for i in range(9,30,10):
#     plt.plot(test_predictions[:,i,0].cpu().detach().numpy(), label='Predictions_{}'.format(i+1))
# plt.plot(test_dataset[ticker[0]].values[WINDOW_SIZE:-FORCAST_SIZE], label='True')
# plt.legend()
# plt.show()

# %% [markdown]
# 데이터 뽑기

# %%
# all_predictions = test(model, all_loader, criterion, device)
# all_predictions = torch.cat(all_predictions, dim=0)
# all_predictions.shape

# %%
# prediction_5 = pd.DataFrame(all_predictions[:,4,:], columns=tickers, index = (data_for_pred.index[WINDOW_SIZE:-FORCAST_SIZE]))
# prediction_10 = pd.DataFrame(all_predictions[:,9,:], columns=tickers, index = (data_for_pred.index[WINDOW_SIZE:-FORCAST_SIZE]))
# prediction_30 = pd.DataFrame(all_predictions[:,29,:], columns=tickers, index = (data_for_pred.index[WINDOW_SIZE:-FORCAST_SIZE]))

# %%
# prediction_5[ticker[0]].plot(figsize=(12,8), label='Predictions_5')
# data_for_pred[ticker[0]].plot(label='True')
# plt.legend()

# %%
# prediction_5.to_csv('prediction_5.csv')
# prediction_10.to_csv('prediction_10.csv')
# prediction_30.to_csv('prediction_30.csv')

# %%
#prediction 업로드시 확인 필요부분
prediction_5 = pd.read_csv('prediction_5.csv').set_index('Unnamed: 0')
prediction_10 = pd.read_csv('prediction_10.csv').set_index('Unnamed: 0')
prediction_30 = pd.read_csv('prediction_30.csv').set_index('Unnamed: 0')

# %%
#prediction 업로드시 확인 필요부분


prediction_5_list = []
for i in range(len(prediction_5)):
    for j in range(len(ticker)):
        prediction_5_list.append(prediction_5.iloc[i,j])
        
for i in range((len(process_full)-len(prediction_5_list))//len(ticker)):
    for j in range(len(ticker)):
        prediction_5_list.append(prediction_5.iloc[-1,j])

prediction_10_list = []
for i in range(len(prediction_10)):
    for j in range(len(ticker)):
        prediction_10_list.append(prediction_10.iloc[i,j])

for i in range((len(process_full)-len(prediction_10_list))//len(ticker)):
    for j in range(len(ticker)):
        prediction_10_list.append(prediction_10.iloc[-1,j])
    
prediction_30_list = []
for i in range(len(prediction_30)):
    for j in range(len(ticker)):
        prediction_30_list.append(prediction_30.iloc[i,j])
for i in range((len(process_full)-len(prediction_30_list))//len(ticker)):
    for j in range(len(ticker)):
        prediction_30_list.append(prediction_30.iloc[-1,j])
        
print(len(prediction_5_list))
# Out:
# 32472

# %%
#prediction 업로드시 확인 필요부분

process_full['prediction_5']=prediction_5_list
process_full['prediction_10']=prediction_10_list
process_full['prediction_30']=prediction_30_list

process_full
# Out:
#              date  tic        open        high         low       close  \
# 0      2009-01-02  XLB   22.900000   23.709999   22.690001   17.207548
# 1      2009-01-02  XLE   48.200001   50.669998   48.080002   31.549149
# 2      2009-01-02  XLF   10.178716   10.406174    9.918765    7.878148
# 3      2009-01-02  XLI   23.520000   24.420000   23.270000   18.167879
# 4      2009-01-02  XLK   15.500000   16.070000   15.380000   12.912431
# ...           ...  ...         ...         ...         ...         ...
# 47110  2023-05-03  XLK  149.690002  150.660004  148.179993  147.940125
# 47111  2023-05-03  XLP   77.059998   77.379997   76.639999   76.119987
# 47112  2023-05-03  XLU   68.639999   69.050003   67.989998   67.526855
# 47113  2023-05-03  XLV  134.259995  134.899994  133.270004  132.912888
# 47114  2023-05-03  XLY  145.940002  147.889999  145.279999  145.098145
#
#             volume  day      macd     boll_ub  ...      rsi_30     cci_30  \
# 0        7110000.0  4.0  0.000000   17.277415  ...  100.000000  66.666667
# 1       34283700.0  4.0  0.000000   17.277415  ...  100.000000  66.666667
# 2      117919090.0  4.0  0.000000   17.277415  ...  100.000000  66.666667
# 3        6659500.0  4.0  0.000000   17.277415  ...  100.000000  66.666667
# 4        4479800.0  4.0  0.000000   17.277415  ...  100.000000  66.666667
# ...            ...  ...       ...         ...  ...         ...        ...
# 47110    5815100.0  2.0  1.101266  151.344400  ...   55.182961  46.442993
# 47111   11656600.0  2.0  0.875702   77.189108  ...   58.998060  93.547472
# 47112   11857200.0  2.0  0.319781   69.807814  ...   50.161291   8.126302
# 47113    8961500.0  2.0  0.915705  134.927106  ...   53.906948  54.096702
# 47114    4256000.0  2.0  0.418781  148.824533  ...   50.679820  23.335247
#
#             dx_30  close_30_sma  close_60_sma        vix  turbulence  \
# 0      100.000000     17.207548     17.207548  39.189999    0.000000
# 1      100.000000     31.549149     31.549149  39.189999    0.000000
# 2      100.000000      7.878148      7.878148  39.189999    0.000000
# 3      100.000000     18.167879     18.167879  39.189999    0.000000
# 4      100.000000     12.912431     12.912431  39.189999    0.000000
# ...           ...           ...           ...        ...         ...
# 47110    6.225843    147.699630    143.517544  18.340000    4.219977
# 47111   22.508083     74.795711     73.269687  18.340000    4.219977
# 47112    8.132944     67.692193     66.656867  18.340000    4.219977
# 47113    6.687990    131.318106    129.596837  18.340000    4.219977
# 47114    0.925005    145.369260    145.068298  18.340000    4.219977
#
#        prediction_5  prediction_10  prediction_30
# 0         25.001299      25.008287      28.824316
# 1         43.503914      40.740055      41.319206
# 2          9.368776       8.849185      10.953069
# 3         25.687847      26.830729      29.474950
# 4         23.967155      25.295761      25.559303
# ...             ...            ...            ...
# 47110    159.765030     199.236300     229.869460
# 47111     77.748860      81.883970      84.795660
# 47112     72.211586      72.498500      82.259070
# 47113    131.804820     142.887970     185.065430
# 47114    158.683320     165.199040     216.651820
#
# [32472 rows x 21 columns]

# %%
#prediction 업로드시 확인 필요부분


INDICATORS += ['prediction_5','prediction_10','prediction_30']

# %%
train = data_split(process_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(process_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 28881
# 3591

# %% [markdown]
# # Env

# %% [markdown]
# ## Overview
#
# State Space = [p,h,b]. stock price p, stock shares h, remaining balance b
#
# Action Space = [sell, buy] (hold action realized by remaining balance )
#
# Reward : Change of pf value (depending on a,s,s')
#
# Policy
#
# Value function
#
# Action function
#
# Reward Hypothesis? Maximize pf value

# %% [markdown]
# ## Env Setting
#
# State Space : 8(INDICATORS) * 9(NUMBER of stocks) + 2(stock price p, stock shares h) * 9(NUMBER of stocks) + 1(remaining balance b)
#
# 1. Balance b : 현금계좌 잔고
#
# 2. Stock price : p
#
# 3. Shares : 보유량
#
# ---
#
# 4. MACD : SMA - LMA, signal = rolling by k days (closed price)
#
# 5. CCI : 주가가 MA에서 얼마나 떨어져 있는지 (과매수, 과매도 측정)
#
# 6. ADX : 추세의 강도를 측정
#
# 7. RSI
#
# 8. Bollinger band
#
# Action Space : (2k+1)^9, k <= h_max (h_max는 사용자 설정 hp)
#
# {-k,...,-1,0,1,...,k}
#
# hmax : 한번에 살수있는 주식의 최대 share

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}
# Out:
# Stock Dimension: 9, State Space: 91

# %% [markdown]
# # kwargs setting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# *** kwargs setting ***
#
# - A2C_model_kwargs
#     - n_steps : 64  : batch_size = n_steps * n_env. n_env=1 이라고 가정
#     - ent_coef : Entropy coefficient for the loss calculation
#     - learning_rate
#     - use_sde : False --> True : generalized State Dependent Exploration (gSDE) instead of action noise exploration (default : uniform distribution action noise)
#     - gae_lambda : Factor for trade-off of bias vs variance for Generalized Advantage Estimator. ()
#         `gae_lambda` 값을 0로 맞추면 1-step TD가 되고, 1로 맞추면 Monte Carlo가 되며,이 두가지를 서로 섞었다고 볼 수 있습니다. (http://incredible.ai/reinforcement-learning/2019/07/20/Advantage-A2C/)
#     - stats_window_size: 1024 : number of episodes
#     A2C는 어떻게 exploration 을 수행하는가?
#     (A2C explores by sampling actions from actor's policy network during the interaction with the environment, plus adding entropy to objective function)
#
#
#
#
# - PPO_model_kwargs
#     - n_steps : 2048: The number of steps to run for each environment per update
#     (number of episodes = n_steps * n_envs). n_envs=1 이라고 가정
#     - 이하 동일
#
#
# - DDPG_model_kwargs
#     number of episodes = 80_000/64 = 1250
#     - "action_noise": "ornstein_uhlenbeck" process  \
#     정확한 값은 estimand를 사용함.
#
#
# - SAC_model_kwargs
#
# - TD3_model_kwargs
#
#     이하 동일

# %% [markdown]
# cf. gSDE
#
# ![image.png](attachment:image.png)

# %%
A2C_model_kwargs = {
                    'n_steps': 5, # batch_size = n_steps * n_env
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    # 'gae_lambda': 0.5
                    }

PPO_model_kwargs = {
                    'ent_coef': 0.0005183132061837715,
                    "n_steps": 2048,
                    'learning_rate': 0.06216758482938669,
                    'batch_size': 256,
                    'gae_lambda': 0.5
                    }

DDPG_model_kwargs = {
                      "action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 1_000_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

TD3_model_kwargs = {
                      "action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 1_000_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }
SAC_model_kwargs = {
                      "action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 1_000_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 100_000, # total number of samples (env steps) to train on
                 'ppo' : 100_000, 
                 'ddpg' : 80_000, 
                 'td3' : 100_000,
                 'sac' : 100_000
                 }

# %% [markdown]
# ## Ornstein_Uhlenbeck_Process Estimand

# %%
# %pip install git+https://github.com/mghadam/ouparams.git
# Out:
# Collecting git+https://github.com/mghadam/ouparams.gitNote: you may need to restart the kernel to use updated packages.
#
#   Cloning https://github.com/mghadam/ouparams.git to c:\users\user\appdata\local\temp\pip-req-build-v2bdmoqn
#   Resolved https://github.com/mghadam/ouparams.git to commit 0862e77b606d833d1955fc47c689661ad12a446d
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
#   Running command git clone --filter=blob:none --quiet https://github.com/mghadam/ouparams.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-v2bdmoqn'
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)

# %% [markdown]
# *** Orstein_Ulhenbeck_Process ***
#
# Stationary, Gaussian, Markov Process 를 만족하는 유일한 Stochastic Process
#
# 시계열이 stationary하다고 가정함.
#
# 해당 가정은 moving average가 과매수/과매도 발생시 평균으로 회귀하려는 mean reversion property를 가지고 있다는 가정과 일맥상통함.
#
#
# \
# \
# \
#
#
# mean-reversion process : 현재 시점의 값이 평균 값에서 떨어진 만큼에 이를 반영하는 정도를 곱한 값이 다음 시점에 반영되어 평균으로 회귀하게 되는 확률 과정이다.
#
# - mu : long term mean
# - sigma : volatility
# - theta : speed of mean reversion to mu
#
# 브라우니안 모션의 입자(component)가 마찰(theta)의 영향을 받아 자신의 이전 상태로 되돌아가려는 경향을 갖게되며, 이러한 경향성이 시간에 따라 심화되면서 장기적인 평균으로 회귀하게 되는 확률과정.
#
# 위에서도 언급했듯이 해당 가정은 주식시장에서 과매수/과매도 상황에서 장기적 평균으로 회귀하려는 특징을 반영함.
#
# 따라서 OU Process 가 단순 random walk environment를 상정하는 것보다 장점을 지닌다고 판단함.

# %%
# preprocess to numpy array

train_close = train.sort_values(['date','tic'],ignore_index=True)[['date','tic','close']]
train_close
XLB= train_close[train_close['tic']=='XLB']['close'].values
XLE= train_close[train_close['tic']=='XLE']['close'].values
XLF= train_close[train_close['tic']=='XLF']['close'].values
XLI= train_close[train_close['tic']=='XLI']['close'].values
XLK= train_close[train_close['tic']=='XLK']['close'].values
XLP= train_close[train_close['tic']=='XLP']['close'].values
XLU= train_close[train_close['tic']=='XLU']['close'].values
XLV= train_close[train_close['tic']=='XLV']['close'].values
XLY= train_close[train_close['tic']=='XLY']['close'].values

# %%
from ouparams import ouparams
sigma_XLB, theta_XLB = ouparams.find(XLB)[1:]
sigma_XLE, theta_XLE = ouparams.find(XLE)[1:]
sigma_XLF, theta_XLF = ouparams.find(XLF)[1:]
sigma_XLI, theta_XLI = ouparams.find(XLF)[1:]
sigma_XLK, theta_XLK = ouparams.find(XLK)[1:]
sigma_XLP, theta_XLP = ouparams.find(XLP)[1:]
sigma_XLU, theta_XLU = ouparams.find(XLU)[1:]
sigma_XLV, theta_XLV = ouparams.find(XLV)[1:]
sigma_XLY, theta_XLY = ouparams.find(XLY)[1:]

print(sigma_XLB, theta_XLB)
# Out:
# 0.5638989380897781 0.00010636857862432567

# %% [markdown]
# 우리가 관심있는건 action noise로써 사용한 ornstein_ulhenbeck_process 의 sigma와 theta. mu는 0인 parametric model을 가정함.
#
# 해당 sigma, theta값을 agent에 input

# %%
sigma_ = [sigma_XLB, sigma_XLE, sigma_XLF, sigma_XLI ,sigma_XLK, sigma_XLP ,sigma_XLU ,sigma_XLV, sigma_XLY]
theta_ = [theta_XLB, theta_XLE, theta_XLF, theta_XLI ,theta_XLK, theta_XLP ,theta_XLU ,theta_XLV, theta_XLY]

# %% [markdown]
# # Agent

# %%
# DRL models from Stable Baselines 3
from __future__ import annotations

import time

import numpy as np
import pandas as pd
from stable_baselines3 import A2C
from stable_baselines3 import DDPG
from stable_baselines3 import PPO
from stable_baselines3 import SAC
from stable_baselines3 import TD3
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.noise import OrnsteinUhlenbeckActionNoise
from stable_baselines3.common.vec_env import DummyVecEnv

from finrl import config
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.meta.preprocessor.preprocessors import data_split

MODELS = {"a2c": A2C, "ddpg": DDPG, "td3": TD3, "sac": SAC, "ppo": PPO}

MODEL_KWARGS = {x: config.__dict__[f"{x.upper()}_PARAMS"] for x in MODELS.keys()}

NOISE = {
    "normal": NormalActionNoise,
    "ornstein_uhlenbeck": OrnsteinUhlenbeckActionNoise,
}


class TensorboardCallback(BaseCallback):
    """
    Custom callback for plotting additional values in tensorboard.
    """

    def __init__(self, verbose=0):
        super().__init__(verbose)

    def _on_step(self) -> bool:
        try:
            self.logger.record(key="train/reward", value=self.locals["rewards"][0])
        except BaseException:
            self.logger.record(key="train/reward", value=self.locals["reward"][0])
        return True


class DRLAgent:
    """Provides implementations for DRL algorithms

    Attributes
    ----------
        env: gym environment class
            user-defined class

    Methods
    -------
        get_model()
            setup DRL algorithms
        train_model()
            train DRL algorithms in a train dataset
            and output the trained model
        DRL_prediction()
            make a prediction in a test dataset and get results
    """

    def __init__(self, env):
        self.env = env

    def get_model(
        self,
        model_name,
        policy="MlpPolicy",
        policy_kwargs=None,
        model_kwargs=None,
        verbose=1,
        seed=None,
        tensorboard_log=None,
    ):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")

        if model_kwargs is None:
            model_kwargs = MODEL_KWARGS[model_name]

        if "action_noise" in model_kwargs:
            n_actions = self.env.action_space.shape[-1]
            model_kwargs["action_noise"] = NOISE[model_kwargs["action_noise"]](
                mean=np.zeros(n_actions), sigma= sigma_ * np.ones(n_actions), theta=theta_ * np.ones(n_actions)
            )
        print(model_kwargs)
        return MODELS[model_name](
            policy=policy,
            env=self.env,
            tensorboard_log=tensorboard_log,
            verbose=verbose,
            policy_kwargs=policy_kwargs,
            seed=seed,
            **model_kwargs,
        )

    def train_model(self, model, tb_log_name, total_timesteps=5000):
        model = model.learn(
            total_timesteps=total_timesteps,
            tb_log_name=tb_log_name,
            callback=TensorboardCallback(),
        )
        return model

    @staticmethod
    def DRL_prediction(model, environment, deterministic=True):
        test_env, test_obs = environment.get_sb_env()
        """make a prediction"""
        account_memory = []
        actions_memory = []
        #         state_memory=[] #add memory pool to store states
        test_env.reset()
        for i in range(len(environment.df.index.unique())):
            action, _states = model.predict(test_obs, deterministic=deterministic)
            # account_memory = test_env.env_method(method_name="save_asset_memory")
            # actions_memory = test_env.env_method(method_name="save_action_memory")
            test_obs, rewards, dones, info = test_env.step(action)
            if i == (len(environment.df.index.unique()) - 2):
                account_memory = test_env.env_method(method_name="save_asset_memory")
                actions_memory = test_env.env_method(method_name="save_action_memory")
            #                 state_memory=test_env.env_method(method_name="save_state_memory") # add current state to state memory
            if dones[0]:
                print("hit end!")
                break
        return account_memory[0], actions_memory[0]

    @staticmethod
    def DRL_prediction_load_from_file(model_name, environment, cwd, deterministic=True):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")
        try:
            # load agent
            model = MODELS[model_name].load(cwd)
            print("Successfully load model", cwd)
        except BaseException:
            raise ValueError("Fail to load agent!")

        # test on the testing env
        state = environment.reset()
        episode_returns = []  # the cumulative_return / initial_account
        episode_total_assets = [environment.initial_total_asset]
        done = False
        while not done:
            action = model.predict(state, deterministic=deterministic)[0]
            state, reward, done, _ = environment.step(action)

            total_asset = (
                environment.amount
                + (environment.price_ary[environment.day] * environment.stocks).sum()
            )
            episode_total_assets.append(total_asset)
            episode_return = total_asset / environment.initial_total_asset
            episode_returns.append(episode_return)

        print("episode_return", episode_return)
        print("Test Finished!")
        return episode_total_assets


class DRLEnsembleAgent:
    @staticmethod
    def get_model(
        model_name,
        env,
        policy="MlpPolicy",
        policy_kwargs=None,
        model_kwargs=None,
        seed=None,
        verbose=1,
    ):
        if model_name not in MODELS:
            raise NotImplementedError("NotImplementedError")

        if model_kwargs is None:
            temp_model_kwargs = MODEL_KWARGS[model_name]
        else:
            temp_model_kwargs = model_kwargs.copy()

        if "action_noise" in temp_model_kwargs:
            n_actions = env.action_space.shape[-1]
            temp_model_kwargs["action_noise"] = NOISE[
                temp_model_kwargs["action_noise"]
            ](mean=np.zeros(n_actions), sigma=sigma_ * np.ones(n_actions), theta=theta_ * np.ones(n_actions))
        print(temp_model_kwargs)
        return MODELS[model_name](
            policy=policy,
            env=env,
            tensorboard_log=f"{config.TENSORBOARD_LOG_DIR}/{model_name}",
            verbose=verbose,
            policy_kwargs=policy_kwargs,
            seed=seed,
            **temp_model_kwargs,
        )

    @staticmethod
    def train_model(model, model_name, tb_log_name, iter_num, total_timesteps=5000):
        model = model.learn(
            total_timesteps=total_timesteps,
            tb_log_name=tb_log_name,
            callback=TensorboardCallback(),
        )
        model.save(
            f"{config.TRAINED_MODEL_DIR}/{model_name.upper()}_{total_timesteps // 1000}k_{iter_num}"
        )
        return model

    @staticmethod
    def get_validation_sharpe(iteration, model_name):
        """Calculate Sharpe ratio based on validation results"""
        df_total_value = pd.read_csv(
            f"results/account_value_validation_{model_name}_{iteration}.csv"
        )
        # If the agent did not make any transaction
        if df_total_value["daily_return"].var() == 0:
            if df_total_value["daily_return"].mean() > 0:
                return np.inf
            else:
                return 0.0
        else:
            return (
                (4**0.5)
                * df_total_value["daily_return"].mean()
                / df_total_value["daily_return"].std()
            )

    def __init__(
        self,
        df,
        train_period,
        val_test_period,
        rebalance_window,
        validation_window,
        stock_dim,
        hmax,
        initial_amount,
        buy_cost_pct,
        sell_cost_pct,
        reward_scaling,
        state_space,
        action_space,
        tech_indicator_list,
        print_verbosity,
    ):
        self.df = df
        self.train_period = train_period
        self.val_test_period = val_test_period

        self.unique_trade_date = df[
            (df.date > val_test_period[0]) & (df.date <= val_test_period[1])
        ].date.unique()
        self.rebalance_window = rebalance_window
        self.validation_window = validation_window

        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        self.print_verbosity = print_verbosity

    def DRL_validation(self, model, test_data, test_env, test_obs):
        """validation process"""
        for _ in range(len(test_data.index.unique())):
            action, _states = model.predict(test_obs)
            test_obs, rewards, dones, info = test_env.step(action)

    def DRL_prediction(
        self, model, name, last_state, iter_num, turbulence_threshold, initial
    ):
        """make a prediction based on trained model"""

        ## trading env
        trade_data = data_split(
            self.df,
            start=self.unique_trade_date[iter_num - self.rebalance_window],
            end=self.unique_trade_date[iter_num],
        )
        trade_env = DummyVecEnv(
            [
                lambda: StockTradingEnv(
                    df=trade_data,
                    stock_dim=self.stock_dim,
                    hmax=self.hmax,
                    initial_amount=self.initial_amount,
                    num_stock_shares=[0] * self.stock_dim,
                    buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                    sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                    reward_scaling=self.reward_scaling,
                    state_space=self.state_space,
                    action_space=self.action_space,
                    tech_indicator_list=self.tech_indicator_list,
                    turbulence_threshold=turbulence_threshold,
                    initial=initial,
                    previous_state=last_state,
                    model_name=name,
                    mode="trade",
                    iteration=iter_num,
                    print_verbosity=self.print_verbosity,
                )
            ]
        )

        trade_obs = trade_env.reset()

        for i in range(len(trade_data.index.unique())):
            action, _states = model.predict(trade_obs)
            trade_obs, rewards, dones, info = trade_env.step(action)
            if i == (len(trade_data.index.unique()) - 2):
                # print(env_test.render())
                last_state = trade_env.envs[0].render()

        df_last_state = pd.DataFrame({"last_state": last_state})
        # 수정(06/28): run_ensemble_strategy 실행시 ValueError: If using all scalar values, you must pass an index 오류 출력됨.
        # 수정: df_last_state가 run_ensemble_strategy를 시행하는데 있어서 쓰이지 않음. 따라서 제거해주고 시행해봄. 그 결과 동일한 오류 발생
        df_last_state.to_csv(f"results/last_state_{name}_{i}.csv", index=False)
        # 수정 : 다시 풀어줌. requirements.txt issue인게 밝혀짐.
        # 수정 : last_state = trade_env.render() --> trade_env.evns[0].render() 로 바꿔줌
        return last_state

    def run_ensemble_strategy_(
        self, A2C_model_kwargs, PPO_model_kwargs, DDPG_model_kwargs, TD3_model_kwargs, SAC_model_kwargs, timesteps_dict
    ):
        """Ensemble Strategy that combines PPO, A2C and DDPG"""
        print("============Start Ensemble Strategy============")
        # for ensemble model, it's necessary to feed the last state
        # of the previous model to the current model as the initial state
        last_state_ensemble = []

        ppo_sharpe_list = []
        ddpg_sharpe_list = []
        a2c_sharpe_list = []
        td3_sharpe_list = []
        sac_sharpe_list = []

        model_use = []
        validation_start_date_list = []
        validation_end_date_list = []
        iteration_list = []

        insample_turbulence = self.df[
            (self.df.date < self.train_period[1])
            & (self.df.date >= self.train_period[0])
        ]
        insample_turbulence_threshold = np.quantile(
            insample_turbulence.turbulence.values, 0.90
        )

        start = time.time()
        for i in range(
            self.rebalance_window + self.validation_window,
            len(self.unique_trade_date),
            self.rebalance_window,
        ):
            validation_start_date = self.unique_trade_date[
                i - self.rebalance_window - self.validation_window
            ]
            validation_end_date = self.unique_trade_date[i - self.rebalance_window]

            validation_start_date_list.append(validation_start_date)
            validation_end_date_list.append(validation_end_date)
            iteration_list.append(i)

            print("============================================")
            ## initial state is empty
            if i - self.rebalance_window - self.validation_window == 0:
                # inital state
                initial = True
            else:
                # previous state
                initial = False

            # Tuning trubulence index based on historical data
            # Turbulence lookback window is one quarter (63 days)
            end_date_index = self.df.index[
                self.df["date"]
                == self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ]
            ].to_list()[-1]
            start_date_index = end_date_index - 63 + 1

            historical_turbulence = self.df.iloc[
                start_date_index : (end_date_index + 1), :
            ]

            historical_turbulence = historical_turbulence.drop_duplicates(
                subset=["date"]
            )

            historical_turbulence_mean = np.mean(
                historical_turbulence.turbulence.values
            )

            # print(historical_turbulence_mean)

            if historical_turbulence_mean > insample_turbulence_threshold:
                # if the mean of the historical data is greater than the 90% quantile of insample turbulence data
                # then we assume that the current market is volatile,
                # therefore we set the 90% quantile of insample turbulence data as the turbulence threshold
                # meaning the current turbulence can't exceed the 90% quantile of insample turbulence data
                turbulence_threshold = insample_turbulence_threshold
            else:
                # if the mean of the historical data is less than the 90% quantile of insample turbulence data
                # then we tune up the turbulence_threshold, meaning we lower the risk
                turbulence_threshold = np.quantile(
                    insample_turbulence.turbulence.values, 1
                )

            turbulence_threshold = np.quantile(
                insample_turbulence.turbulence.values, 0.90
            )
            print("turbulence_threshold: ", turbulence_threshold)

            ############## Environment Setup starts ##############
            ## training env
            train = data_split(
                self.df,
                start=self.train_period[0],
                end=self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
            )
            self.train_env = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=train,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )

            validation = data_split(
                self.df,
                start=self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
                end=self.unique_trade_date[i - self.rebalance_window],
            )
            ############## Environment Setup ends ##############

            ############## Training and Validation starts ##############
            print(
                "======Model training from: ",
                self.train_period[0],
                "to ",
                self.unique_trade_date[
                    i - self.rebalance_window - self.validation_window
                ],
            )
            # print("training: ",len(data_split(df, start=20090000, end=test.datadate.unique()[i-rebalance_window]) ))
            # print("==============Model Training===========")
            print("======A2C Training========")
            model_a2c = self.get_model(
                "a2c", self.train_env, policy="MlpPolicy", model_kwargs=A2C_model_kwargs
            )
            model_a2c = self.train_model(
                model_a2c,
                "a2c",
                tb_log_name=f"a2c_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["a2c"],
            )  # 100_000

            print(
                "======A2C Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_a2c = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="A2C",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_a2c = val_env_a2c.reset()
            self.DRL_validation(
                model=model_a2c,
                test_data=validation,
                test_env=val_env_a2c,
                test_obs=val_obs_a2c,
            )
            sharpe_a2c = self.get_validation_sharpe(i, model_name="A2C")
            print("A2C Sharpe Ratio: ", sharpe_a2c)

            print("======PPO Training========")
            model_ppo = self.get_model(
                "ppo", self.train_env, policy="MlpPolicy", model_kwargs=PPO_model_kwargs
            )
            model_ppo = self.train_model(
                model_ppo,
                "ppo",
                tb_log_name=f"ppo_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["ppo"],
            )  # 100_000
            print(
                "======PPO Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_ppo = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="PPO",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_ppo = val_env_ppo.reset()
            self.DRL_validation(
                model=model_ppo,
                test_data=validation,
                test_env=val_env_ppo,
                test_obs=val_obs_ppo,
            )
            sharpe_ppo = self.get_validation_sharpe(i, model_name="PPO")
            print("PPO Sharpe Ratio: ", sharpe_ppo)

            print("======DDPG Training========")
            model_ddpg = self.get_model(
                "ddpg",
                self.train_env,
                policy="MlpPolicy",
                model_kwargs=DDPG_model_kwargs,
            )
            model_ddpg = self.train_model(
                model_ddpg,
                "ddpg",
                tb_log_name=f"ddpg_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["ddpg"],
            )  # 50_000
            print(
                "======DDPG Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_ddpg = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="DDPG",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_ddpg = val_env_ddpg.reset()
            self.DRL_validation(
                model=model_ddpg,
                test_data=validation,
                test_env=val_env_ddpg,
                test_obs=val_obs_ddpg,
            )
            sharpe_ddpg = self.get_validation_sharpe(i, model_name="DDPG")

            print("======SAC Training========")
            model_sac = self.get_model(
                "sac", self.train_env, policy="MlpPolicy", model_kwargs=SAC_model_kwargs
            )
            model_sac = self.train_model(
                model_sac,
                "sac",
                tb_log_name=f"sac_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["sac"],
                # 100_000
            )

            print(
                "======SAC Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_sac = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="SAC",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_sac = val_env_sac.reset()
            self.DRL_validation(
                model=model_sac,
                test_data=validation,
                test_env=val_env_sac,
                test_obs=val_obs_sac,
            )
            sharpe_sac = self.get_validation_sharpe(i, model_name="SAC")
            print("SAC Sharpe Ratio : ", sharpe_sac)

            print("======TD3 Training========")
            model_td3 = self.get_model(
                "td3", self.train_env, policy="MlpPolicy", model_kwargs=TD3_model_kwargs
            )
            model_td3 = self.train_model(
                model_td3,
                "td3",
                tb_log_name=f"td3_{i}",
                iter_num=i,
                total_timesteps=timesteps_dict["td3"],
                # 100_000
            )

            print(
                "======TD3 Validation from: ",
                validation_start_date,
                "to ",
                validation_end_date,
            )
            val_env_td3 = DummyVecEnv(
                [
                    lambda: StockTradingEnv(
                        df=validation,
                        stock_dim=self.stock_dim,
                        hmax=self.hmax,
                        initial_amount=self.initial_amount,
                        num_stock_shares=[0] * self.stock_dim,
                        buy_cost_pct=[self.buy_cost_pct] * self.stock_dim,
                        sell_cost_pct=[self.sell_cost_pct] * self.stock_dim,
                        reward_scaling=self.reward_scaling,
                        state_space=self.state_space,
                        action_space=self.action_space,
                        tech_indicator_list=self.tech_indicator_list,
                        turbulence_threshold=turbulence_threshold,
                        iteration=i,
                        model_name="TD3",
                        mode="validation",
                        print_verbosity=self.print_verbosity,
                    )
                ]
            )
            val_obs_td3 = val_env_td3.reset()
            self.DRL_validation(
                model=model_td3,
                test_data=validation,
                test_env=val_env_td3,
                test_obs=val_obs_td3,
            )
            sharpe_td3 = self.get_validation_sharpe(i, model_name="TD3")
            print("TD3 Sharpe Ratio : ", sharpe_td3)

            ppo_sharpe_list.append(sharpe_ppo)
            a2c_sharpe_list.append(sharpe_a2c)
            ddpg_sharpe_list.append(sharpe_ddpg)
            sac_sharpe_list.append(sharpe_sac)
            td3_sharpe_list.append(sharpe_td3)

            print(
                "======Best Model Retraining from: ",
                self.train_period[0],
                "to ",
                self.unique_trade_date[i - self.rebalance_window],
            )
            # Environment setup for model retraining up to first trade date
            # train_full = data_split(self.df, start=self.train_period[0], end=self.unique_trade_date[i - self.rebalance_window])
            # self.train_full_env = DummyVecEnv([lambda: StockTradingEnv(train_full,
            #                                                    self.stock_dim,
            #                                                    self.hmax,
            #                                                    self.initial_amount,
            #                                                    self.buy_cost_pct,
            #                                                    self.sell_cost_pct,
            #                                                    self.reward_scaling,
            #                                                    self.state_space,
            #                                                    self.action_space,
            #                                                    self.tech_indicator_list,
            #                                                    print_verbosity=self.print_verbosity)])
            # Model Selection based on sharpe ratio
            if (sharpe_ppo >= sharpe_a2c) & (sharpe_ppo >= sharpe_ddpg) & (sharpe_ppo >= sharpe_sac) & (sharpe_ppo >= sharpe_td3):
                model_use.append("PPO")
                model_ensemble = model_ppo

                # model_ensemble = self.get_model("ppo",self.train_full_env,policy="MlpPolicy",model_kwargs=PPO_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['ppo']) #100_000
            elif (sharpe_a2c > sharpe_ppo) & (sharpe_a2c > sharpe_ddpg) & (sharpe_a2c >= sharpe_sac) & (sharpe_a2c >= sharpe_td3):
                model_use.append("A2C")
                model_ensemble = model_a2c

                # model_ensemble = self.get_model("a2c",self.train_full_env,policy="MlpPolicy",model_kwargs=A2C_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['a2c']) #100_000
            elif (sharpe_ddpg > sharpe_ppo) & (sharpe_ddpg > sharpe_a2c) & (sharpe_ddpg >= sharpe_sac) & (sharpe_ddpg >= sharpe_td3):
                model_use.append("DDPG")
                model_ensemble = model_ddpg

                # model_ensemble = self.get_model("ddpg",self.train_full_env,policy="MlpPolicy",model_kwargs=DDPG_model_kwargs)
                # model_ensemble = self.train_model(model_ensemble, "ensemble", tb_log_name="ensemble_{}".format(i), iter_num = i, total_timesteps=timesteps_dict['ddpg']) #50_000#

            elif (sharpe_sac > sharpe_ppo) & (sharpe_sac > sharpe_a2c) & (sharpe_sac >= sharpe_ddpg) & (sharpe_sac >= sharpe_td3):
                model_use.append("SAC")
                model_ensemble = model_sac
            
            else:
                model_use.append("TD3")
                model_ensemble = model_td3
            ############## Training and Validation ends ##############

            ############## Trading starts ##############
            print(
                "======Trading from: ",
                self.unique_trade_date[i - self.rebalance_window],
                "to ",
                self.unique_trade_date[i],
            )
            # print("Used Model: ", model_ensemble)
            last_state_ensemble = self.DRL_prediction(
                model=model_ensemble,
                name="ensemble",
                last_state=last_state_ensemble,
                iter_num=i,
                turbulence_threshold=turbulence_threshold,
                initial=initial,
            )
            ############## Trading ends #############

        end = time.time()
        print("Ensemble Strategy took: ", (end - start) / 60, " minutes")

        df_summary = pd.DataFrame(
            [
                iteration_list,
                validation_start_date_list,
                validation_end_date_list,
                model_use,
                a2c_sharpe_list,
                ppo_sharpe_list,
                ddpg_sharpe_list,
                sac_sharpe_list,
                td3_sharpe_list
            ]
        ).T
        df_summary.columns = [
            "Iter",
            "Val Start",
            "Val End",
            "Model Used",
            "A2C Sharpe",
            "PPO Sharpe",
            "DDPG Sharpe",
            "SAC Sharpe",
            "TD3 Sharpe"
        ]

        return df_summary

# %%
DRLEnsembleAgent.run_ensemble_strategy_
# Out:
# <function __main__.DRLEnsembleAgent.run_ensemble_strategy_(self, A2C_model_kwargs, PPO_model_kwargs, DDPG_model_kwargs, TD3_model_kwargs, SAC_model_kwargs, timesteps_dict)>

# %%
rebalance_window = 63 # number of days to retrain the model
validation_window = 63 # number of days to do validation 

ensemble_agent = DRLEnsembleAgent(df=train,
                                train_period = (TRAIN_START_DATE, TRAIN_END_DATE),
                                val_test_period = (TRADE_START_DATE, TRADE_END_DATE),
                                rebalance_window=rebalance_window,
                                validation_window=validation_window,
                                **env_kwargs )

# %% [markdown]
# 여기서 말하는 validation test period가 test period임. 우리가 설정해놓은 TRADE_START_DATE, TRADE_END_DATE.

# %%
# df_summary = ensemble_agent.run_ensemble_strategy_(A2C_model_kwargs,
#                                                  PPO_model_kwargs,
#                                                  DDPG_model_kwargs,
#                                                  timesteps_dict)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 오류 fix
#
# 해당 issue에 대해 대처하는 방법 두가지
# 1. source_code들어가서 필요하지 않은 부분 제거함
# 2. requirements issue 로 발생함.
#
# 다음 명령으로 손쉽게 requirements.txt 생성이 가능함
# $ pip freeze > requirements.txt
#
# 다음 명령을 실행하면 모든 패키지를 한번에 설치해준다.
# $ pip install -r requirements.txt

# %%
df_summary = ensemble_agent.run_ensemble_strategy_(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  19.02515510912772
# ======Model training from:  2010-01-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c\a2c_126_29
# --------------------------------------
# | time/                 |            |
# |    fps                | 119        |
# |    iterations         | 100        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -12.8      |
# |    explained_variance | -0.000571  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -17.7      |
# |    reward             | 0.19064035 |
# |    std                | 1          |
# |    value_loss         | 3.22       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 129       |
# |    iterations         | 200       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | -0.153    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -25.8     |
# |    reward             | 1.3628126 |
# |    std                | 0.997     |
# |    value_loss         | 7.63      |
# -------------------------------------
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_41828\204804578.py", line 1, in <module>
#     df_summary = ensemble_agent.run_ensemble_strategy_(A2C_model_kwargs,
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_41828\3347254530.py", line 475, in run_ensemble_strategy_
#     model_a2c = self.train_model(
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_41828\3347254530.py", line 202, in train_model
#     model = model.learn(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\a2c\a2c.py", line 194, in learn
#     return super().learn(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py", line 281, in learn
#     self.train()
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\a2c\a2c.py", line 168, in train
#     loss.backward()
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_tensor.py", line 487, in backward
#     )
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\__init__.py", line 200, in backward
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "c:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-10-04  2022-01-03        PPO   0.298426   0.454561    0.390071
# 1  189  2022-01-03  2022-04-04        SAC  -0.113014  -0.255949   -0.169565
# 2  252  2022-04-04  2022-07-06        PPO  -0.279836  -0.234052   -0.364683
# 3  315  2022-07-06  2022-10-04       DDPG  -0.156674  -0.219096   -0.104062
# 4  378  2022-10-04  2023-01-04       DDPG   0.116403   0.182776    0.227078
#
#   SAC Sharpe TD3 Sharpe
# 0   0.258673   0.283786
# 1  -0.096512  -0.187618
# 2  -0.321579  -0.301564
# 3  -0.135079  -0.202601
# 4   0.121143   0.045832

# %% [markdown]
# # Backtest

# %%
unique_trade_date = processed[(processed.date > TRADE_START_DATE)&(processed.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.6895331915222763

# %%
df_account_value.head()
# Out:
#     account_value        date  daily_return    datadate
# 0  1000000.000000  2022-01-03           NaN  2022-01-03
# 1   999864.229365  2022-01-04     -0.000136  2022-01-04
# 2   997105.324363  2022-01-05     -0.002759  2022-01-05
# 3   995860.569249  2022-01-06     -0.001248  2022-01-06
# 4   993940.290174  2022-01-07     -0.001928  2022-01-07

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.142718
# Cumulative returns    -0.175093
# Annual volatility      0.196160
# Sharpe ratio          -0.689533
# Calmar ratio          -0.551993
# Stability              0.619170
# Max drawdown          -0.258550
# Omega ratio            0.892552
# Sortino ratio         -0.949972
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.960607
# Daily value at risk   -0.025251
# dtype: float64

# %%
# backtest_stats 주소
backtest_stats
# Out:
# <function finrl.plot.backtest_stats(account_value, value_col_name='account_value')>

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (314, 8)
# Annual return         -0.066002
# Cumulative returns    -0.081561
# Annual volatility      0.188609
# Sharpe ratio          -0.269023
# Calmar ratio          -0.300816
# Stability              0.080948
# Max drawdown          -0.219408
# Omega ratio            0.956841
# Sortino ratio         -0.373593
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.988482
# Daily value at risk   -0.023964
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
df_dji.to_csv("df_dji.csv")

df_dji = df_dji.set_index(df_dji.columns[0])
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv("df_account_value.csv")

print("df_dji:",df_dji)
# Out:
# df_dji:                      dji
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.005866e+06
# 2022-01-05  9.951360e+05
# 2022-01-06  9.904718e+05
# 2022-01-07  9.903404e+05
# ...                  ...
# 2023-03-29  8.942886e+05
# 2023-03-30  8.981544e+05
# 2023-03-31  9.095010e+05
# 2023-04-03  9.184391e+05
# 2023-04-04           NaN
#
# [315 rows x 1 columns]

# %%
# plot
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date' : df_account_value['date'], 'ensemble' : df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')
print("df_result_ensemble.columns: ", df_result_ensemble.columns)

print("df_trade_date : ", df_trade_date)

df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble:", df_result_ensemble)

print("==============Compare to DJIA===========")
result = pd.DataFrame()
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date :         datadate
# 0    2021-10-04
# 1    2021-10-05
# 2    2021-10-06
# 3    2021-10-07
# 4    2021-10-08
# ..          ...
# 391  2023-04-25
# 392  2023-04-26
# 393  2023-04-27
# 394  2023-04-28
# 395  2023-05-01
#
# [396 rows x 1 columns]
# df_result_ensemble:                   ensemble
# date
# 2022-01-03  1000000.000000
# 2022-01-04   999864.229365
# 2022-01-05   997105.324363
# 2022-01-06   995860.569249
# 2022-01-07   993940.290174
# ...                    ...
# 2023-03-29   803677.516704
# 2023-03-30   807963.184253
# 2023-03-31   816405.636226
# 2023-04-03   824507.388560
# 2023-04-04   824906.621387
#
# [315 rows x 1 columns]
# ==============Compare to DJIA===========

# %% [markdown]
# # Comments

# %% [markdown]
# - test data가 상승장인 경우로 특이한 케이스임. too specific 함. Should we go (1) more general ? Or (2) more specified to certain scenarios ? (general scenario로 합의)
#
# - Where does randomness come from?
#     - Exploration of policy 인듯. episode도 5개밖에 안되고 training 도 15분 남짓이라 n_step, episode늘려서 더 해봐도 좋은 결과 나올거 같음. 다만 train 에 too dependent 하지 않게. depdendent 하더라도, 그 scenario에 맞다는 걸 검증할 수 있으면 좋을텐데. (Action noise로 diversify)
#
#     - scenario를 나누고 그에 대해 검증해볼까? 진짜 time series classification? (시간 한계)
#
# - SAC랑 TD3에 대해서도 할거임 (완료)
